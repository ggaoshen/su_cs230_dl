# %%
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
import seaborn as sns
import random
sns.set()

# %%
df_hsi = pd.read_csv('^HSI.csv')[['Date', 'Adj Close']]
df_spx = pd.read_csv('^GSPC.csv')[['Date', 'Adj Close']]
df_hsi.rename(columns={'Adj Close':'hsi'}, inplace=True)
df_spx.rename(columns={'Adj Close':'spx'}, inplace=True)
df = df_hsi.merge(df_spx, on='Date').dropna()

# %%
df = pd.read_csv('^GSPC.csv')[['Date', 'Close']]
df
# Out:
#             Date        Close
# 0     2001-01-02  1283.270020
# 1     2001-01-03  1347.560059
# 2     2001-01-04  1333.339966
# 3     2001-01-05  1298.349976
# 4     2001-01-08  1295.859985
# ...          ...          ...
# 3768  2015-12-24  2060.989990
# 3769  2015-12-28  2056.500000
# 3770  2015-12-29  2078.360107
# 3771  2015-12-30  2063.360107
# 3772  2015-12-31  2043.939941
#
# [3773 rows x 2 columns]

# %%
import pkg_resources
import types


def get_imports():
    for name, val in globals().items():
        if isinstance(val, types.ModuleType):
            name = val.__name__.split('.')[0]
        elif isinstance(val, type):
            name = val.__module__.split('.')[0]
        poorly_named_packages = {'PIL': 'Pillow', 'sklearn': 'scikit-learn'}
        if name in poorly_named_packages.keys():
            name = poorly_named_packages[name]
        yield name


imports = list(set(get_imports()))
requirements = []
for m in pkg_resources.working_set:
    if m.project_name in imports and m.project_name != 'pip':
        requirements.append((m.project_name, m.version))

for r in requirements:
    print('{}=={}'.format(*r))
# Out:
# seaborn==0.9.0
# pandas==0.25.1
# numpy==1.17.2
# matplotlib==3.1.1

# %%
# df = pd.read_csv('../dataset/GOOG-year.csv')
# df.head()

# %%
class Deep_Evolution_Strategy:

    inputs = None

    def __init__(
        self, weights, reward_function, population_size, sigma, learning_rate
    ):
        self.weights = weights
        self.reward_function = reward_function
        self.population_size = population_size
        self.sigma = sigma
        self.learning_rate = learning_rate

    def _get_weight_from_population(self, weights, population):
        weights_population = []
        for index, i in enumerate(population):
            jittered = self.sigma * i
            weights_population.append(weights[index] + jittered)
        return weights_population

    def get_weights(self):
        return self.weights

    def train(self, epoch = 100, print_every = 1):
        lasttime = time.time()
        for i in range(epoch):
            population = []
            rewards = np.zeros(self.population_size)
            for k in range(self.population_size):
                x = []
                for w in self.weights:
                    x.append(np.random.randn(*w.shape))
                population.append(x)
            for k in range(self.population_size):
                weights_population = self._get_weight_from_population(
                    self.weights, population[k]
                )
                rewards[k] = self.reward_function(weights_population)
            rewards = (rewards - np.mean(rewards)) / (np.std(rewards) + 1e-7)
            for index, w in enumerate(self.weights):
                A = np.array([p[index] for p in population])
                self.weights[index] = (
                    w
                    + self.learning_rate
                    / (self.population_size * self.sigma)
                    * np.dot(A.T, rewards).T
                )
            if (i + 1) % print_every == 0:
                print(
                    'iter %d. reward: %f'
                    % (i + 1, self.reward_function(self.weights))
                )
        print('time taken to train:', time.time() - lasttime, 'seconds')


class Model:
    def __init__(self, input_size, layer_size, output_size):
        self.weights = [
            np.random.randn(input_size, layer_size),
            np.random.randn(layer_size, output_size),
            np.random.randn(1, layer_size),
        ]

    def predict(self, inputs):
        feed = np.dot(inputs, self.weights[0]) + self.weights[-1]
        decision = np.dot(feed, self.weights[1])
        return decision

    def get_weights(self):
        return self.weights

    def set_weights(self, weights):
        self.weights = weights

# %%
class Agent:

    POPULATION_SIZE = 15
    SIGMA = 0.1
    LEARNING_RATE = 0.03

    def __init__(self, model, window_size, trend, skip, initial_money):
        self.model = model
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.initial_money = initial_money
        self.es = Deep_Evolution_Strategy(
            self.model.get_weights(),
            self.get_reward,
            self.POPULATION_SIZE,
            self.SIGMA,
            self.LEARNING_RATE,
        )

    def act(self, sequence):
        decision = self.model.predict(np.array(sequence))
        return np.argmax(decision[0])
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])

    def get_reward(self, weights):
        initial_money = self.initial_money
        starting_money = initial_money
        self.model.weights = weights
        state = self.get_state(0)
        inventory = []
        quantity = 0
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and starting_money >= self.trend[t]:
                inventory.append(self.trend[t])
                starting_money -= close[t]
                
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                starting_money += self.trend[t]

            state = next_state
        return ((starting_money - initial_money) / initial_money) * 100

    def fit(self, iterations, checkpoint):
        self.es.train(iterations, print_every = checkpoint)

    def buy(self):
        initial_money = self.initial_money
        state = self.get_state(0)
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            state = next_state

        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest

# %%
close = df.Close.values.tolist()
window_size = 30
skip = 1
initial_money = 10000

model = Model(input_size = window_size, layer_size = 500, output_size = 3)
agent = Agent(model = model, 
              window_size = window_size,
              trend = close,
              skip = skip,
              initial_money = initial_money)
agent.fit(iterations = 1000, checkpoint = 10)
# Out:
# iter 10. reward: 88.520822
# time taken to train: 36.54858899116516 seconds

# %%
states_buy, states_sell, total_gains, invest = agent.buy()
# Out:
# day 0: buy 1 unit at price 1283.270020, total balance 8716.729980
# day 1: buy 1 unit at price 1347.560059, total balance 7369.169921
# day 2, sell 1 unit at price 1333.339966, investment 3.901747 %, total balance 8702.509887,
# day 3, sell 1 unit at price 1298.349976, investment -3.651791 %, total balance 10000.859863,
# day 5: buy 1 unit at price 1300.800049, total balance 8700.059814
# day 6: buy 1 unit at price 1313.270020, total balance 7386.789794
# day 7, sell 1 unit at price 1326.819946, investment 2.000300 %, total balance 8713.609740,
# day 8, sell 1 unit at price 1318.550049, investment 0.402052 %, total balance 10032.159789,
# day 9: buy 1 unit at price 1326.650024, total balance 8705.509765
# day 11, sell 1 unit at price 1347.969971, investment 1.607051 %, total balance 10053.479736,
# day 12: buy 1 unit at price 1342.540039, total balance 8710.939697
# day 13: buy 1 unit at price 1342.900024, total balance 7368.039673
# day 14: buy 1 unit at price 1360.400024, total balance 6007.639649
# day 15, sell 1 unit at price 1364.300049, investment 1.620809 %, total balance 7371.939698,
# day 16, sell 1 unit at price 1357.510010, investment 1.087943 %, total balance 8729.449708,
# day 17, sell 1 unit at price 1354.949951, investment -0.400623 %, total balance 10084.399659,
# day 19: buy 1 unit at price 1373.729980, total balance 8710.669679
# day 21: buy 1 unit at price 1373.469971, total balance 7337.199708
# day 22: buy 1 unit at price 1349.469971, total balance 5987.729737
# day 23: buy 1 unit at price 1354.310059, total balance 4633.419678
# day 24, sell 1 unit at price 1352.260010, investment -1.562896 %, total balance 5985.679688,
# day 25, sell 1 unit at price 1340.890015, investment -2.372091 %, total balance 7326.569703,
# day 26: buy 1 unit at price 1332.530029, total balance 5994.039674
# day 27: buy 1 unit at price 1314.760010, total balance 4679.279664
# day 28, sell 1 unit at price 1330.310059, investment -1.419810 %, total balance 6009.589723,
# day 29, sell 1 unit at price 1318.800049, investment -2.622000 %, total balance 7328.389772,
# day 30, sell 1 unit at price 1315.920044, investment -1.246500 %, total balance 8644.309816,
# day 31: buy 1 unit at price 1326.609985, total balance 7317.699831
# day 33, sell 1 unit at price 1278.939941, investment -2.724457 %, total balance 8596.639772,
# day 35: buy 1 unit at price 1252.819946, total balance 7343.819826
# day 36: buy 1 unit at price 1245.859985, total balance 6097.959841
# day 38, sell 1 unit at price 1257.939941, investment -5.176355 %, total balance 7355.899782,
# day 39: buy 1 unit at price 1239.939941, total balance 6115.959841
# day 40, sell 1 unit at price 1241.229980, investment -0.925110 %, total balance 7357.189821,
# day 43: buy 1 unit at price 1253.800049, total balance 6103.389772
# day 45, sell 1 unit at price 1264.739990, investment 1.515419 %, total balance 7368.129762,
# day 47, sell 1 unit at price 1180.160034, investment -4.821194 %, total balance 8548.289796,
# day 48: buy 1 unit at price 1197.660034, total balance 7350.629762
# day 49: buy 1 unit at price 1166.709961, total balance 6183.919801
# day 50: buy 1 unit at price 1173.560059, total balance 5010.359742
# day 51, sell 1 unit at price 1150.530029, investment -8.236562 %, total balance 6160.889771,
# day 52: buy 1 unit at price 1170.810059, total balance 4990.079712
# day 53, sell 1 unit at price 1142.619995, investment -4.595631 %, total balance 6132.699707,
# day 56: buy 1 unit at price 1139.829956, total balance 4992.869751
# day 58, sell 1 unit at price 1182.170044, investment 1.325101 %, total balance 6175.039795,
# day 60, sell 1 unit at price 1147.949951, investment -2.182258 %, total balance 7322.989746,
# day 62, sell 1 unit at price 1145.869995, investment -2.130155 %, total balance 8468.859741,
# day 64: buy 1 unit at price 1103.250000, total balance 7365.609741
# day 65: buy 1 unit at price 1151.439941, total balance 6214.169800
# day 66, sell 1 unit at price 1128.430054, investment -1.000141 %, total balance 7342.599854,
# day 68, sell 1 unit at price 1168.380005, investment 5.903467 %, total balance 8510.979859,
# day 69: buy 1 unit at price 1165.890015, total balance 7345.089844
# day 72: buy 1 unit at price 1191.810059, total balance 6153.279785
# day 73: buy 1 unit at price 1238.160034, total balance 4915.119751
# day 75, sell 1 unit at price 1242.979980, investment 7.950049 %, total balance 6158.099731,
# day 77: buy 1 unit at price 1209.469971, total balance 4948.629760
# day 78: buy 1 unit at price 1228.750000, total balance 3719.879760
# day 79, sell 1 unit at price 1234.520020, investment 5.886491 %, total balance 4954.399780,
# day 80: buy 1 unit at price 1253.050049, total balance 3701.349731
# day 81, sell 1 unit at price 1249.459961, investment 4.837172 %, total balance 4950.809692,
# day 82: buy 1 unit at price 1266.439941, total balance 3684.369751
# day 84, sell 1 unit at price 1248.579956, investment 0.841565 %, total balance 4932.949707,
# day 85: buy 1 unit at price 1266.609985, total balance 3666.339722
# day 86: buy 1 unit at price 1263.510010, total balance 2402.829712
# day 88, sell 1 unit at price 1255.540039, investment 3.809112 %, total balance 3658.369751,
# day 90, sell 1 unit at price 1245.670044, investment 1.377013 %, total balance 4904.039795,
# day 91: buy 1 unit at price 1248.920044, total balance 3655.119751
# day 93: buy 1 unit at price 1284.989990, total balance 2370.129761
# day 94, sell 1 unit at price 1288.489990, investment 2.828294 %, total balance 3658.619751,
# day 96, sell 1 unit at price 1312.829956, investment 3.663025 %, total balance 4971.449707,
# day 97, sell 1 unit at price 1309.380005, investment 3.376732 %, total balance 6280.829712,
# day 99, sell 1 unit at price 1293.170044, investment 2.347432 %, total balance 7573.999756,
# day 100: buy 1 unit at price 1277.890015, total balance 6296.109741
# day 101, sell 1 unit at price 1267.930054, investment 1.522116 %, total balance 7564.039795,
# day 102, sell 1 unit at price 1248.079956, investment -2.872399 %, total balance 8812.119751,
# day 103: buy 1 unit at price 1255.819946, total balance 7556.299805
# day 104: buy 1 unit at price 1260.670044, total balance 6295.629761
# day 107: buy 1 unit at price 1270.030029, total balance 5025.599732
# day 109, sell 1 unit at price 1264.959961, investment -1.011828 %, total balance 6290.559693,
# day 111, sell 1 unit at price 1255.849976, investment 0.002391 %, total balance 7546.409669,
# day 113, sell 1 unit at price 1219.869995, investment -3.236378 %, total balance 8766.279664,
# day 114: buy 1 unit at price 1214.359985, total balance 7551.919679
# day 116: buy 1 unit at price 1212.579956, total balance 6339.339723
# day 117: buy 1 unit at price 1223.140015, total balance 5116.199708
# day 118: buy 1 unit at price 1237.040039, total balance 3879.159669
# day 120, sell 1 unit at price 1218.599976, investment -4.049515 %, total balance 5097.759645,
# day 122, sell 1 unit at price 1211.069946, investment -0.270928 %, total balance 6308.829591,
# day 126: buy 1 unit at price 1234.449951, total balance 5074.379640
# day 128, sell 1 unit at price 1190.589966, investment -1.813488 %, total balance 6264.969606,
# day 129: buy 1 unit at price 1198.780029, total balance 5066.189577
# day 130: buy 1 unit at price 1181.520020, total balance 3884.669557
# day 131: buy 1 unit at price 1180.180054, total balance 2704.489503
# day 132, sell 1 unit at price 1208.140015, investment -1.226352 %, total balance 3912.629518,
# day 133, sell 1 unit at price 1215.680054, investment -1.726701 %, total balance 5128.309572,
# day 134, sell 1 unit at price 1202.449951, investment -2.592248 %, total balance 6330.759523,
# day 135, sell 1 unit at price 1214.439941, investment 1.306321 %, total balance 7545.199464,
# day 137: buy 1 unit at price 1215.020020, total balance 6330.179444
# day 139, sell 1 unit at price 1191.030029, investment 0.804896 %, total balance 7521.209473,
# day 140: buy 1 unit at price 1171.650024, total balance 6349.559449
# day 141: buy 1 unit at price 1190.489990, total balance 5159.069459
# day 143: buy 1 unit at price 1205.819946, total balance 3953.249513
# day 145: buy 1 unit at price 1211.229980, total balance 2742.019533
# day 146, sell 1 unit at price 1215.930054, investment 3.029199 %, total balance 3957.949587,
# day 147, sell 1 unit at price 1220.750000, investment 0.471596 %, total balance 5178.699587,
# day 149, sell 1 unit at price 1200.479980, investment 2.460629 %, total balance 6379.179567,
# day 150: buy 1 unit at price 1204.400024, total balance 5174.779543
# day 153: buy 1 unit at price 1190.160034, total balance 3984.619509
# day 154: buy 1 unit at price 1191.290039, total balance 2793.329470
# day 155, sell 1 unit at price 1186.729980, investment -0.315837 %, total balance 3980.059450,
# day 156: buy 1 unit at price 1178.020020, total balance 2802.039430
# day 158: buy 1 unit at price 1161.969971, total balance 1640.069459
# day 160, sell 1 unit at price 1157.260010, investment -4.027130 %, total balance 2797.329469,
# day 161: buy 1 unit at price 1165.310059, total balance 1632.019410
# day 162, sell 1 unit at price 1162.089966, investment -4.057034 %, total balance 2794.109376,
# day 164, sell 1 unit at price 1179.209961, investment -2.091503 %, total balance 3973.319337,
# day 167: buy 1 unit at price 1129.030029, total balance 2844.289308
# day 168: buy 1 unit at price 1133.579956, total balance 1710.709352
# day 169, sell 1 unit at price 1132.939941, investment -4.807765 %, total balance 2843.649293,
# day 171, sell 1 unit at price 1106.400024, investment -7.125890 %, total balance 3950.049317,
# day 173, sell 1 unit at price 1092.540039, investment -7.256242 %, total balance 5042.589356,
# day 175: buy 1 unit at price 1032.739990, total balance 4009.849366
# day 176: buy 1 unit at price 1016.099976, total balance 2993.749390
# day 177: buy 1 unit at price 984.539978, total balance 2009.209412
# day 180, sell 1 unit at price 1012.270020, investment -12.883289 %, total balance 3021.479432,
# day 183: buy 1 unit at price 1040.939941, total balance 1980.539491
# day 187, sell 1 unit at price 1069.630005, investment -8.210695 %, total balance 3050.169496,
# day 189, sell 1 unit at price 1062.439941, investment -5.897991 %, total balance 4112.609437,
# day 190: buy 1 unit at price 1056.750000, total balance 3055.859437
# day 191: buy 1 unit at price 1080.989990, total balance 1974.869447
# day 193: buy 1 unit at price 1091.650024, total balance 883.219423
# day 196, sell 1 unit at price 1077.089966, investment -4.983326 %, total balance 1960.309389,
# day 197: buy 1 unit at price 1068.609985, total balance 891.699404
# day 202, sell 1 unit at price 1100.089966, investment 6.521484 %, total balance 1991.789370,
# day 203: buy 1 unit at price 1104.609985, total balance 887.179385
# day 208, sell 1 unit at price 1087.199951, investment 6.997340 %, total balance 1974.379336,
# day 209, sell 1 unit at price 1102.839966, investment 12.015763 %, total balance 3077.219302,
# day 211, sell 1 unit at price 1115.800049, investment 7.191588 %, total balance 4193.019351,
# day 214: buy 1 unit at price 1118.329956, total balance 3074.689395
# day 215: buy 1 unit at price 1139.089966, total balance 1935.599429
# day 216, sell 1 unit at price 1141.209961, investment 7.992426 %, total balance 3076.809390,
# day 217, sell 1 unit at price 1142.239990, investment 5.666102 %, total balance 4219.049380,
# day 218, sell 1 unit at price 1138.650024, investment 4.305409 %, total balance 5357.699404,
# day 220: buy 1 unit at price 1142.660034, total balance 4215.039370
# day 221: buy 1 unit at price 1137.030029, total balance 3078.009341
# day 222: buy 1 unit at price 1150.339966, total balance 1927.669375
# day 223: buy 1 unit at price 1157.420044, total balance 770.249331
# day 224, sell 1 unit at price 1149.500000, investment 7.569648 %, total balance 1919.749331,
# day 225, sell 1 unit at price 1128.520020, investment 2.164568 %, total balance 3048.269351,
# day 227: buy 1 unit at price 1139.449951, total balance 1908.819400
# day 230: buy 1 unit at price 1170.349976, total balance 738.469424
# day 231, sell 1 unit at price 1167.099976, investment 4.360969 %, total balance 1905.569400,
# day 232, sell 1 unit at price 1158.310059, investment 1.687320 %, total balance 3063.879459,
# day 233, sell 1 unit at price 1139.930054, investment -0.238914 %, total balance 4203.809513,
# day 234: buy 1 unit at price 1136.760010, total balance 3067.049503
# day 236, sell 1 unit at price 1119.380005, investment -1.552292 %, total balance 4186.429508,
# day 237: buy 1 unit at price 1123.089966, total balance 3063.339542
# day 238, sell 1 unit at price 1134.359985, investment -1.389153 %, total balance 4197.699527,
# day 239, sell 1 unit at price 1142.920044, investment -1.252786 %, total balance 5340.619571,
# day 240, sell 1 unit at price 1149.560059, investment 0.887280 %, total balance 6490.179630,
# day 242: buy 1 unit at price 1144.890015, total balance 5345.289615
# day 244: buy 1 unit at price 1149.369995, total balance 4195.919620
# day 245, sell 1 unit at price 1157.130005, investment -1.129574 %, total balance 5353.049625,
# day 246, sell 1 unit at price 1161.020020, investment 2.134136 %, total balance 6514.069645,
# day 247, sell 1 unit at price 1148.079956, investment 2.225110 %, total balance 7662.149601,
# day 250: buy 1 unit at price 1172.510010, total balance 6489.639591
# day 251: buy 1 unit at price 1164.890015, total balance 5324.749576
# day 252: buy 1 unit at price 1160.709961, total balance 4164.039615
# day 253: buy 1 unit at price 1155.140015, total balance 3008.899600
# day 255, sell 1 unit at price 1145.599976, investment 0.062011 %, total balance 4154.499576,
# day 256: buy 1 unit at price 1138.410034, total balance 3016.089542
# day 258, sell 1 unit at price 1127.569946, investment -1.896696 %, total balance 4143.659488,
# day 260, sell 1 unit at price 1127.579956, investment -3.831955 %, total balance 5271.239444,
# day 261: buy 1 unit at price 1119.310059, total balance 4151.929385
# day 262, sell 1 unit at price 1128.180054, investment -3.151367 %, total balance 5280.109439,
# day 264: buy 1 unit at price 1133.280029, total balance 4146.829410
# day 266, sell 1 unit at price 1100.640015, investment -5.175276 %, total balance 5247.469425,
# day 267: buy 1 unit at price 1113.569946, total balance 4133.899479
# day 269, sell 1 unit at price 1122.199951, investment -2.851608 %, total balance 5256.099430,
# day 271, sell 1 unit at price 1090.020020, investment -4.250667 %, total balance 6346.119450,
# day 272: buy 1 unit at price 1083.510010, total balance 5262.609440
# day 273, sell 1 unit at price 1080.170044, investment -3.496798 %, total balance 6342.779484,
# day 275: buy 1 unit at price 1111.939941, total balance 5230.839543
# day 277, sell 1 unit at price 1118.510010, investment -1.303298 %, total balance 6349.349553,
# day 279: buy 1 unit at price 1104.180054, total balance 5245.169499
# day 280: buy 1 unit at price 1083.339966, total balance 4161.829533
# day 282: buy 1 unit at price 1080.949951, total balance 3080.879582
# day 283: buy 1 unit at price 1089.839966, total balance 1991.039616
# day 285, sell 1 unit at price 1109.380005, investment -0.376262 %, total balance 3100.419621,
# day 286, sell 1 unit at price 1109.890015, investment 2.434680 %, total balance 4210.309636,
# day 288: buy 1 unit at price 1131.780029, total balance 3078.529607
# day 289: buy 1 unit at price 1153.839966, total balance 1924.689641
# day 291, sell 1 unit at price 1162.770020, investment 4.571297 %, total balance 3087.459661,
# day 292: buy 1 unit at price 1157.540039, total balance 1929.919622
# day 296: buy 1 unit at price 1154.089966, total balance 775.829656
# day 298, sell 1 unit at price 1166.160034, investment 5.613213 %, total balance 1941.989690,
# day 299: buy 1 unit at price 1165.550049, total balance 776.439641
# day 300, sell 1 unit at price 1170.290039, investment 8.026111 %, total balance 1946.729680,
# day 301, sell 1 unit at price 1151.849976, investment 6.559048 %, total balance 3098.579656,
# day 302: buy 1 unit at price 1153.589966, total balance 1944.989690
# day 303, sell 1 unit at price 1148.699951, investment 5.400792 %, total balance 3093.689641,
# day 304: buy 1 unit at price 1131.869995, total balance 1961.819646
# day 305, sell 1 unit at price 1138.489990, investment 0.592868 %, total balance 3100.309636,
# day 306: buy 1 unit at price 1144.579956, total balance 1955.729680
# day 307, sell 1 unit at price 1147.390015, investment -0.558999 %, total balance 3103.119695,
# day 310: buy 1 unit at price 1125.400024, total balance 1977.719671
# day 312, sell 1 unit at price 1122.729980, investment -3.007244 %, total balance 3100.449651,
# day 313: buy 1 unit at price 1125.290039, total balance 1975.159612
# day 314, sell 1 unit at price 1117.800049, investment -3.144462 %, total balance 3092.959661,
# day 315: buy 1 unit at price 1130.469971, total balance 1962.489690
# day 316, sell 1 unit at price 1103.689941, investment -5.307375 %, total balance 3066.179631,
# day 317, sell 1 unit at price 1111.010010, investment -3.691082 %, total balance 4177.189641,
# day 318: buy 1 unit at price 1102.550049, total balance 3074.639592
# day 319: buy 1 unit at price 1128.369995, total balance 1946.269597
# day 320, sell 1 unit at price 1126.069946, investment -0.512431 %, total balance 3072.339543,
# day 321, sell 1 unit at price 1124.469971, investment -1.756975 %, total balance 4196.809514,
# day 322, sell 1 unit at price 1125.170044, investment -0.020435 %, total balance 5321.979558,
# day 323: buy 1 unit at price 1107.829956, total balance 4214.149602
# day 325, sell 1 unit at price 1093.140015, investment -2.857043 %, total balance 5307.289617,
# day 327: buy 1 unit at price 1076.319946, total balance 4230.969671
# day 329, sell 1 unit at price 1076.920044, investment -4.736961 %, total balance 5307.889715,
# day 331, sell 1 unit at price 1084.560059, investment -1.631671 %, total balance 6392.449774,
# day 332: buy 1 unit at price 1073.430054, total balance 5319.019720
# day 334: buy 1 unit at price 1049.489990, total balance 4269.529730
# day 336, sell 1 unit at price 1073.010010, investment -4.906191 %, total balance 5342.539740,
# day 338, sell 1 unit at price 1074.560059, investment -3.003159 %, total balance 6417.099799,
# day 342: buy 1 unit at price 1106.589966, total balance 5310.509833
# day 343: buy 1 unit at price 1091.880005, total balance 4218.629828
# day 346: buy 1 unit at price 1097.079956, total balance 3121.549872
# day 347, sell 1 unit at price 1083.819946, investment 0.696819 %, total balance 4205.369818,
# day 348, sell 1 unit at price 1074.550049, investment 0.104338 %, total balance 5279.919867,
# day 349, sell 1 unit at price 1067.660034, investment 1.731321 %, total balance 6347.579901,
# day 350: buy 1 unit at price 1064.660034, total balance 5282.919867
# day 352, sell 1 unit at price 1040.680054, investment -5.956128 %, total balance 6323.599921,
# day 353: buy 1 unit at price 1040.689941, total balance 5282.909980
# day 356: buy 1 unit at price 1027.530029, total balance 4255.379951
# day 358, sell 1 unit at price 1013.599976, investment -7.169289 %, total balance 5268.979927,
# day 359: buy 1 unit at price 1020.260010, total balance 4248.719917
# day 361: buy 1 unit at price 1007.270020, total balance 3241.449897
# day 362: buy 1 unit at price 1036.170044, total balance 2205.279853
# day 363, sell 1 unit at price 1037.140015, investment -5.463589 %, total balance 3242.419868,
# day 364, sell 1 unit at price 1019.989990, investment -4.195710 %, total balance 4262.409858,
# day 367: buy 1 unit at price 992.719971, total balance 3269.689887
# day 368, sell 1 unit at price 976.140015, investment -6.202609 %, total balance 4245.829902,
# day 369: buy 1 unit at price 973.530029, total balance 3272.299873
# day 370: buy 1 unit at price 990.640015, total balance 2281.659858
# day 371: buy 1 unit at price 989.820007, total balance 1291.839851
# day 374: buy 1 unit at price 953.989990, total balance 337.849861
# day 377, sell 1 unit at price 952.830017, investment -7.269862 %, total balance 1290.679878,
# day 378: buy 1 unit at price 920.469971, total balance 370.209907
# day 380, sell 1 unit at price 921.390015, investment -9.690666 %, total balance 1291.599922,
# day 382: buy 1 unit at price 900.940002, total balance 390.659920
# day 385, sell 1 unit at price 847.750000, investment -15.836868 %, total balance 1238.409920,
# day 387: buy 1 unit at price 797.700012, total balance 440.709908
# day 391, sell 1 unit at price 898.960022, investment -13.242037 %, total balance 1339.669930,
# day 393, sell 1 unit at price 911.619995, investment -8.169472 %, total balance 2251.289925,
# day 395: buy 1 unit at price 864.239990, total balance 1387.049935
# day 396: buy 1 unit at price 834.599976, total balance 552.449959
# day 398, sell 1 unit at price 876.770020, investment -9.939088 %, total balance 1429.219979,
# day 399: buy 1 unit at price 905.460022, total balance 523.759957
# day 400, sell 1 unit at price 908.640015, investment -8.277477 %, total balance 1432.399972,
# day 403: buy 1 unit at price 919.619995, total balance 512.779977
# day 407, sell 1 unit at price 937.429993, investment -5.292883 %, total balance 1450.209970,
# day 409, sell 1 unit at price 962.700012, investment 0.913010 %, total balance 2412.909982,
# day 411: buy 1 unit at price 947.950012, total balance 1464.959970
# day 412: buy 1 unit at price 934.820007, total balance 530.139963
# day 415, sell 1 unit at price 916.070007, investment -0.478013 %, total balance 1446.209970,
# day 416, sell 1 unit at price 878.020020, investment -2.544008 %, total balance 2324.229990,
# day 417: buy 1 unit at price 893.400024, total balance 1430.829966
# day 420, sell 1 unit at price 902.960022, investment 13.195438 %, total balance 2333.789988,
# day 421, sell 1 unit at price 909.580017, investment 5.246231 %, total balance 3243.370005,
# day 422, sell 1 unit at price 909.450012, investment 8.968373 %, total balance 4152.820017,
# day 424: buy 1 unit at price 889.809998, total balance 3263.010019
# day 426, sell 1 unit at price 873.520020, investment -3.527489 %, total balance 4136.530039,
# day 427, sell 1 unit at price 869.460022, investment -5.454424 %, total balance 5005.990061,
# day 429: buy 1 unit at price 845.390015, total balance 4160.600046
# day 430: buy 1 unit at price 833.700012, total balance 3326.900034
# day 432: buy 1 unit at price 839.659973, total balance 2487.240061
# day 433: buy 1 unit at price 854.950012, total balance 1632.290049
# day 434, sell 1 unit at price 827.369995, investment -12.720082 %, total balance 2459.660044,
# day 435: buy 1 unit at price 815.280029, total balance 1644.380015
# day 437, sell 1 unit at price 827.909973, investment -11.436430 %, total balance 2472.289988,
# day 440: buy 1 unit at price 785.280029, total balance 1687.009959
# day 444: buy 1 unit at price 835.320007, total balance 851.689952
# day 448, sell 1 unit at price 879.200012, investment -1.589435 %, total balance 1730.889964,
# day 450, sell 1 unit at price 899.719971, investment 1.113718 %, total balance 2630.609935,
# day 451: buy 1 unit at price 890.159973, total balance 1740.449962
# day 453, sell 1 unit at price 882.500000, investment 4.389688 %, total balance 2622.949962,
# day 454: buy 1 unit at price 897.650024, total balance 1725.299938
# day 456: buy 1 unit at price 882.150024, total balance 843.149914
# day 460, sell 1 unit at price 908.349976, investment 8.954056 %, total balance 1751.499890,
# day 461: buy 1 unit at price 915.390015, total balance 836.109875
# day 462, sell 1 unit at price 923.760010, investment 10.015964 %, total balance 1759.869885,
# day 464, sell 1 unit at price 894.739990, investment 4.654071 %, total balance 2654.609875,
# day 465: buy 1 unit at price 876.190002, total balance 1778.419873
# day 466: buy 1 unit at price 882.950012, total balance 895.469861
# day 467, sell 1 unit at price 882.530029, investment 8.248700 %, total balance 1777.999890,
# day 469, sell 1 unit at price 909.830017, investment 15.860583 %, total balance 2687.829907,
# day 470: buy 1 unit at price 900.359985, total balance 1787.469922
# day 471, sell 1 unit at price 896.739990, investment 7.352869 %, total balance 2684.209912,
# day 472, sell 1 unit at price 914.150024, investment 2.695027 %, total balance 3598.359936,
# day 473, sell 1 unit at price 933.760010, investment 4.022724 %, total balance 4532.119946,
# day 474, sell 1 unit at price 930.549988, investment 5.486591 %, total balance 5462.669934,
# day 475: buy 1 unit at price 932.869995, total balance 4529.799939
# day 476, sell 1 unit at price 913.309998, investment -0.227227 %, total balance 5443.109937,
# day 477: buy 1 unit at price 938.869995, total balance 4504.239942
# day 478, sell 1 unit at price 936.309998, investment 6.861525 %, total balance 5440.549940,
# day 479: buy 1 unit at price 934.530029, total balance 4506.019911
# day 480, sell 1 unit at price 920.750000, investment 4.281102 %, total balance 5426.769911,
# day 481: buy 1 unit at price 917.580017, total balance 4509.189894
# day 482, sell 1 unit at price 906.549988, investment 0.687503 %, total balance 5415.739882,
# day 483: buy 1 unit at price 912.229980, total balance 4503.509902
# day 484, sell 1 unit at price 892.000000, investment -4.381103 %, total balance 5395.509902,
# day 485: buy 1 unit at price 904.450012, total balance 4491.059890
# day 487, sell 1 unit at price 901.580017, investment -3.971794 %, total balance 5392.639907,
# day 489, sell 1 unit at price 910.400024, investment -2.582047 %, total balance 6303.039931,
# day 491, sell 1 unit at price 891.119995, investment -2.883675 %, total balance 7194.159926,
# day 493: buy 1 unit at price 895.760010, total balance 6298.399916
# day 495, sell 1 unit at price 892.469971, investment -2.166121 %, total balance 7190.869887,
# day 497, sell 1 unit at price 875.400024, investment -3.211895 %, total balance 8066.269911,
# day 498: buy 1 unit at price 879.390015, total balance 7186.879896
# day 500: buy 1 unit at price 909.030029, total balance 6277.849867
# day 501, sell 1 unit at price 908.590027, investment 1.432305 %, total balance 7186.439894,
# day 503, sell 1 unit at price 922.929993, investment 4.951157 %, total balance 8109.369887,
# day 504: buy 1 unit at price 909.929993, total balance 7199.439894
# day 506, sell 1 unit at price 927.570007, investment 2.039534 %, total balance 8127.009901,
# day 507: buy 1 unit at price 926.260010, total balance 7200.749891
# day 508: buy 1 unit at price 931.659973, total balance 6269.089918
# day 510: buy 1 unit at price 914.599976, total balance 5354.489942
# day 512, sell 1 unit at price 887.619995, investment -2.451837 %, total balance 6242.109937,
# day 513: buy 1 unit at price 878.359985, total balance 5363.749952
# day 514: buy 1 unit at price 887.340027, total balance 4476.409925
# day 515: buy 1 unit at price 861.400024, total balance 3615.009901
# day 516, sell 1 unit at price 847.479980, investment -8.505174 %, total balance 4462.489881,
# day 517, sell 1 unit at price 858.539978, investment -7.848356 %, total balance 5321.029859,
# day 518: buy 1 unit at price 864.359985, total balance 4456.669874
# day 522, sell 1 unit at price 848.200012, investment -7.260001 %, total balance 5304.869886,
# day 523, sell 1 unit at price 843.590027, investment -3.958509 %, total balance 6148.459913,
# day 524, sell 1 unit at price 838.150024, investment -5.543535 %, total balance 6986.609937,
# day 525: buy 1 unit at price 829.690002, total balance 6156.919935
# day 526: buy 1 unit at price 835.969971, total balance 5320.949964
# day 528, sell 1 unit at price 818.679993, investment -4.959372 %, total balance 6139.629957,
# day 529: buy 1 unit at price 817.369995, total balance 5322.259962
# day 531, sell 1 unit at price 851.169983, investment -1.525985 %, total balance 6173.429945,
# day 534: buy 1 unit at price 848.169983, total balance 5325.259962
# day 535: buy 1 unit at price 832.580017, total balance 4492.679945
# day 537, sell 1 unit at price 827.549988, investment -0.257929 %, total balance 5320.229933,
# day 538: buy 1 unit at price 837.280029, total balance 4482.949904
# day 539: buy 1 unit at price 841.150024, total balance 3641.799880
# day 541, sell 1 unit at price 821.989990, investment -1.672307 %, total balance 4463.789870,
# day 542: buy 1 unit at price 829.849976, total balance 3633.939894
# day 543: buy 1 unit at price 822.099976, total balance 2811.839918
# day 544: buy 1 unit at price 828.890015, total balance 1982.949903
# day 546: buy 1 unit at price 800.729980, total balance 1182.219923
# day 547: buy 1 unit at price 804.190002, total balance 378.029921
# day 554, sell 1 unit at price 895.789978, investment 9.594184 %, total balance 1273.819899,
# day 555: buy 1 unit at price 864.229980, total balance 409.589919
# day 557, sell 1 unit at price 869.950012, investment 2.567885 %, total balance 1279.539931,
# day 558: buy 1 unit at price 868.520020, total balance 411.019911
# day 559, sell 1 unit at price 863.500000, investment 3.713755 %, total balance 1274.519911,
# day 560, sell 1 unit at price 848.179993, investment 1.301830 %, total balance 2122.699904,
# day 561: buy 1 unit at price 858.479980, total balance 1264.219924
# day 562: buy 1 unit at price 880.900024, total balance 383.319900
# day 564, sell 1 unit at price 878.849976, investment 4.481953 %, total balance 1262.169876,
# day 565: buy 1 unit at price 879.929993, total balance 382.239883
# day 566, sell 1 unit at price 878.289978, investment 5.837200 %, total balance 1260.529861,
# day 568, sell 1 unit at price 871.580017, investment 6.018738 %, total balance 2132.109878,
# day 569: buy 1 unit at price 868.299988, total balance 1263.809890
# day 571, sell 1 unit at price 890.809998, investment 7.470229 %, total balance 2154.619888,
# day 573: buy 1 unit at price 893.580017, total balance 1261.039871
# day 574: buy 1 unit at price 892.010010, total balance 369.029861
# day 576, sell 1 unit at price 919.020020, investment 14.772775 %, total balance 1288.049881,
# day 577, sell 1 unit at price 911.429993, investment 13.335156 %, total balance 2199.479874,
# day 578, sell 1 unit at price 898.809998, investment 4.001252 %, total balance 3098.289872,
# day 579: buy 1 unit at price 914.840027, total balance 2183.449845
# day 580, sell 1 unit at price 917.840027, investment 5.678626 %, total balance 3101.289872,
# day 582, sell 1 unit at price 916.299988, investment 6.735161 %, total balance 4017.589860,
# day 583: buy 1 unit at price 930.080017, total balance 3087.509843
# day 585, sell 1 unit at price 934.390015, investment 6.072198 %, total balance 4021.899858,
# day 587: buy 1 unit at price 920.270020, total balance 3101.629838
# day 588: buy 1 unit at price 933.409973, total balance 2168.219865
# day 589, sell 1 unit at price 945.109985, investment 7.407407 %, total balance 3113.329850,
# day 591, sell 1 unit at price 939.280029, investment 8.174599 %, total balance 4052.609879,
# day 593, sell 1 unit at price 944.299988, investment 5.676041 %, total balance 4996.909867,
# day 595: buy 1 unit at price 919.729980, total balance 4077.179887
# day 596: buy 1 unit at price 923.419983, total balance 3153.759904
# day 597: buy 1 unit at price 931.869995, total balance 2221.889909
# day 598, sell 1 unit at price 933.219971, investment 4.619899 %, total balance 3155.109880,
# day 599, sell 1 unit at price 951.479980, investment 4.005067 %, total balance 4106.589860,
# day 600: buy 1 unit at price 953.219971, total balance 3153.369889
# day 602, sell 1 unit at price 963.590027, investment 3.602917 %, total balance 4116.959916,
# day 603, sell 1 unit at price 967.000000, investment 5.077855 %, total balance 5083.959916,
# day 604: buy 1 unit at price 971.559998, total balance 4112.399918
# day 605, sell 1 unit at price 986.239990, investment 5.659894 %, total balance 5098.639908,
# day 606, sell 1 unit at price 990.140015, investment 7.655512 %, total balance 6088.779923,
# day 607, sell 1 unit at price 987.760010, investment 6.967580 %, total balance 7076.539933,
# day 608, sell 1 unit at price 975.929993, investment 4.728127 %, total balance 8052.469926,
# day 609, sell 1 unit at price 984.840027, investment 3.317184 %, total balance 9037.309953,
# day 610: buy 1 unit at price 997.479980, total balance 8039.829973
# day 611, sell 1 unit at price 998.510010, investment 2.773891 %, total balance 9038.339983,
# day 612, sell 1 unit at price 988.609985, investment -0.889240 %, total balance 10026.949968,
# day 613: buy 1 unit at price 1010.739990, total balance 9016.209978
# day 614, sell 1 unit at price 1011.659973, investment 0.091021 %, total balance 10027.869951,
# day 617: buy 1 unit at price 995.690002, total balance 9032.179949
# day 618: buy 1 unit at price 981.640015, total balance 8050.539934
# day 619, sell 1 unit at price 983.450012, investment -1.229297 %, total balance 9033.989946,
# day 620, sell 1 unit at price 975.320007, investment -0.643821 %, total balance 10009.309953,
# day 621: buy 1 unit at price 985.820007, total balance 9023.489946
# day 622, sell 1 unit at price 976.219971, investment -0.973812 %, total balance 9999.709917,
# day 625: buy 1 unit at price 993.750000, total balance 9005.959917
# day 627, sell 1 unit at price 1004.419983, investment 1.073709 %, total balance 10010.379900,
# day 631: buy 1 unit at price 998.140015, total balance 9012.239885
# day 632: buy 1 unit at price 1003.859985, total balance 8008.379900
# day 633, sell 1 unit at price 1000.419983, investment 0.228422 %, total balance 9008.799883,
# day 634, sell 1 unit at price 994.090027, investment -0.973239 %, total balance 10002.889910,
# day 635: buy 1 unit at price 981.729980, total balance 9021.159930
# day 636: buy 1 unit at price 993.320007, total balance 8027.839923
# day 637, sell 1 unit at price 978.799988, investment -0.298452 %, total balance 9006.639911,
# day 639, sell 1 unit at price 988.609985, investment -0.474170 %, total balance 9995.249896,
# day 640: buy 1 unit at price 981.599976, total balance 9013.649920
# day 642, sell 1 unit at price 996.520020, investment 1.519972 %, total balance 10010.169940,
# day 644: buy 1 unit at price 987.489990, total balance 9022.679950
# day 646: buy 1 unit at price 980.150024, total balance 8042.529926
# day 648, sell 1 unit at price 965.460022, investment -2.230905 %, total balance 9007.989948,
# day 649: buy 1 unit at price 967.080017, total balance 8040.909931
# day 650, sell 1 unit at price 974.119995, investment -0.615215 %, total balance 9015.029926,
# day 653: buy 1 unit at price 990.349976, total balance 8024.679950
# day 654, sell 1 unit at price 984.030029, investment 1.752700 %, total balance 9008.709979,
# day 655, sell 1 unit at price 990.510010, investment 0.016159 %, total balance 9999.219989,
# day 657: buy 1 unit at price 999.739990, total balance 8999.479999
# day 659, sell 1 unit at price 1000.299988, investment 0.056014 %, total balance 9999.779987,
# day 662: buy 1 unit at price 993.710022, total balance 9006.069965
# day 663: buy 1 unit at price 996.729980, total balance 8009.339985
# day 665: buy 1 unit at price 1002.840027, total balance 7006.499958
# day 667, sell 1 unit at price 1021.989990, investment 2.845897 %, total balance 8028.489948,
# day 668, sell 1 unit at price 1026.270020, investment 2.963695 %, total balance 9054.759968,
# day 670, sell 1 unit at price 1021.390015, investment 1.849745 %, total balance 10076.149983,
# day 671: buy 1 unit at price 1031.640015, total balance 9044.509968
# day 672, sell 1 unit at price 1023.169983, investment -0.821026 %, total balance 10067.679951,
# day 675: buy 1 unit at price 1018.630005, total balance 9049.049946
# day 676, sell 1 unit at price 1014.809998, investment -0.375014 %, total balance 10063.859944,
# day 679: buy 1 unit at price 1039.579956, total balance 9024.279988
# day 680, sell 1 unit at price 1036.300049, investment -0.315503 %, total balance 10060.580037,
# day 682: buy 1 unit at price 1029.030029, total balance 9031.550008
# day 683, sell 1 unit at price 1009.380005, investment -1.909568 %, total balance 10040.930013,
# day 686: buy 1 unit at price 1006.580017, total balance 9034.349996
# day 687, sell 1 unit at price 995.969971, investment -1.054069 %, total balance 10030.319967,
# day 690: buy 1 unit at price 1029.849976, total balance 9000.469991
# day 691, sell 1 unit at price 1034.349976, investment 0.436957 %, total balance 10034.819967,
# day 692: buy 1 unit at price 1039.250000, total balance 8995.569967
# day 694, sell 1 unit at price 1038.729980, investment -0.050038 %, total balance 10034.299947,
# day 701: buy 1 unit at price 1044.680054, total balance 8989.619893
# day 702, sell 1 unit at price 1046.030029, investment 0.129224 %, total balance 10035.649922,
# day 703: buy 1 unit at price 1030.359985, total balance 9005.289937
# day 704: buy 1 unit at price 1033.770020, total balance 7971.519917
# day 705, sell 1 unit at price 1028.910034, investment -0.140723 %, total balance 9000.429951,
# day 706, sell 1 unit at price 1031.130005, investment -0.255377 %, total balance 10031.559956,
# day 709: buy 1 unit at price 1046.939941, total balance 8984.620015
# day 711, sell 1 unit at price 1059.020020, investment 1.153846 %, total balance 10043.640035,
# day 712: buy 1 unit at price 1053.250000, total balance 8990.390035
# day 714, sell 1 unit at price 1058.050049, investment 0.455737 %, total balance 10048.440084,
# day 715: buy 1 unit at price 1053.209961, total balance 8995.230123
# day 717, sell 1 unit at price 1046.569946, investment -0.630455 %, total balance 10041.800069,
# day 718: buy 1 unit at price 1058.530029, total balance 8983.270040
# day 719: buy 1 unit at price 1058.410034, total balance 7924.860006
# day 720, sell 1 unit at price 1050.349976, investment -0.772775 %, total balance 8975.209982,
# day 721, sell 1 unit at price 1043.630005, investment -1.396437 %, total balance 10018.839987,
# day 722: buy 1 unit at price 1034.150024, total balance 8984.689963
# day 723: buy 1 unit at price 1042.439941, total balance 7942.250022
# day 724, sell 1 unit at price 1033.650024, investment -0.048349 %, total balance 8975.900046,
# day 725, sell 1 unit at price 1035.280029, investment -0.686842 %, total balance 10011.180075,
# day 726: buy 1 unit at price 1052.079956, total balance 8959.100119
# day 728, sell 1 unit at price 1058.449951, investment 0.605467 %, total balance 10017.550070,
# day 731: buy 1 unit at price 1066.619995, total balance 8950.930075
# day 733, sell 1 unit at price 1069.719971, investment 0.290635 %, total balance 10020.650046,
# day 734: buy 1 unit at price 1061.500000, total balance 8959.150046
# day 735, sell 1 unit at price 1069.300049, investment 0.734814 %, total balance 10028.450095,
# day 738: buy 1 unit at price 1071.209961, total balance 8957.240134
# day 740, sell 1 unit at price 1068.040039, investment -0.295920 %, total balance 10025.280173,
# day 741: buy 1 unit at price 1075.130005, total balance 8950.150168
# day 742, sell 1 unit at price 1076.479980, investment 0.125564 %, total balance 10026.630148,
# day 743: buy 1 unit at price 1089.180054, total balance 8937.450094
# day 747, sell 1 unit at price 1094.040039, investment 0.446206 %, total balance 10031.490133,
# day 750: buy 1 unit at price 1109.640015, total balance 8921.850118
# day 751: buy 1 unit at price 1111.920044, total balance 7809.930074
# day 752, sell 1 unit at price 1108.479980, investment -0.104542 %, total balance 8918.410054,
# day 753: buy 1 unit at price 1122.219971, total balance 7796.190083
# day 755, sell 1 unit at price 1126.329956, investment 1.295949 %, total balance 8922.520039,
# day 756, sell 1 unit at price 1131.920044, investment 0.864365 %, total balance 10054.440083,
# day 760: buy 1 unit at price 1130.520020, total balance 8923.920063
# day 761, sell 1 unit at price 1132.050049, investment 0.135339 %, total balance 10055.970112,
# day 762: buy 1 unit at price 1139.829956, total balance 8916.140156
# day 763, sell 1 unit at price 1138.770020, investment -0.092991 %, total balance 10054.910176,
# day 764: buy 1 unit at price 1147.619995, total balance 8907.290181
# day 765, sell 1 unit at price 1143.939941, investment -0.320668 %, total balance 10051.230122,
# day 766: buy 1 unit at price 1141.550049, total balance 8909.680073
# day 767, sell 1 unit at price 1155.369995, investment 1.210630 %, total balance 10065.050068,
# day 771: buy 1 unit at price 1131.130005, total balance 8933.920063
# day 772, sell 1 unit at price 1135.260010, investment 0.365122 %, total balance 10069.180073,
# day 775: buy 1 unit at price 1128.589966, total balance 8940.590107
# day 776, sell 1 unit at price 1142.760010, investment 1.255553 %, total balance 10083.350117,
# day 778: buy 1 unit at price 1145.540039, total balance 8937.810078
# day 779, sell 1 unit at price 1157.760010, investment 1.066743 %, total balance 10095.570088,
# day 783: buy 1 unit at price 1151.819946, total balance 8943.750142
# day 784, sell 1 unit at price 1147.060059, investment -0.413249 %, total balance 10090.810201,
# day 785: buy 1 unit at price 1144.109985, total balance 8946.700216
# day 787: buy 1 unit at price 1139.089966, total balance 7807.610250
# day 788, sell 1 unit at price 1143.670044, investment -0.038453 %, total balance 8951.280294,
# day 789, sell 1 unit at price 1144.910034, investment 0.510940 %, total balance 10096.190328,
# day 791: buy 1 unit at price 1155.969971, total balance 8940.220357
# day 793, sell 1 unit at price 1151.030029, investment -0.427342 %, total balance 10091.250386,
# day 797: buy 1 unit at price 1140.579956, total balance 8950.670430
# day 799: buy 1 unit at price 1106.780029, total balance 7843.890401
# day 800: buy 1 unit at price 1120.569946, total balance 6723.320455
# day 801, sell 1 unit at price 1104.489990, investment -3.164177 %, total balance 7827.810445,
# day 802: buy 1 unit at price 1110.699951, total balance 6717.110494
# day 803: buy 1 unit at price 1123.750000, total balance 5593.360494
# day 805, sell 1 unit at price 1109.780029, investment 0.271057 %, total balance 6703.140523,
# day 808: buy 1 unit at price 1091.329956, total balance 5611.810567
# day 810, sell 1 unit at price 1108.060059, investment -1.116386 %, total balance 6719.870626,
# day 811: buy 1 unit at price 1122.469971, total balance 5597.400655
# day 812, sell 1 unit at price 1127.000000, investment 1.467547 %, total balance 6724.400655,
# day 814, sell 1 unit at price 1132.170044, investment 0.749281 %, total balance 7856.570699,
# day 815: buy 1 unit at price 1141.810059, total balance 6714.760640
# day 817, sell 1 unit at price 1148.160034, investment 5.207415 %, total balance 7862.920674,
# day 818, sell 1 unit at price 1140.530029, investment 1.608957 %, total balance 9003.450703,
# day 819, sell 1 unit at price 1139.319946, investment -0.218085 %, total balance 10142.770649,
# day 820: buy 1 unit at price 1145.199951, total balance 8997.570698
# day 821, sell 1 unit at price 1129.439941, investment -1.376180 %, total balance 10127.010639,
# day 824: buy 1 unit at price 1134.609985, total balance 8992.400654
# day 825, sell 1 unit at price 1135.819946, investment 0.106641 %, total balance 10128.220600,
# day 827: buy 1 unit at price 1124.089966, total balance 9004.130634
# day 832, sell 1 unit at price 1122.410034, investment -0.149448 %, total balance 10126.540668,
# day 835: buy 1 unit at price 1117.489990, total balance 9009.050678
# day 836: buy 1 unit at price 1119.550049, total balance 7889.500629
# day 837, sell 1 unit at price 1121.530029, investment 0.361528 %, total balance 9011.030658,
# day 838, sell 1 unit at price 1113.989990, investment -0.496633 %, total balance 10125.020648,
# day 840: buy 1 unit at price 1087.119995, total balance 9037.900653
# day 841: buy 1 unit at price 1095.449951, total balance 7942.450702
# day 843, sell 1 unit at price 1096.439941, investment 0.857306 %, total balance 9038.890643,
# day 845, sell 1 unit at price 1084.099976, investment -1.036102 %, total balance 10122.990619,
# day 849: buy 1 unit at price 1093.560059, total balance 9029.430560
# day 851, sell 1 unit at price 1113.050049, investment 1.782251 %, total balance 10142.480609,
# day 856: buy 1 unit at price 1124.989990, total balance 9017.490619
# day 858, sell 1 unit at price 1122.500000, investment -0.221334 %, total balance 10139.990619,
# day 859: buy 1 unit at price 1140.420044, total balance 8999.570575
# day 860, sell 1 unit at price 1142.180054, investment 0.154330 %, total balance 10141.750629,
# day 862: buy 1 unit at price 1136.469971, total balance 9005.280658
# day 863, sell 1 unit at price 1125.290039, investment -0.983742 %, total balance 10130.570697,
# day 864: buy 1 unit at price 1132.010010, total balance 8998.560687
# day 865, sell 1 unit at price 1133.560059, investment 0.136929 %, total balance 10132.120746,
# day 866: buy 1 unit at price 1132.050049, total balance 9000.070697
# day 867: buy 1 unit at price 1135.020020, total balance 7865.050677
# day 870, sell 1 unit at price 1144.060059, investment 1.060908 %, total balance 9009.110736,
# day 872: buy 1 unit at price 1134.430054, total balance 7874.680682
# day 873: buy 1 unit at price 1133.349976, total balance 6741.330706
# day 874, sell 1 unit at price 1136.199951, investment 0.103957 %, total balance 7877.530657,
# day 876, sell 1 unit at price 1128.939941, investment -0.483953 %, total balance 9006.470598,
# day 877: buy 1 unit at price 1125.380005, total balance 7881.090593
# day 878, sell 1 unit at price 1116.209961, investment -1.512332 %, total balance 8997.300554,
# day 880: buy 1 unit at price 1109.109985, total balance 7888.190569
# day 881: buy 1 unit at price 1112.810059, total balance 6775.380510
# day 882, sell 1 unit at price 1114.349976, investment -0.980116 %, total balance 7889.730486,
# day 883: buy 1 unit at price 1115.140015, total balance 6774.590471
# day 885: buy 1 unit at price 1106.689941, total balance 5667.900530
# day 887, sell 1 unit at price 1100.900024, investment -0.740230 %, total balance 6768.800554,
# day 889, sell 1 unit at price 1093.880005, investment -1.701104 %, total balance 7862.680559,
# day 891, sell 1 unit at price 1086.199951, investment -2.595196 %, total balance 8948.880510,
# day 893, sell 1 unit at price 1094.829956, investment -1.071663 %, total balance 10043.710466,
# day 895: buy 1 unit at price 1100.430054, total balance 8943.280412
# day 896: buy 1 unit at price 1101.719971, total balance 7841.560441
# day 898, sell 1 unit at price 1099.689941, investment -0.067257 %, total balance 8941.250382,
# day 900, sell 1 unit at price 1080.699951, investment -1.907928 %, total balance 10021.950333,
# day 901: buy 1 unit at price 1063.969971, total balance 8957.980362
# day 902, sell 1 unit at price 1065.219971, investment 0.117485 %, total balance 10023.200333,
# day 903: buy 1 unit at price 1079.040039, total balance 8944.160294
# day 904, sell 1 unit at price 1075.790039, investment -0.301194 %, total balance 10019.950333,
# day 907: buy 1 unit at price 1079.339966, total balance 8940.610367
# day 910, sell 1 unit at price 1091.229980, investment 1.101600 %, total balance 10031.840347,
# day 911: buy 1 unit at price 1098.349976, total balance 8933.490371
# day 914: buy 1 unit at price 1104.959961, total balance 7828.530410
# day 915: buy 1 unit at price 1105.089966, total balance 6723.440444
# day 916, sell 1 unit at price 1107.770020, investment 0.857654 %, total balance 7831.210464,
# day 917: buy 1 unit at price 1099.150024, total balance 6732.060440
# day 919: buy 1 unit at price 1105.910034, total balance 5626.150406
# day 920: buy 1 unit at price 1118.310059, total balance 4507.840347
# day 921, sell 1 unit at price 1113.630005, investment 0.784648 %, total balance 5621.470352,
# day 922: buy 1 unit at price 1121.300049, total balance 4500.170303
# day 923, sell 1 unit at price 1116.270020, investment 1.011687 %, total balance 5616.440323,
# day 924: buy 1 unit at price 1118.380005, total balance 4498.060318
# day 925, sell 1 unit at price 1123.920044, investment 2.253561 %, total balance 5621.980362,
# day 926, sell 1 unit at price 1125.819946, investment 1.800319 %, total balance 6747.800308,
# day 928: buy 1 unit at price 1120.369995, total balance 5627.430313
# day 930, sell 1 unit at price 1128.550049, investment 0.915666 %, total balance 6755.980362,
# day 932, sell 1 unit at price 1129.300049, investment 0.713458 %, total balance 7885.280411,
# day 933: buy 1 unit at price 1113.560059, total balance 6771.720352
# day 934: buy 1 unit at price 1108.359985, total balance 5663.360367
# day 935: buy 1 unit at price 1110.109985, total balance 4553.250382
# ...
# day 3499, sell 1 unit at price 2053.439941, investment 2.054568 %, total balance 10167.981283,
# day 3500: buy 1 unit at price 2066.550049, total balance 8101.431234
# day 3501, sell 1 unit at price 2074.330078, investment 2.087190 %, total balance 10175.761312,
# day 3502, sell 1 unit at price 2071.919922, investment 1.580634 %, total balance 12247.681234,
# day 3503, sell 1 unit at price 2075.370117, investment 1.821176 %, total balance 14323.051351,
# day 3505: buy 1 unit at price 2059.820068, total balance 12263.231283
# day 3506, sell 1 unit at price 2026.140015, investment -1.250611 %, total balance 14289.371298,
# day 3507: buy 1 unit at price 2035.329956, total balance 12254.041342
# day 3508, sell 1 unit at price 2002.329956, investment -3.107599 %, total balance 14256.371298,
# day 3509: buy 1 unit at price 1989.630005, total balance 12266.741293
# day 3510, sell 1 unit at price 1972.739990, investment -4.227558 %, total balance 14239.481283,
# day 3511: buy 1 unit at price 2012.890015, total balance 12226.591268
# day 3512, sell 1 unit at price 2061.229980, investment 1.272522 %, total balance 14287.821248,
# day 3515: buy 1 unit at price 2082.169922, total balance 12205.651326
# day 3517, sell 1 unit at price 2088.770020, investment 4.982837 %, total balance 14294.421346,
# day 3519, sell 1 unit at price 2080.350098, investment 3.351404 %, total balance 16374.771444,
# day 3520: buy 1 unit at price 2058.899902, total balance 14315.871542
# day 3521, sell 1 unit at price 2058.199951, investment -1.151201 %, total balance 16374.071493,
# day 3522: buy 1 unit at price 2020.579956, total balance 14353.491537
# day 3523: buy 1 unit at price 2002.609985, total balance 12350.881552
# day 3524: buy 1 unit at price 2025.900024, total balance 10324.981528
# day 3525: buy 1 unit at price 2062.139893, total balance 8262.841635
# day 3526, sell 1 unit at price 2044.810059, investment -0.684338 %, total balance 10307.651694,
# day 3528, sell 1 unit at price 2023.030029, investment 0.121256 %, total balance 12330.681723,
# day 3529: buy 1 unit at price 2011.270020, total balance 10319.411703
# day 3532: buy 1 unit at price 2022.550049, total balance 8296.861654
# day 3533: buy 1 unit at price 2032.119995, total balance 6264.741659
# day 3535, sell 1 unit at price 2051.820068, investment 2.457297 %, total balance 8316.561727,
# day 3536: buy 1 unit at price 2057.090088, total balance 6259.471639
# day 3538: buy 1 unit at price 2002.160034, total balance 4257.311605
# day 3539: buy 1 unit at price 2021.250000, total balance 2236.061605
# day 3540, sell 1 unit at price 1994.989990, investment -1.525743 %, total balance 4231.051595,
# day 3541, sell 1 unit at price 2020.849976, investment -2.002285 %, total balance 6251.901571,
# day 3542, sell 1 unit at price 2050.030029, investment 1.927141 %, total balance 8301.931600,
# day 3546: buy 1 unit at price 2046.739990, total balance 6255.191610
# day 3547: buy 1 unit at price 2068.590088, total balance 4186.601522
# day 3548, sell 1 unit at price 2068.530029, investment 2.273367 %, total balance 6255.131551,
# day 3549: buy 1 unit at price 2088.479980, total balance 4166.651571
# day 3551, sell 1 unit at price 2100.340088, investment 3.357090 %, total balance 6266.991659,
# day 3554: buy 1 unit at price 2110.300049, total balance 4156.691610
# day 3555: buy 1 unit at price 2109.659912, total balance 2047.031698
# day 3558, sell 1 unit at price 2110.739990, investment 2.608048 %, total balance 4157.771688,
# day 3559, sell 1 unit at price 2104.500000, investment 5.111478 %, total balance 6262.271688,
# day 3560: buy 1 unit at price 2117.389893, total balance 4144.881795
# day 3562: buy 1 unit at price 2098.530029, total balance 2046.351766
# day 3564, sell 1 unit at price 2071.260010, investment 2.474212 %, total balance 4117.611776,
# day 3565: buy 1 unit at price 2079.429932, total balance 2038.181844
# day 3566, sell 1 unit at price 2044.160034, investment -0.126052 %, total balance 4082.341878,
# day 3568: buy 1 unit at price 2065.949951, total balance 2016.391927
# day 3570, sell 1 unit at price 2081.189941, investment 0.609103 %, total balance 4097.581868,
# day 3571, sell 1 unit at price 2074.280029, investment -0.679918 %, total balance 6171.861897,
# day 3573, sell 1 unit at price 2089.270020, investment -0.996542 %, total balance 8261.131917,
# day 3575, sell 1 unit at price 2104.419922, investment -0.248381 %, total balance 10365.551839,
# day 3576: buy 1 unit at price 2091.500000, total balance 8274.051839
# day 3577, sell 1 unit at price 2061.050049, investment -2.660816 %, total balance 10335.101888,
# day 3578: buy 1 unit at price 2056.149902, total balance 8278.951986
# day 3580: buy 1 unit at price 2086.239990, total balance 6192.711996
# day 3582, sell 1 unit at price 2059.689941, investment -1.850824 %, total balance 8252.401937,
# day 3583: buy 1 unit at price 2066.959961, total balance 6185.441976
# day 3584, sell 1 unit at price 2080.620117, investment 0.057236 %, total balance 8266.062093,
# day 3586, sell 1 unit at price 2081.899902, investment 0.772040 %, total balance 10347.961995,
# day 3588, sell 1 unit at price 2102.060059, investment 0.504904 %, total balance 12450.022054,
# day 3592: buy 1 unit at price 2104.989990, total balance 10345.032064
# day 3594: buy 1 unit at price 2100.399902, total balance 8244.632162
# day 3595: buy 1 unit at price 2097.290039, total balance 6147.342123
# day 3596, sell 1 unit at price 2107.959961, investment 2.519761 %, total balance 8255.302084,
# day 3597, sell 1 unit at price 2112.929932, investment 1.279332 %, total balance 10368.232016,
# day 3598, sell 1 unit at price 2117.689941, investment 2.454328 %, total balance 12485.921957,
# day 3599: buy 1 unit at price 2108.919922, total balance 10377.002035
# day 3601, sell 1 unit at price 2106.850098, investment 0.088367 %, total balance 12483.852133,
# day 3602, sell 1 unit at price 2085.510010, investment -0.708907 %, total balance 14569.362143,
# day 3603: buy 1 unit at price 2108.290039, total balance 12461.072104
# day 3604, sell 1 unit at price 2114.489990, investment 0.820104 %, total balance 14575.562094,
# day 3605: buy 1 unit at price 2089.459961, total balance 12486.102133
# day 3606, sell 1 unit at price 2080.149902, investment -1.364206 %, total balance 14566.252035,
# day 3608: buy 1 unit at price 2116.100098, total balance 12450.151937
# day 3609: buy 1 unit at price 2105.330078, total balance 10344.821859
# day 3611: buy 1 unit at price 2098.479980, total balance 8246.341879
# day 3612: buy 1 unit at price 2121.100098, total balance 6125.241781
# day 3613, sell 1 unit at price 2122.729980, investment 0.684912 %, total balance 8247.971761,
# day 3615, sell 1 unit at price 2127.830078, investment 1.836365 %, total balance 10375.801839,
# day 3616: buy 1 unit at price 2125.850098, total balance 8249.951741
# day 3617, sell 1 unit at price 2130.820068, investment 0.695618 %, total balance 10380.771809,
# day 3618, sell 1 unit at price 2126.060059, investment 0.984643 %, total balance 12506.831868,
# day 3619: buy 1 unit at price 2104.199951, total balance 10402.631917
# day 3620: buy 1 unit at price 2123.479980, total balance 8279.151937
# day 3621: buy 1 unit at price 2120.790039, total balance 6158.361898
# day 3624, sell 1 unit at price 2109.600098, investment 0.529913 %, total balance 8267.961996,
# day 3625: buy 1 unit at price 2114.070068, total balance 6153.891928
# day 3626, sell 1 unit at price 2095.840088, investment -1.190892 %, total balance 8249.732016,
# day 3628: buy 1 unit at price 2079.280029, total balance 6170.451987
# day 3629: buy 1 unit at price 2080.149902, total balance 4090.302085
# day 3630, sell 1 unit at price 2105.199951, investment -0.971383 %, total balance 6195.502036,
# day 3631, sell 1 unit at price 2108.860107, investment 0.221469 %, total balance 8304.362143,
# day 3632, sell 1 unit at price 2094.110107, investment -1.383101 %, total balance 10398.472250,
# day 3633: buy 1 unit at price 2084.429932, total balance 8314.042318
# day 3635: buy 1 unit at price 2100.439941, total balance 6213.602377
# day 3637, sell 1 unit at price 2109.989990, investment -0.509246 %, total balance 8323.592367,
# day 3638: buy 1 unit at price 2122.850098, total balance 6200.742269
# day 3639, sell 1 unit at price 2124.199951, investment 0.479165 %, total balance 8324.942220,
# day 3641, sell 1 unit at price 2102.310059, investment 1.107596 %, total balance 10427.252279,
# day 3642: buy 1 unit at price 2101.489990, total balance 8325.762289
# day 3643, sell 1 unit at price 2057.639893, investment -1.082134 %, total balance 10383.402182,
# day 3644: buy 1 unit at price 2063.110107, total balance 8320.292075
# day 3645: buy 1 unit at price 2077.419922, total balance 6242.872153
# day 3646: buy 1 unit at price 2076.780029, total balance 4166.092124
# day 3648, sell 1 unit at price 2081.340088, investment -0.148234 %, total balance 6247.432212,
# day 3650: buy 1 unit at price 2051.310059, total balance 4196.122153
# day 3652: buy 1 unit at price 2099.600098, total balance 2096.522055
# day 3653, sell 1 unit at price 2108.949951, investment 0.405154 %, total balance 4205.472006,
# day 3654, sell 1 unit at price 2107.399902, investment -0.727804 %, total balance 6312.871908,
# day 3656: buy 1 unit at price 2126.639893, total balance 4186.232015
# day 3658, sell 1 unit at price 2119.209961, investment 0.843210 %, total balance 6305.441976,
# day 3659: buy 1 unit at price 2114.149902, total balance 4191.292074
# day 3660: buy 1 unit at price 2102.149902, total balance 2089.142172
# day 3662, sell 1 unit at price 2067.639893, investment 0.219561 %, total balance 4156.782065,
# day 3663: buy 1 unit at price 2093.250000, total balance 2063.532065
# day 3665, sell 1 unit at price 2108.629883, investment 1.502342 %, total balance 4172.161948,
# day 3667, sell 1 unit at price 2098.040039, investment 1.023701 %, total balance 6270.201987,
# day 3668, sell 1 unit at price 2093.320068, investment 2.047960 %, total balance 8363.522055,
# day 3669, sell 1 unit at price 2099.840088, investment 0.011430 %, total balance 10463.362143,
# day 3671: buy 1 unit at price 2077.570068, total balance 8385.792075
# day 3673, sell 1 unit at price 2084.070068, investment -2.001741 %, total balance 10469.862143,
# day 3674, sell 1 unit at price 2086.050049, investment -1.329132 %, total balance 12555.912192,
# day 3675, sell 1 unit at price 2083.389893, investment -0.892420 %, total balance 14639.302085,
# day 3676: buy 1 unit at price 2091.540039, total balance 12547.762046
# day 3677: buy 1 unit at price 2102.439941, total balance 10445.322105
# day 3679, sell 1 unit at price 2079.610107, investment -0.651613 %, total balance 12524.932212,
# day 3680, sell 1 unit at price 2035.729980, investment -2.013895 %, total balance 14560.662192,
# day 3681, sell 1 unit at price 1970.890015, investment -5.768478 %, total balance 16531.552207,
# day 3682, sell 1 unit at price 1893.209961, investment -9.951770 %, total balance 18424.762168,
# day 3683: buy 1 unit at price 1867.609985, total balance 16557.152183
# day 3684: buy 1 unit at price 1940.510010, total balance 14616.642173
# day 3686, sell 1 unit at price 1988.869995, investment 6.492791 %, total balance 16605.512168,
# day 3687, sell 1 unit at price 1972.180054, investment 1.632047 %, total balance 18577.692222,
# day 3689: buy 1 unit at price 1948.859985, total balance 16628.832237
# day 3692: buy 1 unit at price 1969.410034, total balance 14659.422203
# day 3693, sell 1 unit at price 1942.040039, investment -0.349945 %, total balance 16601.462242,
# day 3695, sell 1 unit at price 1961.050049, investment -0.424492 %, total balance 18562.512291,
# day 3697: buy 1 unit at price 1978.089966, total balance 16584.422325
# day 3698: buy 1 unit at price 1995.310059, total balance 14589.112266
# day 3699: buy 1 unit at price 1990.199951, total balance 12598.912315
# day 3700: buy 1 unit at price 1958.030029, total balance 10640.882286
# day 3701, sell 1 unit at price 1966.969971, investment -0.562158 %, total balance 12607.852257,
# day 3702, sell 1 unit at price 1942.739990, investment -2.634682 %, total balance 14550.592247,
# day 3705: buy 1 unit at price 1931.339966, total balance 12619.252281
# day 3706, sell 1 unit at price 1881.770020, investment -5.448193 %, total balance 14501.022301,
# day 3707: buy 1 unit at price 1884.089966, total balance 12616.932335
# day 3708, sell 1 unit at price 1920.030029, investment -1.940726 %, total balance 14536.962364,
# day 3709: buy 1 unit at price 1923.819946, total balance 12613.142418
# day 3710: buy 1 unit at price 1951.359985, total balance 10661.782433
# day 3713, sell 1 unit at price 1995.829956, investment 3.339132 %, total balance 12657.612389,
# day 3715, sell 1 unit at price 2014.890015, investment 6.942346 %, total balance 14672.502404,
# day 3716: buy 1 unit at price 2017.459961, total balance 12655.042443
# day 3718, sell 1 unit at price 1994.239990, investment 3.660428 %, total balance 14649.282433,
# day 3719: buy 1 unit at price 2023.859985, total balance 12625.422448
# day 3721, sell 1 unit at price 2033.660034, investment 4.217574 %, total balance 14659.082482,
# day 3722: buy 1 unit at price 2030.770020, total balance 12628.312462
# day 3723: buy 1 unit at price 2018.939941, total balance 10609.372521
# day 3724: buy 1 unit at price 2052.510010, total balance 8556.862511
# day 3725, sell 1 unit at price 2075.149902, investment 2.859533 %, total balance 10632.012413,
# day 3726, sell 1 unit at price 2071.179932, investment 2.338104 %, total balance 12703.192345,
# day 3727, sell 1 unit at price 2065.889893, investment 1.729387 %, total balance 14769.082238,
# day 3728: buy 1 unit at price 2090.350098, total balance 12678.732140
# day 3731, sell 1 unit at price 2104.050049, investment 4.215584 %, total balance 14782.782189,
# day 3732: buy 1 unit at price 2109.790039, total balance 12672.992150
# day 3733: buy 1 unit at price 2102.310059, total balance 10570.682091
# day 3734, sell 1 unit at price 2099.929932, investment 2.310338 %, total balance 12670.612023,
# day 3736, sell 1 unit at price 2078.580078, investment -0.563065 %, total balance 14749.192101,
# day 3737, sell 1 unit at price 2081.719971, investment -1.330467 %, total balance 16830.912072,
# day 3738, sell 1 unit at price 2075.000000, investment -1.299050 %, total balance 18905.912072,
# day 3739: buy 1 unit at price 2045.969971, total balance 16859.942101
# day 3740: buy 1 unit at price 2023.040039, total balance 14836.902062
# day 3742, sell 1 unit at price 2050.439941, investment 0.218477 %, total balance 16887.342003,
# day 3743, sell 1 unit at price 2083.580078, investment 2.992528 %, total balance 18970.922081,
# day 3745: buy 1 unit at price 2089.169922, total balance 16881.752159
# day 3746: buy 1 unit at price 2086.590088, total balance 14795.162071
# day 3748, sell 1 unit at price 2088.870117, investment -0.014350 %, total balance 16884.032188,
# day 3749: buy 1 unit at price 2090.110107, total balance 14793.922081
# day 3751, sell 1 unit at price 2102.629883, investment 0.768708 %, total balance 16896.551964,
# day 3753, sell 1 unit at price 2049.620117, investment -1.937218 %, total balance 18946.172081,
# day 3754: buy 1 unit at price 2091.689941, total balance 16854.482140
# day 3755, sell 1 unit at price 2077.070068, investment -0.698950 %, total balance 18931.552208,
# day 3756: buy 1 unit at price 2063.590088, total balance 16867.962120
# day 3757, sell 1 unit at price 2047.619995, investment -0.773899 %, total balance 18915.582115,
# day 3758: buy 1 unit at price 2052.229980, total balance 16863.352135
# day 3759, sell 1 unit at price 2012.369995, investment -1.942277 %, total balance 18875.722130,
# day 3762: buy 1 unit at price 2073.070068, total balance 16802.652062
# day 3764, sell 1 unit at price 2005.550049, investment -3.257006 %, total balance 18808.202111,
# day 3766: buy 1 unit at price 2038.969971, total balance 16769.232140
# day 3768, sell 1 unit at price 2060.989990, investment 1.079958 %, total balance 18830.222130,
# day 3769: buy 1 unit at price 2056.500000, total balance 16773.722130
# day 3770, sell 1 unit at price 2078.360107, investment 1.062976 %, total balance 18852.082237,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
