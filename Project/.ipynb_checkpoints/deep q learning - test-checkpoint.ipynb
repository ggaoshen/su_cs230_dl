# %% [markdown]
# #### objective
# 1. understand algo
# 2. re-read paper and understand "online-training" and other technical nuances
# 3. think about data
# 4. (optional) set up AWS
# 5. (optional) backtester

# %%
import numpy as np
import pandas as pd
# import tensorflow as tf
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
import matplotlib.pyplot as plt
import seaborn as sns
# from tensorflow.python.framework import ops
tf.disable_v2_behavior()
sns.set()

# %%
df_hsi = pd.read_csv('^HSI.csv')[['Date', 'Adj Close']]
df_spx = pd.read_csv('^GSPC.csv')[['Date', 'Adj Close']]
df_hsi.rename(columns={'Adj Close':'hsi'}, inplace=True)
df_spx.rename(columns={'Adj Close':'spx'}, inplace=True)
df = df_hsi.merge(df_spx, on='Date').dropna()

# %%
df = pd.read_csv('^GSPC.csv')[['Date', 'Close']]
df
# Out:
#             Date        Close
# 0     2001-01-02  1283.270020
# 1     2001-01-03  1347.560059
# 2     2001-01-04  1333.339966
# 3     2001-01-05  1298.349976
# 4     2001-01-08  1295.859985
# ...          ...          ...
# 3768  2015-12-24  2060.989990
# 3769  2015-12-28  2056.500000
# 3770  2015-12-29  2078.360107
# 3771  2015-12-30  2063.360107
# 3772  2015-12-31  2043.939941
#
# [3773 rows x 2 columns]

# %%
from collections import deque
import random


class Agent:
    def __init__(self, state_size, window_size, trend, skip, batch_size):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.action_size = 3
        self.batch_size = batch_size
        self.memory = deque(maxlen = 1000)
        self.inventory = []

        self.gamma = 0.95
        self.epsilon = 0.5
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.999

        tf.reset_default_graph()
        self.sess = tf.InteractiveSession()
        self.X = tf.placeholder(tf.float32, [None, self.state_size])
        self.Y = tf.placeholder(tf.float32, [None, self.action_size])
        feed = tf.layers.dense(self.X, 256, activation = tf.nn.relu)
        self.logits = tf.layers.dense(feed, self.action_size)
        self.cost = tf.reduce_mean(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.GradientDescentOptimizer(1e-5).minimize(
            self.cost
        )
        self.sess.run(tf.global_variables_initializer())

    def act(self, state):
        if random.random() <= self.epsilon:
            return random.randrange(self.action_size)
        return np.argmax(
            self.sess.run(self.logits, feed_dict = {self.X: state})[0] # pick action that maximizes logits (through forward pass)
        )
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])

    def replay(self, batch_size):
        mini_batch = []
        l = len(self.memory)
        for i in range(l - batch_size, l):
            mini_batch.append(self.memory[i])
        replay_size = len(mini_batch)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.action_size))
        states = np.array([a[0][0] for a in mini_batch])
        new_states = np.array([a[3][0] for a in mini_batch])
        Q = self.sess.run(self.logits, feed_dict = {self.X: states})
        Q_new = self.sess.run(self.logits, feed_dict = {self.X: new_states})
        for i in range(len(mini_batch)):
            state, action, reward, next_state, done = mini_batch[i]
            target = Q[i]
            target[action] = reward
            if not done:
                target[action] += self.gamma * np.amax(Q_new[i])
            X[i] = state
            Y[i] = target
        cost, _ = self.sess.run(
            [self.cost, self.optimizer], feed_dict = {self.X: X, self.Y: Y}
        )
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
        return cost
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
                
                
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
        
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.act(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                self.memory.append((state, action, invest, 
                                    next_state, starting_money < initial_money))
                state = next_state
                batch_size = min(self.batch_size, len(self.memory))
                cost = self.replay(batch_size)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip, 
              batch_size = batch_size)
agent.train(iterations = 1000, checkpoint = 10, initial_money = initial_money)
# Out:
# epoch: 10, total rewards: 1834.437592.3, cost: 0.895270, total money: 11834.437592
# epoch: 20, total rewards: 2796.128938.3, cost: 0.638386, total money: 12796.128938
# epoch: 30, total rewards: 2445.088467.3, cost: 0.331469, total money: 12445.088467
# epoch: 40, total rewards: 3385.508822.3, cost: 0.262817, total money: 13385.508822
# epoch: 50, total rewards: 2606.938386.3, cost: 0.191249, total money: 12606.938386
# epoch: 60, total rewards: 1928.438746.3, cost: 0.168297, total money: 11928.438746
# epoch: 70, total rewards: 2132.628874.3, cost: 0.130826, total money: 12132.628874
# epoch: 80, total rewards: 1820.618074.3, cost: 0.105027, total money: 11820.618074
# epoch: 90, total rewards: 2353.718782.3, cost: 0.331270, total money: 12353.718782
# epoch: 100, total rewards: 2361.038114.3, cost: 0.101765, total money: 12361.038114
# epoch: 110, total rewards: 1912.047824.3, cost: 0.075510, total money: 11912.047824
# epoch: 120, total rewards: 1620.488068.3, cost: 0.124818, total money: 11620.488068
# epoch: 130, total rewards: 1667.328582.3, cost: 0.060644, total money: 11667.328582
# epoch: 140, total rewards: 2162.078529.3, cost: 0.069106, total money: 12162.078529
# epoch: 150, total rewards: 1665.597690.3, cost: 0.206943, total money: 11665.597690
# epoch: 160, total rewards: 1226.918307.3, cost: 0.045792, total money: 11226.918307
# epoch: 170, total rewards: 1184.237339.3, cost: 0.040581, total money: 11184.237339
# epoch: 180, total rewards: 1317.048253.3, cost: 0.109743, total money: 11317.048253
# epoch: 190, total rewards: 1208.387856.3, cost: 0.035374, total money: 11208.387856
# epoch: 200, total rewards: 1351.218606.3, cost: 0.034380, total money: 11351.218606
# epoch: 210, total rewards: 1098.507055.3, cost: 0.029096, total money: 11098.507055
# epoch: 220, total rewards: 1714.077733.3, cost: 0.040293, total money: 11714.077733
# epoch: 230, total rewards: 1829.627786.3, cost: 0.029300, total money: 11829.627786
# epoch: 240, total rewards: 1783.958049.3, cost: 0.029733, total money: 11783.958049
# epoch: 250, total rewards: 857.358257.3, cost: 0.024495, total money: 10857.358257
# epoch: 260, total rewards: 1060.028485.3, cost: 0.048576, total money: 11060.028485
# epoch: 270, total rewards: 1719.637979.3, cost: 0.024272, total money: 11719.637979
# epoch: 280, total rewards: 950.408059.3, cost: 0.023441, total money: 10950.408059
# epoch: 290, total rewards: 803.928325.3, cost: 0.015167, total money: 10803.928325
# epoch: 300, total rewards: 973.529035.3, cost: 0.016294, total money: 10973.529035
# epoch: 310, total rewards: 1296.417522.3, cost: 0.018754, total money: 11296.417522
# epoch: 320, total rewards: 1511.988201.3, cost: 0.038020, total money: 11511.988201
# epoch: 330, total rewards: 1861.988381.3, cost: 0.026909, total money: 11861.988381
# epoch: 340, total rewards: 1510.788131.3, cost: 0.024801, total money: 11510.788131
# epoch: 350, total rewards: 1316.367657.3, cost: 0.013714, total money: 11316.367657
# epoch: 360, total rewards: 1640.487773.3, cost: 0.014990, total money: 11640.487773
# epoch: 370, total rewards: 1146.537397.3, cost: 0.012428, total money: 11146.537397
# epoch: 380, total rewards: 1033.178146.3, cost: 0.405394, total money: 11033.178146
# epoch: 390, total rewards: 1587.327682.3, cost: 0.015095, total money: 11587.327682
# epoch: 400, total rewards: 1428.667098.3, cost: 0.012321, total money: 11428.667098
# epoch: 410, total rewards: 1367.667834.3, cost: 0.016828, total money: 11367.667834
# epoch: 420, total rewards: 1103.806865.3, cost: 0.009487, total money: 11103.806865
# epoch: 430, total rewards: 1063.577801.3, cost: 0.093387, total money: 11063.577801
# epoch: 440, total rewards: 1490.637370.3, cost: 0.017574, total money: 11490.637370

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 5: buy 1 unit at price 1300.800049, total balance 8699.199951
# day 7: buy 1 unit at price 1326.819946, total balance 7372.380005
# day 8: buy 1 unit at price 1318.550049, total balance 6053.829956
# day 10, sell 1 unit at price 1329.469971, investment 2.204022 %, total balance 7383.299927,
# day 11, sell 1 unit at price 1347.969971, investment 1.594039 %, total balance 8731.269898,
# day 16, sell 1 unit at price 1357.510010, investment 2.954758 %, total balance 10088.779908,
# day 29: buy 1 unit at price 1318.800049, total balance 8769.979859
# day 30, sell 1 unit at price 1315.920044, investment -0.218381 %, total balance 10085.899903,
# day 35: buy 1 unit at price 1252.819946, total balance 8833.079957
# day 37: buy 1 unit at price 1267.650024, total balance 7565.429933
# day 38, sell 1 unit at price 1257.939941, investment 0.408678 %, total balance 8823.369874,
# day 39: buy 1 unit at price 1239.939941, total balance 7583.429933
# day 40: buy 1 unit at price 1241.229980, total balance 6342.199953
# day 41, sell 1 unit at price 1234.180054, investment -2.640316 %, total balance 7576.380007,
# day 43, sell 1 unit at price 1253.800049, investment 1.117805 %, total balance 8830.180056,
# day 45: buy 1 unit at price 1264.739990, total balance 7565.440066
# day 46, sell 1 unit at price 1233.420044, investment -0.629209 %, total balance 8798.860110,
# day 47, sell 1 unit at price 1180.160034, investment -6.687537 %, total balance 9979.020144,
# day 61: buy 1 unit at price 1160.329956, total balance 8818.690188
# day 64, sell 1 unit at price 1103.250000, investment -4.919287 %, total balance 9921.940188,
# day 66: buy 1 unit at price 1128.430054, total balance 8793.510134
# day 67, sell 1 unit at price 1137.589966, investment 0.811739 %, total balance 9931.100100,
# day 75: buy 1 unit at price 1242.979980, total balance 8688.120120
# day 76, sell 1 unit at price 1224.359985, investment -1.498012 %, total balance 9912.480105,
# day 94: buy 1 unit at price 1288.489990, total balance 8623.990115
# day 95, sell 1 unit at price 1291.959961, investment 0.269305 %, total balance 9915.950076,
# day 103: buy 1 unit at price 1255.819946, total balance 8660.130130
# day 107, sell 1 unit at price 1270.030029, investment 1.131538 %, total balance 9930.160159,
# day 117: buy 1 unit at price 1223.140015, total balance 8707.020144
# day 118, sell 1 unit at price 1237.040039, investment 1.136421 %, total balance 9944.060183,
# day 144: buy 1 unit at price 1204.520020, total balance 8739.540163
# day 145, sell 1 unit at price 1211.229980, investment 0.557065 %, total balance 9950.770143,
# day 147: buy 1 unit at price 1220.750000, total balance 8730.020143
# day 148, sell 1 unit at price 1214.349976, investment -0.524270 %, total balance 9944.370119,
# day 153: buy 1 unit at price 1190.160034, total balance 8754.210085
# day 154, sell 1 unit at price 1191.290039, investment 0.094946 %, total balance 9945.500124,
# day 158: buy 1 unit at price 1161.969971, total balance 8783.530153
# day 160, sell 1 unit at price 1157.260010, investment -0.405343 %, total balance 9940.790163,
# day 164: buy 1 unit at price 1179.209961, total balance 8761.580202
# day 165, sell 1 unit at price 1161.510010, investment -1.501001 %, total balance 9923.090212,
# day 167: buy 1 unit at price 1129.030029, total balance 8794.060183
# day 169, sell 1 unit at price 1132.939941, investment 0.346307 %, total balance 9927.000124,
# day 170: buy 1 unit at price 1131.739990, total balance 8795.260134
# day 171, sell 1 unit at price 1106.400024, investment -2.239027 %, total balance 9901.660158,
# day 180: buy 1 unit at price 1012.270020, total balance 8889.390138
# day 185: buy 1 unit at price 1051.329956, total balance 7838.060182
# day 186: buy 1 unit at price 1072.280029, total balance 6765.780153
# day 188, sell 1 unit at price 1071.380005, investment 5.839350 %, total balance 7837.160158,
# day 189, sell 1 unit at price 1062.439941, investment 1.056755 %, total balance 8899.600099,
# day 191: buy 1 unit at price 1080.989990, total balance 7818.610109
# day 192, sell 1 unit at price 1097.430054, investment 2.345472 %, total balance 8916.040163,
# day 194, sell 1 unit at price 1089.979980, investment 0.831644 %, total balance 10006.020143,
# day 198: buy 1 unit at price 1073.479980, total balance 8932.540163
# day 199, sell 1 unit at price 1089.900024, investment 1.529609 %, total balance 10022.440187,
# day 200: buy 1 unit at price 1084.780029, total balance 8937.660158
# day 203, sell 1 unit at price 1104.609985, investment 1.828016 %, total balance 10042.270143,
# day 207: buy 1 unit at price 1084.099976, total balance 8958.170167
# day 208, sell 1 unit at price 1087.199951, investment 0.285949 %, total balance 10045.370118,
# day 213: buy 1 unit at price 1120.310059, total balance 8925.060059
# day 215, sell 1 unit at price 1139.089966, investment 1.676313 %, total balance 10064.150025,
# day 217: buy 1 unit at price 1142.239990, total balance 8921.910035
# day 218, sell 1 unit at price 1138.650024, investment -0.314292 %, total balance 10060.560059,
# day 221: buy 1 unit at price 1137.030029, total balance 8923.530030
# day 222, sell 1 unit at price 1150.339966, investment 1.170588 %, total balance 10073.869996,
# day 225: buy 1 unit at price 1128.520020, total balance 8945.349976
# day 226, sell 1 unit at price 1140.199951, investment 1.034978 %, total balance 10085.549927,
# day 229: buy 1 unit at price 1144.800049, total balance 8940.749878
# day 230, sell 1 unit at price 1170.349976, investment 2.231824 %, total balance 10111.099854,
# day 237: buy 1 unit at price 1123.089966, total balance 8988.009888
# day 238, sell 1 unit at price 1134.359985, investment 1.003483 %, total balance 10122.369873,
# day 243: buy 1 unit at price 1144.650024, total balance 8977.719849
# day 244: buy 1 unit at price 1149.369995, total balance 7828.349854
# day 245, sell 1 unit at price 1157.130005, investment 1.090288 %, total balance 8985.479859,
# day 246, sell 1 unit at price 1161.020020, investment 1.013601 %, total balance 10146.499879,
# day 247: buy 1 unit at price 1148.079956, total balance 8998.419923
# day 248, sell 1 unit at price 1154.670044, investment 0.574009 %, total balance 10153.089967,
# day 249: buy 1 unit at price 1165.270020, total balance 8987.819947
# day 250: buy 1 unit at price 1172.510010, total balance 7815.309937
# day 251, sell 1 unit at price 1164.890015, investment -0.032611 %, total balance 8980.199952,
# day 252, sell 1 unit at price 1160.709961, investment -1.006392 %, total balance 10140.909913,
# day 267: buy 1 unit at price 1113.569946, total balance 9027.339967
# day 268, sell 1 unit at price 1130.199951, investment 1.493396 %, total balance 10157.539918,
# day 272: buy 1 unit at price 1083.510010, total balance 9074.029908
# day 274, sell 1 unit at price 1096.219971, investment 1.173036 %, total balance 10170.249879,
# day 281: buy 1 unit at price 1097.979980, total balance 9072.269899
# day 283, sell 1 unit at price 1089.839966, investment -0.741363 %, total balance 10162.109865,
# day 291: buy 1 unit at price 1162.770020, total balance 8999.339845
# day 293: buy 1 unit at price 1164.310059, total balance 7835.029786
# day 294, sell 1 unit at price 1168.260010, investment 0.472148 %, total balance 9003.289796,
# day 296: buy 1 unit at price 1154.089966, total balance 7849.199830
# day 298, sell 1 unit at price 1166.160034, investment 0.158890 %, total balance 9015.359864,
# day 299, sell 1 unit at price 1165.550049, investment 0.992997 %, total balance 10180.909913,
# day 306: buy 1 unit at price 1144.579956, total balance 9036.329957
# day 307, sell 1 unit at price 1147.390015, investment 0.245510 %, total balance 10183.719972,
# day 317: buy 1 unit at price 1111.010010, total balance 9072.709962
# day 318, sell 1 unit at price 1102.550049, investment -0.761466 %, total balance 10175.260011,
# day 333: buy 1 unit at price 1052.670044, total balance 9122.589967
# day 336, sell 1 unit at price 1073.010010, investment 1.932226 %, total balance 10195.599977,
# day 341: buy 1 unit at price 1098.229980, total balance 9097.369997
# day 342, sell 1 unit at price 1106.589966, investment 0.761224 %, total balance 10203.959963,
# day 343: buy 1 unit at price 1091.880005, total balance 9112.079958
# day 344: buy 1 unit at price 1079.880005, total balance 8032.199953
# day 345: buy 1 unit at price 1086.020020, total balance 6946.179933
# day 346, sell 1 unit at price 1097.079956, investment 0.476238 %, total balance 8043.259889,
# day 347, sell 1 unit at price 1083.819946, investment 0.364850 %, total balance 9127.079835,
# day 348, sell 1 unit at price 1074.550049, investment -1.056147 %, total balance 10201.629884,
# day 350: buy 1 unit at price 1064.660034, total balance 9136.969850
# day 352: buy 1 unit at price 1040.680054, total balance 8096.289796
# day 354, sell 1 unit at price 1049.900024, investment -1.386359 %, total balance 9146.189820,
# day 356, sell 1 unit at price 1027.530029, investment -1.263599 %, total balance 10173.719849,
# day 357: buy 1 unit at price 1030.739990, total balance 9142.979859
# day 358, sell 1 unit at price 1013.599976, investment -1.662884 %, total balance 10156.579835,
# day 359: buy 1 unit at price 1020.260010, total balance 9136.319825
# day 360, sell 1 unit at price 1009.559998, investment -1.048753 %, total balance 10145.879823,
# day 361: buy 1 unit at price 1007.270020, total balance 9138.609803
# day 362, sell 1 unit at price 1036.170044, investment 2.869144 %, total balance 10174.779847,
# day 364: buy 1 unit at price 1019.989990, total balance 9154.789857
# day 365, sell 1 unit at price 1006.289978, investment -1.343152 %, total balance 10161.079835,
# day 366: buy 1 unit at price 989.140015, total balance 9171.939820
# day 367, sell 1 unit at price 992.719971, investment 0.361926 %, total balance 10164.659791,
# day 368: buy 1 unit at price 976.140015, total balance 9188.519776
# day 369, sell 1 unit at price 973.530029, investment -0.267378 %, total balance 10162.049805,
# day 370: buy 1 unit at price 990.640015, total balance 9171.409790
# day 371: buy 1 unit at price 989.820007, total balance 8181.589783
# day 373, sell 1 unit at price 948.090027, investment -4.295202 %, total balance 9129.679810,
# day 374: buy 1 unit at price 953.989990, total balance 8175.689820
# day 375: buy 1 unit at price 989.030029, total balance 7186.659791
# day 377, sell 1 unit at price 952.830017, investment -3.737042 %, total balance 8139.489808,
# day 379: buy 1 unit at price 927.369995, total balance 7212.119813
# day 380: buy 1 unit at price 921.390015, total balance 6290.729798
# day 381: buy 1 unit at price 917.929993, total balance 5372.799805
# day 383, sell 1 unit at price 906.039978, investment -5.026259 %, total balance 6278.839783,
# day 385, sell 1 unit at price 847.750000, investment -14.284706 %, total balance 7126.589783,
# day 386, sell 1 unit at price 819.849976, investment -11.594080 %, total balance 7946.439759,
# day 387, sell 1 unit at price 797.700012, investment -13.424283 %, total balance 8744.139771,
# day 390, sell 1 unit at price 852.840027, investment -7.090951 %, total balance 9596.979798,
# day 391: buy 1 unit at price 898.960022, total balance 8698.019776
# day 392, sell 1 unit at price 902.780029, investment 0.424936 %, total balance 9600.799805,
# day 393: buy 1 unit at price 911.619995, total balance 8689.179810
# day 394, sell 1 unit at price 884.659973, investment -2.957375 %, total balance 9573.839783,
# day 397: buy 1 unit at price 859.570007, total balance 8714.269776
# day 398, sell 1 unit at price 876.770020, investment 2.001002 %, total balance 9591.039796,
# day 399: buy 1 unit at price 905.460022, total balance 8685.579774
# day 400: buy 1 unit at price 908.640015, total balance 7776.939759
# day 403: buy 1 unit at price 919.619995, total balance 6857.319764
# day 404, sell 1 unit at price 930.250000, investment 2.737832 %, total balance 7787.569764,
# day 405: buy 1 unit at price 928.770020, total balance 6858.799744
# day 407, sell 1 unit at price 937.429993, investment 3.168469 %, total balance 7796.229737,
# day 409: buy 1 unit at price 962.700012, total balance 6833.529725
# day 410, sell 1 unit at price 940.859985, investment 2.309649 %, total balance 7774.389710,
# day 411, sell 1 unit at price 947.950012, investment 2.065096 %, total balance 8722.339722,
# day 413: buy 1 unit at price 917.869995, total balance 7804.469727
# day 416, sell 1 unit at price 878.020020, investment -8.796093 %, total balance 8682.489747,
# day 420, sell 1 unit at price 902.960022, investment -1.624410 %, total balance 9585.449769,
# day 428: buy 1 unit at price 843.320007, total balance 8742.129762
# day 429: buy 1 unit at price 845.390015, total balance 7896.739747
# day 430, sell 1 unit at price 833.700012, investment -1.140729 %, total balance 8730.439759,
# day 432, sell 1 unit at price 839.659973, investment -0.677799 %, total balance 9570.099732,
# day 441: buy 1 unit at price 798.549988, total balance 8771.549744
# day 442, sell 1 unit at price 776.760010, investment -2.728693 %, total balance 9548.309754,
# day 448: buy 1 unit at price 879.200012, total balance 8669.109742
# day 449, sell 1 unit at price 884.390015, investment 0.590310 %, total balance 9553.499757,
# day 453: buy 1 unit at price 882.500000, total balance 8670.999757
# day 454, sell 1 unit at price 897.650024, investment 1.716717 %, total balance 9568.649781,
# day 472: buy 1 unit at price 914.150024, total balance 8654.499757
# day 473, sell 1 unit at price 933.760010, investment 2.145161 %, total balance 9588.259767,
# day 479: buy 1 unit at price 934.530029, total balance 8653.729738
# day 481, sell 1 unit at price 917.580017, investment -1.813747 %, total balance 9571.309755,
# day 489: buy 1 unit at price 910.400024, total balance 8660.909731
# day 490, sell 1 unit at price 902.989990, investment -0.813932 %, total balance 9563.899721,
# day 498: buy 1 unit at price 879.390015, total balance 8684.509706
# day 499: buy 1 unit at price 879.820007, total balance 7804.689699
# day 500, sell 1 unit at price 909.030029, investment 3.370520 %, total balance 8713.719728,
# day 501: buy 1 unit at price 908.590027, total balance 7805.129701
# day 502, sell 1 unit at price 929.010010, investment 5.590917 %, total balance 8734.139711,
# day 503, sell 1 unit at price 922.929993, investment 1.578266 %, total balance 9657.069704,
# day 511: buy 1 unit at price 901.780029, total balance 8755.289675
# day 513, sell 1 unit at price 878.359985, investment -2.597091 %, total balance 9633.649660,
# day 514: buy 1 unit at price 887.340027, total balance 8746.309633
# day 517, sell 1 unit at price 858.539978, investment -3.245661 %, total balance 9604.849611,
# day 540: buy 1 unit at price 834.809998, total balance 8770.039613
# day 541, sell 1 unit at price 821.989990, investment -1.535680 %, total balance 9592.029603,
# day 551: buy 1 unit at price 866.450012, total balance 8725.579591
# day 553, sell 1 unit at price 875.669983, investment 1.064109 %, total balance 9601.249574,
# day 556: buy 1 unit at price 874.739990, total balance 8726.509584
# day 557, sell 1 unit at price 869.950012, investment -0.547589 %, total balance 9596.459596,
# day 562: buy 1 unit at price 880.900024, total balance 8715.559572
# day 563, sell 1 unit at price 876.450012, investment -0.505167 %, total balance 9592.009584,
# day 570: buy 1 unit at price 885.229980, total balance 8706.779604
# day 571: buy 1 unit at price 890.809998, total balance 7815.969606
# day 572, sell 1 unit at price 879.909973, investment -0.600975 %, total balance 8695.879579,
# day 573, sell 1 unit at price 893.580017, investment 0.310955 %, total balance 9589.459596,
# day 582: buy 1 unit at price 916.299988, total balance 8673.159608
# day 583, sell 1 unit at price 930.080017, investment 1.503877 %, total balance 9603.239625,
# day 597: buy 1 unit at price 931.869995, total balance 8671.369630
# day 598, sell 1 unit at price 933.219971, investment 0.144867 %, total balance 9604.589601,
# day 599: buy 1 unit at price 951.479980, total balance 8653.109621
# day 600, sell 1 unit at price 953.219971, investment 0.182872 %, total balance 9606.329592,
# day 602: buy 1 unit at price 963.590027, total balance 8642.739565
# day 604, sell 1 unit at price 971.559998, investment 0.827112 %, total balance 9614.299563,
# day 605: buy 1 unit at price 986.239990, total balance 8628.059573
# day 606, sell 1 unit at price 990.140015, investment 0.395444 %, total balance 9618.199588,
# day 610: buy 1 unit at price 997.479980, total balance 8620.719608
# day 611, sell 1 unit at price 998.510010, investment 0.103263 %, total balance 9619.229618,
# day 620: buy 1 unit at price 975.320007, total balance 8643.909611
# day 621: buy 1 unit at price 985.820007, total balance 7658.089604
# day 622, sell 1 unit at price 976.219971, investment 0.092274 %, total balance 8634.309575,
# day 623, sell 1 unit at price 974.500000, investment -1.148283 %, total balance 9608.809575,
# day 625: buy 1 unit at price 993.750000, total balance 8615.059575
# day 626, sell 1 unit at price 985.700012, investment -0.810062 %, total balance 9600.759587,
# day 627: buy 1 unit at price 1004.419983, total balance 8596.339604
# day 628, sell 1 unit at price 1007.840027, investment 0.340499 %, total balance 9604.179631,
# day 631: buy 1 unit at price 998.140015, total balance 8606.039616
# day 632, sell 1 unit at price 1003.859985, investment 0.573063 %, total balance 9609.899601,
# day 634: buy 1 unit at price 994.090027, total balance 8615.809574
# day 636, sell 1 unit at price 993.320007, investment -0.077460 %, total balance 9609.129581,
# day 642: buy 1 unit at price 996.520020, total balance 8612.609561
# day 643, sell 1 unit at price 989.280029, investment -0.726527 %, total balance 9601.889590,
# day 653: buy 1 unit at price 990.349976, total balance 8611.539614
# day 656: buy 1 unit at price 990.669983, total balance 7620.869631
# day 658, sell 1 unit at price 1002.349976, investment 1.211693 %, total balance 8623.219607,
# day 659, sell 1 unit at price 1000.299988, investment 0.972070 %, total balance 9623.519595,
# day 662: buy 1 unit at price 993.710022, total balance 8629.809573
# day 663, sell 1 unit at price 996.729980, investment 0.303907 %, total balance 9626.539553,
# day 678: buy 1 unit at price 1025.969971, total balance 8600.569582
# day 679, sell 1 unit at price 1039.579956, investment 1.326548 %, total balance 9640.149538,
# day 686: buy 1 unit at price 1006.580017, total balance 8633.569521
# day 687, sell 1 unit at price 995.969971, investment -1.054069 %, total balance 9629.539492,
# day 709: buy 1 unit at price 1046.939941, total balance 8582.599551
# day 710, sell 1 unit at price 1050.709961, investment 0.360099 %, total balance 9633.309512,
# day 718: buy 1 unit at price 1058.530029, total balance 8574.779483
# day 720, sell 1 unit at price 1050.349976, investment -0.772775 %, total balance 9625.129459,
# day 723: buy 1 unit at price 1042.439941, total balance 8582.689518
# day 724, sell 1 unit at price 1033.650024, investment -0.843206 %, total balance 9616.339542,
# day 730: buy 1 unit at price 1070.119995, total balance 8546.219547
# day 731, sell 1 unit at price 1066.619995, investment -0.327066 %, total balance 9612.839542,
# day 736: buy 1 unit at price 1060.180054, total balance 8552.659488
# day 738, sell 1 unit at price 1071.209961, investment 1.040381 %, total balance 9623.869449,
# day 740: buy 1 unit at price 1068.040039, total balance 8555.829410
# day 741, sell 1 unit at price 1075.130005, investment 0.663830 %, total balance 9630.959415,
# day 777: buy 1 unit at price 1139.810059, total balance 8491.149356
# day 779, sell 1 unit at price 1157.760010, investment 1.574819 %, total balance 9648.909366,
# day 782: buy 1 unit at price 1156.989990, total balance 8491.919376
# day 783: buy 1 unit at price 1151.819946, total balance 7340.099430
# day 785: buy 1 unit at price 1144.109985, total balance 6195.989445
# day 786: buy 1 unit at price 1140.989990, total balance 5054.999455
# day 788, sell 1 unit at price 1143.670044, investment -1.151259 %, total balance 6198.669499,
# day 789, sell 1 unit at price 1144.910034, investment -0.599913 %, total balance 7343.579533,
# day 793, sell 1 unit at price 1151.030029, investment 0.604841 %, total balance 8494.609562,
# day 795, sell 1 unit at price 1156.859985, investment 1.390897 %, total balance 9651.469547,
# day 800: buy 1 unit at price 1120.569946, total balance 8530.899601
# day 801, sell 1 unit at price 1104.489990, investment -1.434980 %, total balance 9635.389591,
# day 807: buy 1 unit at price 1093.949951, total balance 8541.439640
# day 808, sell 1 unit at price 1091.329956, investment -0.239499 %, total balance 9632.769596,
# day 809: buy 1 unit at price 1109.189941, total balance 8523.579655
# day 810, sell 1 unit at price 1108.060059, investment -0.101866 %, total balance 9631.639714,
# day 815: buy 1 unit at price 1141.810059, total balance 8489.829655
# day 817, sell 1 unit at price 1148.160034, investment 0.556132 %, total balance 9637.989689,
# day 820: buy 1 unit at price 1145.199951, total balance 8492.789738
# day 822, sell 1 unit at price 1128.170044, investment -1.487068 %, total balance 9620.959782,
# day 824: buy 1 unit at price 1134.609985, total balance 8486.349797
# day 825, sell 1 unit at price 1135.819946, investment 0.106641 %, total balance 9622.169743,
# day 826: buy 1 unit at price 1118.150024, total balance 8504.019719
# day 827, sell 1 unit at price 1124.089966, investment 0.531229 %, total balance 9628.109685,
# day 831: buy 1 unit at price 1138.109985, total balance 8489.999700
# day 832: buy 1 unit at price 1122.410034, total balance 7367.589666
# day 833, sell 1 unit at price 1113.890015, investment -2.128087 %, total balance 8481.479681,
# day 834, sell 1 unit at price 1107.300049, investment -1.346209 %, total balance 9588.779730,
# day 835: buy 1 unit at price 1117.489990, total balance 8471.289740
# day 837, sell 1 unit at price 1121.530029, investment 0.361528 %, total balance 9592.819769,
# day 840: buy 1 unit at price 1087.119995, total balance 8505.699774
# day 841, sell 1 unit at price 1095.449951, investment 0.766241 %, total balance 9601.149725,
# day 845: buy 1 unit at price 1084.099976, total balance 8517.049749
# day 847, sell 1 unit at price 1088.680054, investment 0.422477 %, total balance 9605.729803,
# day 852: buy 1 unit at price 1114.939941, total balance 8490.789862
# day 853, sell 1 unit at price 1121.280029, investment 0.568648 %, total balance 9612.069891,
# day 859: buy 1 unit at price 1140.420044, total balance 8471.649847
# day 861: buy 1 unit at price 1131.329956, total balance 7340.319891
# day 862, sell 1 unit at price 1136.469971, investment -0.346370 %, total balance 8476.789862,
# day 864, sell 1 unit at price 1132.010010, investment 0.060111 %, total balance 9608.799872,
# day 869: buy 1 unit at price 1134.410034, total balance 8474.389838
# day 871, sell 1 unit at price 1140.650024, investment 0.550065 %, total balance 9615.039862,
# day 876: buy 1 unit at price 1128.939941, total balance 8486.099921
# day 877, sell 1 unit at price 1125.380005, investment -0.315334 %, total balance 9611.479926,
# day 881: buy 1 unit at price 1112.810059, total balance 8498.669867
# day 882, sell 1 unit at price 1114.349976, investment 0.138381 %, total balance 9613.019843,
# day 884: buy 1 unit at price 1111.469971, total balance 8501.549872
# day 886: buy 1 unit at price 1101.390015, total balance 7400.159857
# day 887, sell 1 unit at price 1100.900024, investment -0.950988 %, total balance 8501.059881,
# day 888: buy 1 unit at price 1108.670044, total balance 7392.389837
# day 889, sell 1 unit at price 1093.880005, investment -0.681867 %, total balance 8486.269842,
# day 890, sell 1 unit at price 1096.839966, investment -1.067051 %, total balance 9583.109808,
# day 903: buy 1 unit at price 1079.040039, total balance 8504.069769
# day 905: buy 1 unit at price 1063.229980, total balance 7440.839789
# day 906, sell 1 unit at price 1064.800049, investment -1.319691 %, total balance 8505.639838,
# day 907, sell 1 unit at price 1079.339966, investment 1.515193 %, total balance 9584.979804,
# day 919: buy 1 unit at price 1105.910034, total balance 8479.069770
# day 920, sell 1 unit at price 1118.310059, investment 1.121251 %, total balance 9597.379829,
# day 921: buy 1 unit at price 1113.630005, total balance 8483.749824
# day 922, sell 1 unit at price 1121.300049, investment 0.688743 %, total balance 9605.049873,
# day 923: buy 1 unit at price 1116.270020, total balance 8488.779853
# day 924, sell 1 unit at price 1118.380005, investment 0.189021 %, total balance 9607.159858,
# day 927: buy 1 unit at price 1128.329956, total balance 8478.829902
# day 928, sell 1 unit at price 1120.369995, investment -0.705464 %, total balance 9599.199897,
# day 934: buy 1 unit at price 1108.359985, total balance 8490.839912
# day 937: buy 1 unit at price 1110.060059, total balance 7380.779853
# day 941, sell 1 unit at price 1135.170044, investment 2.418895 %, total balance 8515.949897,
# day 942, sell 1 unit at price 1134.479980, investment 2.199874 %, total balance 9650.429877,
# day 950: buy 1 unit at price 1108.199951, total balance 8542.229926
# day 951, sell 1 unit at price 1114.020020, investment 0.525182 %, total balance 9656.249946,
# day 954: buy 1 unit at price 1106.489990, total balance 8549.759956
# day 955: buy 1 unit at price 1095.739990, total balance 7454.019966
# day 957, sell 1 unit at price 1111.089966, investment 0.415727 %, total balance 8565.109932,
# day 960: buy 1 unit at price 1130.199951, total balance 7434.909981
# day 962, sell 1 unit at price 1130.560059, investment 3.177767 %, total balance 8565.470040,
# day 963: buy 1 unit at price 1143.199951, total balance 7422.270089
# day 964, sell 1 unit at price 1161.670044, investment 2.784471 %, total balance 8583.940133,
# day 966, sell 1 unit at price 1164.890015, investment 1.897311 %, total balance 9748.830148,
# day 969: buy 1 unit at price 1173.479980, total balance 8575.350168
# day 970: buy 1 unit at price 1184.170044, total balance 7391.180124
# day 972: buy 1 unit at price 1175.430054, total balance 6215.750070
# day 973: buy 1 unit at price 1181.939941, total balance 5033.810129
# day 977, sell 1 unit at price 1176.939941, investment 0.294846 %, total balance 6210.750070,
# day 979: buy 1 unit at price 1182.650024, total balance 5028.100046
# day 980, sell 1 unit at price 1178.569946, investment -0.472913 %, total balance 6206.669992,
# day 981, sell 1 unit at price 1173.819946, investment -0.136980 %, total balance 7380.489938,
# day 983, sell 1 unit at price 1190.329956, investment 0.709851 %, total balance 8570.819894,
# day 985, sell 1 unit at price 1190.250000, investment 0.642623 %, total balance 9761.069894,
# day 999: buy 1 unit at price 1204.920044, total balance 8556.149850
# day 1000, sell 1 unit at price 1213.540039, investment 0.715400 %, total balance 9769.689889,
# day 1020: buy 1 unit at price 1174.069946, total balance 8595.619943
# day 1021, sell 1 unit at price 1174.550049, investment 0.040892 %, total balance 9770.169992,
# day 1022: buy 1 unit at price 1171.359985, total balance 8598.810007
# day 1023, sell 1 unit at price 1181.270020, investment 0.846028 %, total balance 9780.080027,
# day 1042: buy 1 unit at price 1203.599976, total balance 8576.480051
# day 1044, sell 1 unit at price 1210.079956, investment 0.538383 %, total balance 9786.560007,
# day 1048: buy 1 unit at price 1219.430054, total balance 8567.129953
# day 1050: buy 1 unit at price 1209.250000, total balance 7357.879953
# day 1052, sell 1 unit at price 1206.829956, investment -1.033278 %, total balance 8564.709909,
# day 1053, sell 1 unit at price 1197.750000, investment -0.951003 %, total balance 9762.459909,
# day 1059: buy 1 unit at price 1172.530029, total balance 8589.929880
# day 1063: buy 1 unit at price 1181.410034, total balance 7408.519846
# day 1064, sell 1 unit at price 1180.589966, investment 0.687397 %, total balance 8589.109812,
# day 1065, sell 1 unit at price 1172.920044, investment -0.718632 %, total balance 9762.029856,
# day 1068: buy 1 unit at price 1184.069946, total balance 8577.959910
# day 1069, sell 1 unit at price 1191.140015, investment 0.597099 %, total balance 9769.099925,
# day 1072: buy 1 unit at price 1187.760010, total balance 8581.339915
# day 1073, sell 1 unit at price 1173.790039, investment -1.176161 %, total balance 9755.129954,
# day 1076: buy 1 unit at price 1145.979980, total balance 8609.149974
# day 1080, sell 1 unit at price 1152.119995, investment 0.535787 %, total balance 9761.269969,
# day 1081: buy 1 unit at price 1162.099976, total balance 8599.169993
# day 1082, sell 1 unit at price 1151.829956, investment -0.883747 %, total balance 9750.999949,
# day 1085: buy 1 unit at price 1156.849976, total balance 8594.149973
# day 1086, sell 1 unit at price 1162.160034, investment 0.459010 %, total balance 9756.310007,
# day 1092: buy 1 unit at price 1166.219971, total balance 8590.090036
# day 1093: buy 1 unit at price 1171.109985, total balance 7418.980051
# day 1094, sell 1 unit at price 1159.359985, investment -0.588224 %, total balance 8578.340036,
# day 1095, sell 1 unit at price 1154.050049, investment -1.456732 %, total balance 9732.390085,
# day 1097: buy 1 unit at price 1173.800049, total balance 8558.590036
# day 1099, sell 1 unit at price 1191.079956, investment 1.472134 %, total balance 9749.669992,
# day 1108: buy 1 unit at price 1204.290039, total balance 8545.379953
# day 1109, sell 1 unit at price 1196.020020, investment -0.686713 %, total balance 9741.399973,
# day 1112: buy 1 unit at price 1194.670044, total balance 8546.729929
# day 1114, sell 1 unit at price 1198.109985, investment 0.287941 %, total balance 9744.839914,
# day 1122: buy 1 unit at price 1213.880005, total balance 8530.959909
# day 1123, sell 1 unit at price 1200.729980, investment -1.083305 %, total balance 9731.689889,
# day 1136: buy 1 unit at price 1223.290039, total balance 8508.399850
# day 1137, sell 1 unit at price 1226.500000, investment 0.262404 %, total balance 9734.899850,
# day 1140: buy 1 unit at price 1229.349976, total balance 8505.549874
# day 1141, sell 1 unit at price 1235.199951, investment 0.475859 %, total balance 9740.749825,
# day 1144: buy 1 unit at price 1229.030029, total balance 8511.719796
# day 1145, sell 1 unit at price 1231.160034, investment 0.173308 %, total balance 9742.879830,
# day 1147: buy 1 unit at price 1243.719971, total balance 8499.159859
# day 1148: buy 1 unit at price 1234.180054, total balance 7264.979805
# day 1149, sell 1 unit at price 1235.349976, investment -0.672981 %, total balance 8500.329781,
# day 1150: buy 1 unit at price 1244.119995, total balance 7256.209786
# day 1151, sell 1 unit at price 1245.040039, investment 0.879935 %, total balance 8501.249825,
# day 1152, sell 1 unit at price 1235.859985, investment -0.663924 %, total balance 9737.109810,
# day 1154: buy 1 unit at price 1223.130005, total balance 8513.979805
# day 1155, sell 1 unit at price 1231.380005, investment 0.674499 %, total balance 9745.359810,
# day 1157: buy 1 unit at price 1237.810059, total balance 8507.549751
# day 1158, sell 1 unit at price 1230.390015, investment -0.599449 %, total balance 9737.939766,
# day 1161: buy 1 unit at price 1220.239990, total balance 8517.699776
# day 1163: buy 1 unit at price 1219.709961, total balance 7297.989815
# day 1164, sell 1 unit at price 1221.729980, investment 0.122106 %, total balance 8519.719795,
# day 1165, sell 1 unit at price 1217.589966, investment -0.173811 %, total balance 9737.309761,
# day 1168: buy 1 unit at price 1205.099976, total balance 8532.209785
# day 1169: buy 1 unit at price 1212.280029, total balance 7319.929756
# day 1170, sell 1 unit at price 1208.410034, investment 0.274671 %, total balance 8528.339790,
# day 1171: buy 1 unit at price 1220.329956, total balance 7308.009834
# day 1173: buy 1 unit at price 1218.020020, total balance 6089.989814
# day 1174, sell 1 unit at price 1233.390015, investment 1.741346 %, total balance 7323.379829,
# day 1175, sell 1 unit at price 1236.359985, investment 1.313582 %, total balance 8559.739814,
# day 1177, sell 1 unit at price 1241.479980, investment 1.926073 %, total balance 9801.219794,
# day 1183: buy 1 unit at price 1231.020020, total balance 8570.199774
# day 1185, sell 1 unit at price 1210.199951, investment -1.691286 %, total balance 9780.399725,
# day 1196: buy 1 unit at price 1191.489990, total balance 8588.909735
# day 1197, sell 1 unit at price 1195.900024, investment 0.370128 %, total balance 9784.809759,
# day 1205: buy 1 unit at price 1195.760010, total balance 8589.049749
# day 1206, sell 1 unit at price 1177.800049, investment -1.501970 %, total balance 9766.849798,
# day 1212: buy 1 unit at price 1198.410034, total balance 8568.439764
# day 1215, sell 1 unit at price 1214.760010, investment 1.364306 %, total balance 9783.199774,
# day 1221: buy 1 unit at price 1230.959961, total balance 8552.239813
# day 1222, sell 1 unit at price 1234.719971, investment 0.305453 %, total balance 9786.959784,
# day 1234: buy 1 unit at price 1249.479980, total balance 8537.479804
# day 1235, sell 1 unit at price 1264.670044, investment 1.215711 %, total balance 9802.149848,
# day 1236: buy 1 unit at price 1265.079956, total balance 8537.069892
# day 1237, sell 1 unit at price 1262.089966, investment -0.236348 %, total balance 9799.159858,
# day 1250: buy 1 unit at price 1268.119995, total balance 8531.039863
# day 1252, sell 1 unit at price 1256.540039, investment -0.913159 %, total balance 9787.579902,
# day 1257: buy 1 unit at price 1273.459961, total balance 8514.119941
# day 1258, sell 1 unit at price 1273.479980, investment 0.001572 %, total balance 9787.599921,
# day 1262: buy 1 unit at price 1294.180054, total balance 8493.419867
# day 1264, sell 1 unit at price 1287.609985, investment -0.507663 %, total balance 9781.029852,
# day 1271: buy 1 unit at price 1264.680054, total balance 8516.349798
# day 1272, sell 1 unit at price 1273.829956, investment 0.723495 %, total balance 9790.179754,
# day 1276: buy 1 unit at price 1282.459961, total balance 8507.719793
# day 1277, sell 1 unit at price 1270.839966, investment -0.906071 %, total balance 9778.559759,
# day 1281: buy 1 unit at price 1265.650024, total balance 8512.909735
# day 1284, sell 1 unit at price 1262.859985, investment -0.220443 %, total balance 9775.769720,
# day 1285: buy 1 unit at price 1275.530029, total balance 8500.239691
# day 1287, sell 1 unit at price 1289.380005, investment 1.085821 %, total balance 9789.619696,
# day 1294: buy 1 unit at price 1280.660034, total balance 8508.959662
# day 1295, sell 1 unit at price 1291.239990, investment 0.826133 %, total balance 9800.199652,
# day 1296: buy 1 unit at price 1289.140015, total balance 8511.059637
# day 1297, sell 1 unit at price 1287.229980, investment -0.148164 %, total balance 9798.289617,
# day 1300: buy 1 unit at price 1278.469971, total balance 8519.819646
# day 1301, sell 1 unit at price 1272.229980, investment -0.488083 %, total balance 9792.049626,
# day 1326: buy 1 unit at price 1289.119995, total balance 8502.929631
# day 1327, sell 1 unit at price 1285.329956, investment -0.294002 %, total balance 9788.259587,
# day 1332: buy 1 unit at price 1308.109985, total balance 8480.149602
# day 1333, sell 1 unit at price 1301.739990, investment -0.486962 %, total balance 9781.889592,
# day 1338: buy 1 unit at price 1313.209961, total balance 8468.679631
# day 1339, sell 1 unit at price 1308.119995, investment -0.387597 %, total balance 9776.799626,
# day 1342: buy 1 unit at price 1324.660034, total balance 8452.139592
# day 1343, sell 1 unit at price 1325.140015, investment 0.036234 %, total balance 9777.279607,
# day 1352: buy 1 unit at price 1262.069946, total balance 8515.209661
# day 1353, sell 1 unit at price 1256.579956, investment -0.434999 %, total balance 9771.789617,
# day 1358: buy 1 unit at price 1270.089966, total balance 8501.699651
# day 1359, sell 1 unit at price 1285.709961, investment 1.229834 %, total balance 9787.409612,
# day 1360: buy 1 unit at price 1288.219971, total balance 8499.189641
# day 1361, sell 1 unit at price 1265.290039, investment -1.779970 %, total balance 9764.479680,
# day 1364: buy 1 unit at price 1257.930054, total balance 8506.549626
# day 1365: buy 1 unit at price 1252.300049, total balance 7254.249577
# day 1366: buy 1 unit at price 1237.439941, total balance 6016.809636
# day 1367, sell 1 unit at price 1223.689941, investment -2.721941 %, total balance 7240.499577,
# day 1368: buy 1 unit at price 1230.040039, total balance 6010.459538
# day 1371, sell 1 unit at price 1240.130005, investment -0.971815 %, total balance 7250.589543,
# day 1372, sell 1 unit at price 1240.119995, investment 0.216581 %, total balance 8490.709538,
# day 1374: buy 1 unit at price 1245.599976, total balance 7245.109562
# day 1375, sell 1 unit at price 1244.500000, investment 1.175568 %, total balance 8489.609562,
# day 1376: buy 1 unit at price 1250.560059, total balance 7239.049503
# day 1377, sell 1 unit at price 1239.199951, investment -0.513811 %, total balance 8478.249454,
# day 1378: buy 1 unit at price 1246.000000, total balance 7232.249454
# day 1379, sell 1 unit at price 1272.869995, investment 1.783996 %, total balance 8505.119449,
# day 1380: buy 1 unit at price 1270.199951, total balance 7234.919498
# day 1382: buy 1 unit at price 1270.910034, total balance 5964.009464
# day 1385, sell 1 unit at price 1267.339966, investment 1.712678 %, total balance 7231.349430,
# day 1386: buy 1 unit at price 1272.430054, total balance 5958.919376
# day 1388, sell 1 unit at price 1242.280029, investment -2.198073 %, total balance 7201.199405,
# day 1389, sell 1 unit at price 1236.199951, investment -2.731120 %, total balance 8437.399356,
# day 1390, sell 1 unit at price 1234.489990, investment -2.981701 %, total balance 9671.889346,
# day 1393: buy 1 unit at price 1249.130005, total balance 8422.759341
# day 1394: buy 1 unit at price 1240.290039, total balance 7182.469302
# day 1395: buy 1 unit at price 1260.910034, total balance 5921.559268
# day 1396, sell 1 unit at price 1268.880005, investment 1.581100 %, total balance 7190.439273,
# day 1397: buy 1 unit at price 1268.400024, total balance 5922.039249
# day 1398, sell 1 unit at price 1263.199951, investment 1.847141 %, total balance 7185.239200,
# day 1400, sell 1 unit at price 1276.660034, investment 1.249098 %, total balance 8461.899234,
# day 1401, sell 1 unit at price 1270.920044, investment 0.198677 %, total balance 9732.819278,
# day 1402: buy 1 unit at price 1277.410034, total balance 8455.409244
# day 1403: buy 1 unit at price 1280.270020, total balance 7175.139224
# day 1405: buy 1 unit at price 1275.770020, total balance 5899.369204
# day 1406, sell 1 unit at price 1271.479980, investment -0.464225 %, total balance 7170.849184,
# day 1407, sell 1 unit at price 1265.949951, investment -1.118519 %, total balance 8436.799135,
# day 1408, sell 1 unit at price 1271.810059, investment -0.310398 %, total balance 9708.609194,
# day 1409: buy 1 unit at price 1266.739990, total balance 8441.869204
# day 1414, sell 1 unit at price 1302.300049, investment 2.807211 %, total balance 9744.169253,
# day 1415: buy 1 unit at price 1297.520020, total balance 8446.649233
# day 1416, sell 1 unit at price 1298.819946, investment 0.100185 %, total balance 9745.469179,
# day 1418: buy 1 unit at price 1296.060059, total balance 8449.409120
# day 1419, sell 1 unit at price 1295.089966, investment -0.074849 %, total balance 9744.499086,
# day 1430: buy 1 unit at price 1313.000000, total balance 8431.499086
# day 1431: buy 1 unit at price 1318.069946, total balance 7113.429140
# day 1432, sell 1 unit at price 1316.280029, investment 0.249812 %, total balance 8429.709169,
# day 1435, sell 1 unit at price 1317.640015, investment -0.032618 %, total balance 9747.349184,
# day 1442: buy 1 unit at price 1338.880005, total balance 8408.469179
# day 1443: buy 1 unit at price 1335.849976, total balance 7072.619203
# day 1445, sell 1 unit at price 1334.109985, investment -0.356269 %, total balance 8406.729188,
# day 1446, sell 1 unit at price 1350.199951, investment 1.074221 %, total balance 9756.929139,
# day 1464: buy 1 unit at price 1377.930054, total balance 8378.999085
# day 1465, sell 1 unit at price 1377.939941, investment 0.000718 %, total balance 9756.939026,
# day 1468: buy 1 unit at price 1364.300049, total balance 8392.638977
# day 1469, sell 1 unit at price 1379.780029, investment 1.134646 %, total balance 9772.419006,
# day 1480: buy 1 unit at price 1402.810059, total balance 8369.608947
# day 1481, sell 1 unit at price 1406.089966, investment 0.233810 %, total balance 9775.698913,
# day 1482: buy 1 unit at price 1400.949951, total balance 8374.748962
# day 1485, sell 1 unit at price 1399.479980, investment -0.104927 %, total balance 9774.228942,
# day 1487: buy 1 unit at price 1396.709961, total balance 8377.518981
# day 1488: buy 1 unit at price 1409.119995, total balance 6968.398986
# day 1490, sell 1 unit at price 1412.900024, investment 1.159157 %, total balance 8381.299010,
# day 1491, sell 1 unit at price 1407.290039, investment -0.129865 %, total balance 9788.589049,
# day 1496: buy 1 unit at price 1425.489990, total balance 8363.099059
# day 1497, sell 1 unit at price 1427.089966, investment 0.112240 %, total balance 9790.189025,
# day 1499: buy 1 unit at price 1425.550049, total balance 8364.638976
# day 1500: buy 1 unit at price 1423.530029, total balance 6941.108947
# day 1501, sell 1 unit at price 1418.300049, investment -0.508576 %, total balance 8359.408996,
# day 1502, sell 1 unit at price 1410.760010, investment -0.897067 %, total balance 9770.169006,
# day 1503: buy 1 unit at price 1416.900024, total balance 8353.268982
# day 1504, sell 1 unit at price 1426.839966, investment 0.701527 %, total balance 9780.108948,
# day 1507: buy 1 unit at price 1416.599976, total balance 8363.508972
# day 1508, sell 1 unit at price 1418.339966, investment 0.122829 %, total balance 9781.848938,
# day 1509: buy 1 unit at price 1409.709961, total balance 8372.138977
# day 1510, sell 1 unit at price 1412.839966, investment 0.222032 %, total balance 9784.978943,
# day 1515: buy 1 unit at price 1431.900024, total balance 8353.078919
# day 1516, sell 1 unit at price 1430.619995, investment -0.089394 %, total balance 9783.698914,
# day 1517: buy 1 unit at price 1426.369995, total balance 8357.328919
# day 1518, sell 1 unit at price 1430.500000, investment 0.289547 %, total balance 9787.828919,
# day 1524: buy 1 unit at price 1420.619995, total balance 8367.208924
# day 1525: buy 1 unit at price 1428.819946, total balance 6938.388978
# day 1527, sell 1 unit at price 1445.939941, investment 1.782317 %, total balance 8384.328919,
# day 1528, sell 1 unit at price 1448.390015, investment 1.369667 %, total balance 9832.718934,
# day 1531: buy 1 unit at price 1450.020020, total balance 8382.698914
# day 1532: buy 1 unit at price 1448.310059, total balance 6934.388855
# day 1533, sell 1 unit at price 1438.060059, investment -0.824814 %, total balance 8372.448914,
# day 1534, sell 1 unit at price 1433.369995, investment -1.031551 %, total balance 9805.818909,
# day 1536: buy 1 unit at price 1455.300049, total balance 8350.518860
# day 1537, sell 1 unit at price 1456.810059, investment 0.103759 %, total balance 9807.328919,
# day 1542: buy 1 unit at price 1451.189941, total balance 8356.138978
# day 1543, sell 1 unit at price 1449.369995, investment -0.125411 %, total balance 9805.508973,
# day 1549: buy 1 unit at price 1395.410034, total balance 8410.098939
# day 1550: buy 1 unit at price 1391.969971, total balance 7018.128968
# day 1552, sell 1 unit at price 1402.839966, investment 0.532455 %, total balance 8420.968934,
# day 1553, sell 1 unit at price 1406.599976, investment 1.051029 %, total balance 9827.568910,
# day 1557: buy 1 unit at price 1386.949951, total balance 8440.618959
# day 1558, sell 1 unit at price 1402.060059, investment 1.089449 %, total balance 9842.679018,
# day 1560: buy 1 unit at price 1435.040039, total balance 8407.638979
# day 1563, sell 1 unit at price 1437.500000, investment 0.171421 %, total balance 9845.138979,
# day 1570: buy 1 unit at price 1439.369995, total balance 8405.768984
# day 1571: buy 1 unit at price 1443.760010, total balance 6962.008974
# day 1572, sell 1 unit at price 1444.609985, investment 0.364047 %, total balance 8406.618959,
# day 1573, sell 1 unit at price 1448.390015, investment 0.320691 %, total balance 9855.008974,
# day 1581: buy 1 unit at price 1484.349976, total balance 8370.658998
# day 1582, sell 1 unit at price 1480.930054, investment -0.230399 %, total balance 9851.589052,
# day 1608: buy 1 unit at price 1530.229980, total balance 8321.359072
# day 1609, sell 1 unit at price 1530.619995, investment 0.025487 %, total balance 9851.979067,
# day 1618: buy 1 unit at price 1515.670044, total balance 8336.309023
# day 1619: buy 1 unit at price 1522.969971, total balance 6813.339052
# day 1621, sell 1 unit at price 1531.050049, investment 1.014733 %, total balance 8344.389101,
# day 1623, sell 1 unit at price 1512.839966, investment -0.665148 %, total balance 9857.229067,
# day 1630: buy 1 unit at price 1503.349976, total balance 8353.879091
# day 1631, sell 1 unit at price 1519.430054, investment 1.069616 %, total balance 9873.309145,
# day 1648: buy 1 unit at price 1482.660034, total balance 8390.649111
# day 1650, sell 1 unit at price 1473.910034, investment -0.590156 %, total balance 9864.559145,
# day 1655: buy 1 unit at price 1467.670044, total balance 8396.889101
# day 1656, sell 1 unit at price 1476.709961, investment 0.615937 %, total balance 9873.599062,
# day 1657: buy 1 unit at price 1497.489990, total balance 8376.109072
# day 1658, sell 1 unit at price 1453.089966, investment -2.964963 %, total balance 9829.199038,
# day 1663: buy 1 unit at price 1411.270020, total balance 8417.929018
# day 1664, sell 1 unit at price 1445.939941, investment 2.456647 %, total balance 9863.868959,
# day 1669: buy 1 unit at price 1479.369995, total balance 8384.498964
# day 1670, sell 1 unit at price 1466.790039, investment -0.850359 %, total balance 9851.289003,
# day 1673: buy 1 unit at price 1457.640015, total balance 8393.648988
# day 1675, sell 1 unit at price 1489.420044, investment 2.180239 %, total balance 9883.069032,
# day 1683: buy 1 unit at price 1484.250000, total balance 8398.819032
# day 1684, sell 1 unit at price 1476.650024, investment -0.512042 %, total balance 9875.469056,
# day 1687: buy 1 unit at price 1518.750000, total balance 8356.719056
# day 1691: buy 1 unit at price 1525.420044, total balance 6831.299012
# day 1692: buy 1 unit at price 1531.380005, total balance 5299.919007
# day 1693, sell 1 unit at price 1526.750000, investment 0.526749 %, total balance 6826.669007,
# day 1695, sell 1 unit at price 1546.630005, investment 1.390434 %, total balance 8373.299012,
# day 1696, sell 1 unit at price 1539.589966, investment 0.536115 %, total balance 9912.888978,
# day 1703: buy 1 unit at price 1561.800049, total balance 8351.088929
# day 1704, sell 1 unit at price 1548.709961, investment -0.838141 %, total balance 9899.798890,
# day 1713: buy 1 unit at price 1535.280029, total balance 8364.518861
# day 1714: buy 1 unit at price 1540.979980, total balance 6823.538881
# day 1716, sell 1 unit at price 1549.380005, investment 0.918398 %, total balance 8372.918886,
# day 1717, sell 1 unit at price 1508.439941, investment -2.111646 %, total balance 9881.358827,
# day 1720: buy 1 unit at price 1520.270020, total balance 8361.088807
# day 1722, sell 1 unit at price 1474.770020, investment -2.992889 %, total balance 9835.858827,
# day 1723: buy 1 unit at price 1453.699951, total balance 8382.158876
# day 1728, sell 1 unit at price 1458.739990, investment 0.346704 %, total balance 9840.898866,
# day 1729: buy 1 unit at price 1433.270020, total balance 8407.628846
# day 1731, sell 1 unit at price 1416.770020, investment -1.151214 %, total balance 9824.398866,
# day 1736: buy 1 unit at price 1469.719971, total balance 8354.678895
# day 1737, sell 1 unit at price 1481.140015, investment 0.777022 %, total balance 9835.818910,
# day 1761: buy 1 unit at price 1416.180054, total balance 8419.638856
# day 1762, sell 1 unit at price 1390.189941, investment -1.835227 %, total balance 9809.828797,
# day 1763: buy 1 unit at price 1409.130005, total balance 8400.698792
# day 1764: buy 1 unit at price 1420.329956, total balance 6980.368836
# day 1765, sell 1 unit at price 1401.020020, investment -0.575531 %, total balance 8381.388856,
# day 1766, sell 1 unit at price 1416.250000, investment -0.287254 %, total balance 9797.638856,
# ...
# day 3105, sell 1 unit at price 1626.670044, investment -0.368710 %, total balance 9269.339112,
# day 3123: buy 1 unit at price 1608.900024, total balance 7660.439088
# day 3124, sell 1 unit at price 1622.560059, investment 0.849029 %, total balance 9282.999147,
# day 3128: buy 1 unit at price 1612.520020, total balance 7670.479127
# day 3129: buy 1 unit at price 1636.359985, total balance 6034.119142
# day 3130, sell 1 unit at price 1626.729980, investment 0.881227 %, total balance 7660.849122,
# day 3131: buy 1 unit at price 1639.040039, total balance 6021.809083
# day 3132: buy 1 unit at price 1651.810059, total balance 4369.999024
# day 3133: buy 1 unit at price 1628.930054, total balance 2741.068970
# day 3134, sell 1 unit at price 1588.189941, investment -2.943731 %, total balance 4329.258911,
# day 3135, sell 1 unit at price 1592.430054, investment -2.843737 %, total balance 5921.688965,
# day 3137, sell 1 unit at price 1588.030029, investment -3.861221 %, total balance 7509.718994,
# day 3138, sell 1 unit at price 1603.260010, investment -1.575884 %, total balance 9112.979004,
# day 3150: buy 1 unit at price 1682.500000, total balance 7430.479004
# day 3151, sell 1 unit at price 1676.260010, investment -0.370876 %, total balance 9106.739014,
# day 3170: buy 1 unit at price 1689.469971, total balance 7417.269043
# day 3171, sell 1 unit at price 1694.160034, investment 0.277606 %, total balance 9111.429077,
# day 3178: buy 1 unit at price 1656.959961, total balance 7454.469116
# day 3180, sell 1 unit at price 1656.780029, investment -0.010859 %, total balance 9111.249145,
# day 3185: buy 1 unit at price 1639.770020, total balance 7471.479125
# day 3186, sell 1 unit at price 1653.079956, investment 0.811695 %, total balance 9124.559081,
# day 3188: buy 1 unit at price 1655.170044, total balance 7469.389037
# day 3189: buy 1 unit at price 1671.709961, total balance 5797.679076
# day 3190: buy 1 unit at price 1683.989990, total balance 4113.689086
# day 3192, sell 1 unit at price 1683.420044, investment 1.706773 %, total balance 5797.109130,
# day 3193, sell 1 unit at price 1687.989990, investment 0.973855 %, total balance 7485.099120,
# day 3194, sell 1 unit at price 1697.599976, investment 0.808199 %, total balance 9182.699096,
# day 3197: buy 1 unit at price 1722.339966, total balance 7460.359130
# day 3198, sell 1 unit at price 1709.910034, investment -0.721689 %, total balance 9170.269164,
# day 3205: buy 1 unit at price 1695.000000, total balance 7475.269164
# day 3207, sell 1 unit at price 1678.660034, investment -0.964010 %, total balance 9153.929198,
# day 3212: buy 1 unit at price 1692.560059, total balance 7461.369139
# day 3214: buy 1 unit at price 1710.140015, total balance 5751.229124
# day 3218, sell 1 unit at price 1744.500000, investment 3.068721 %, total balance 7495.729124,
# day 3219: buy 1 unit at price 1744.660034, total balance 5751.069090
# day 3220, sell 1 unit at price 1754.670044, investment 2.603882 %, total balance 7505.739134,
# day 3222, sell 1 unit at price 1752.069946, investment 0.424720 %, total balance 9257.809080,
# day 3223: buy 1 unit at price 1759.770020, total balance 7498.039060
# day 3224, sell 1 unit at price 1762.109985, investment 0.132970 %, total balance 9260.149045,
# day 3238: buy 1 unit at price 1798.180054, total balance 7461.968991
# day 3239, sell 1 unit at price 1791.530029, investment -0.369820 %, total balance 9253.499020,
# day 3240: buy 1 unit at price 1787.869995, total balance 7465.629025
# day 3241, sell 1 unit at price 1781.369995, investment -0.363561 %, total balance 9246.999020,
# day 3242: buy 1 unit at price 1795.849976, total balance 7451.149044
# day 3243, sell 1 unit at price 1804.760010, investment 0.496146 %, total balance 9255.909054,
# day 3250: buy 1 unit at price 1792.810059, total balance 7463.098995
# day 3251, sell 1 unit at price 1785.030029, investment -0.433957 %, total balance 9248.129024,
# day 3257: buy 1 unit at price 1775.319946, total balance 7472.809078
# day 3260, sell 1 unit at price 1810.650024, investment 1.990068 %, total balance 9283.459102,
# day 3267: buy 1 unit at price 1841.069946, total balance 7442.389156
# day 3268, sell 1 unit at price 1848.359985, investment 0.395968 %, total balance 9290.749141,
# day 3273: buy 1 unit at price 1837.489990, total balance 7453.259151
# day 3274, sell 1 unit at price 1838.130005, investment 0.034831 %, total balance 9291.389156,
# day 3275: buy 1 unit at price 1842.369995, total balance 7449.019161
# day 3276, sell 1 unit at price 1819.199951, investment -1.257622 %, total balance 9268.219112,
# day 3289: buy 1 unit at price 1782.589966, total balance 7485.629146
# day 3290, sell 1 unit at price 1741.890015, investment -2.283192 %, total balance 9227.519161,
# day 3292: buy 1 unit at price 1751.640015, total balance 7475.879146
# day 3294, sell 1 unit at price 1797.020020, investment 2.590715 %, total balance 9272.899166,
# day 3301: buy 1 unit at price 1828.750000, total balance 7444.149166
# day 3302, sell 1 unit at price 1839.780029, investment 0.603146 %, total balance 9283.929195,
# day 3304: buy 1 unit at price 1847.609985, total balance 7436.319210
# day 3305, sell 1 unit at price 1845.119995, investment -0.134768 %, total balance 9281.439205,
# day 3306: buy 1 unit at price 1845.160034, total balance 7436.279171
# day 3307: buy 1 unit at price 1854.290039, total balance 5581.989132
# day 3308, sell 1 unit at price 1859.449951, investment 0.774454 %, total balance 7441.439083,
# day 3309: buy 1 unit at price 1845.729980, total balance 5595.709103
# day 3310, sell 1 unit at price 1873.910034, investment 1.058087 %, total balance 7469.619137,
# day 3311, sell 1 unit at price 1873.810059, investment 1.521354 %, total balance 9343.429196,
# day 3317: buy 1 unit at price 1846.339966, total balance 7497.089230
# day 3318, sell 1 unit at price 1841.130005, investment -0.282178 %, total balance 9338.219235,
# day 3328: buy 1 unit at price 1857.619995, total balance 7480.599240
# day 3329, sell 1 unit at price 1872.339966, investment 0.792410 %, total balance 9352.939206,
# day 3339: buy 1 unit at price 1830.609985, total balance 7522.329221
# day 3340, sell 1 unit at price 1842.979980, investment 0.675731 %, total balance 9365.309201,
# day 3354: buy 1 unit at price 1867.719971, total balance 7497.589230
# day 3355, sell 1 unit at price 1878.209961, investment 0.561647 %, total balance 9375.799191,
# day 3378: buy 1 unit at price 1950.790039, total balance 7425.009152
# day 3380, sell 1 unit at price 1930.109985, investment -1.060086 %, total balance 9355.119137,
# day 3404: buy 1 unit at price 1958.119995, total balance 7396.999142
# day 3405: buy 1 unit at price 1978.219971, total balance 5418.779171
# day 3406, sell 1 unit at price 1973.630005, investment 0.792087 %, total balance 7392.409176,
# day 3407: buy 1 unit at price 1983.530029, total balance 5408.879147
# day 3408, sell 1 unit at price 1987.010010, investment 0.444341 %, total balance 7395.889157,
# day 3409, sell 1 unit at price 1987.979980, investment 0.224345 %, total balance 9383.869137,
# day 3420: buy 1 unit at price 1931.589966, total balance 7452.279171
# day 3422, sell 1 unit at price 1933.750000, investment 0.111827 %, total balance 9386.029171,
# day 3427: buy 1 unit at price 1981.599976, total balance 7404.429195
# day 3428, sell 1 unit at price 1986.510010, investment 0.247781 %, total balance 9390.939205,
# day 3430: buy 1 unit at price 1988.400024, total balance 7402.539181
# day 3431, sell 1 unit at price 1997.920044, investment 0.478778 %, total balance 9400.459225,
# day 3436: buy 1 unit at price 2002.280029, total balance 7398.179196
# day 3437, sell 1 unit at price 2000.719971, investment -0.077914 %, total balance 9398.899167,
# day 3438: buy 1 unit at price 1997.650024, total balance 7401.249143
# day 3440, sell 1 unit at price 2001.540039, investment 0.194730 %, total balance 9402.789182,
# day 3446: buy 1 unit at price 1998.979980, total balance 7403.809202
# day 3448, sell 1 unit at price 2011.359985, investment 0.619316 %, total balance 9415.169187,
# day 3452: buy 1 unit at price 1998.300049, total balance 7416.869138
# day 3453: buy 1 unit at price 1965.989990, total balance 5450.879148
# day 3454, sell 1 unit at price 1982.849976, investment -0.773161 %, total balance 7433.729124,
# day 3455, sell 1 unit at price 1977.800049, investment 0.600718 %, total balance 9411.529173,
# day 3457: buy 1 unit at price 1946.160034, total balance 7465.369139
# day 3458: buy 1 unit at price 1946.170044, total balance 5519.199095
# day 3459, sell 1 unit at price 1967.900024, investment 1.117071 %, total balance 7487.099119,
# day 3460: buy 1 unit at price 1964.819946, total balance 5522.279173
# day 3463, sell 1 unit at price 1928.209961, investment -0.922842 %, total balance 7450.489134,
# day 3465, sell 1 unit at price 1874.739990, investment -4.584642 %, total balance 9325.229124,
# day 3470: buy 1 unit at price 1904.010010, total balance 7421.219114
# day 3471, sell 1 unit at price 1941.280029, investment 1.957449 %, total balance 9362.499143,
# day 3476: buy 1 unit at price 1985.050049, total balance 7377.449094
# day 3477, sell 1 unit at price 1982.300049, investment -0.138536 %, total balance 9359.749143,
# day 3479: buy 1 unit at price 2018.050049, total balance 7341.699094
# day 3480, sell 1 unit at price 2017.810059, investment -0.011892 %, total balance 9359.509153,
# day 3481: buy 1 unit at price 2012.099976, total balance 7347.409177
# day 3482, sell 1 unit at price 2023.569946, investment 0.570050 %, total balance 9370.979123,
# day 3489: buy 1 unit at price 2039.819946, total balance 7331.159177
# day 3491: buy 1 unit at price 2051.800049, total balance 5279.359128
# day 3492, sell 1 unit at price 2048.719971, investment 0.436314 %, total balance 7328.079099,
# day 3494, sell 1 unit at price 2063.500000, investment 0.570229 %, total balance 9391.579099,
# day 3507: buy 1 unit at price 2035.329956, total balance 7356.249143
# day 3508: buy 1 unit at price 2002.329956, total balance 5353.919187
# day 3511: buy 1 unit at price 2012.890015, total balance 3341.029172
# day 3512, sell 1 unit at price 2061.229980, investment 1.272522 %, total balance 5402.259152,
# day 3515, sell 1 unit at price 2082.169922, investment 3.987353 %, total balance 7484.429074,
# day 3516, sell 1 unit at price 2081.879883, investment 3.427404 %, total balance 9566.308957,
# day 3517: buy 1 unit at price 2088.770020, total balance 7477.538937
# day 3518: buy 1 unit at price 2090.570068, total balance 5386.968869
# day 3520, sell 1 unit at price 2058.899902, investment -1.430034 %, total balance 7445.868771,
# day 3521, sell 1 unit at price 2058.199951, investment -1.548387 %, total balance 9504.068722,
# day 3522: buy 1 unit at price 2020.579956, total balance 7483.488766
# day 3524, sell 1 unit at price 2025.900024, investment 0.263294 %, total balance 9509.388790,
# day 3526: buy 1 unit at price 2044.810059, total balance 7464.578731
# day 3527, sell 1 unit at price 2028.260010, investment -0.809369 %, total balance 9492.838741,
# day 3533: buy 1 unit at price 2032.119995, total balance 7460.718746
# day 3534, sell 1 unit at price 2063.149902, investment 1.526972 %, total balance 9523.868648,
# day 3546: buy 1 unit at price 2046.739990, total balance 7477.128658
# day 3548, sell 1 unit at price 2068.530029, investment 1.064622 %, total balance 9545.658687,
# day 3549: buy 1 unit at price 2088.479980, total balance 7457.178707
# day 3551, sell 1 unit at price 2100.340088, investment 0.567882 %, total balance 9557.518795,
# day 3552: buy 1 unit at price 2099.679932, total balance 7457.838863
# day 3553, sell 1 unit at price 2097.449951, investment -0.106206 %, total balance 9555.288814,
# day 3554: buy 1 unit at price 2110.300049, total balance 7444.988765
# day 3555, sell 1 unit at price 2109.659912, investment -0.030334 %, total balance 9554.648677,
# day 3567: buy 1 unit at price 2040.239990, total balance 7514.408687
# day 3568, sell 1 unit at price 2065.949951, investment 1.260144 %, total balance 9580.358638,
# day 3572: buy 1 unit at price 2099.500000, total balance 7480.858638
# day 3573, sell 1 unit at price 2089.270020, investment -0.487258 %, total balance 9570.128658,
# day 3574: buy 1 unit at price 2108.100098, total balance 7462.028560
# day 3576, sell 1 unit at price 2091.500000, investment -0.787444 %, total balance 9553.528560,
# day 3581: buy 1 unit at price 2067.889893, total balance 7485.638667
# day 3582, sell 1 unit at price 2059.689941, investment -0.396537 %, total balance 9545.328608,
# day 3583: buy 1 unit at price 2066.959961, total balance 7478.368647
# day 3584, sell 1 unit at price 2080.620117, investment 0.660882 %, total balance 9558.988764,
# day 3594: buy 1 unit at price 2100.399902, total balance 7458.588862
# day 3595, sell 1 unit at price 2097.290039, investment -0.148061 %, total balance 9555.878901,
# day 3606: buy 1 unit at price 2080.149902, total balance 7475.728999
# day 3607, sell 1 unit at price 2088.000000, investment 0.377381 %, total balance 9563.728999,
# day 3612: buy 1 unit at price 2121.100098, total balance 7442.628901
# day 3613, sell 1 unit at price 2122.729980, investment 0.076841 %, total balance 9565.358881,
# day 3620: buy 1 unit at price 2123.479980, total balance 7441.878901
# day 3621, sell 1 unit at price 2120.790039, investment -0.126676 %, total balance 9562.668940,
# day 3622: buy 1 unit at price 2107.389893, total balance 7455.279047
# day 3623, sell 1 unit at price 2111.729980, investment 0.205946 %, total balance 9567.009027,
# day 3624: buy 1 unit at price 2109.600098, total balance 7457.408929
# day 3625, sell 1 unit at price 2114.070068, investment 0.211887 %, total balance 9571.478997,
# day 3632: buy 1 unit at price 2094.110107, total balance 7477.368890
# day 3635, sell 1 unit at price 2100.439941, investment 0.302268 %, total balance 9577.808831,
# day 3646: buy 1 unit at price 2076.780029, total balance 7501.028802
# day 3648, sell 1 unit at price 2081.340088, investment 0.219574 %, total balance 9582.368890,
# day 3657: buy 1 unit at price 2128.280029, total balance 7454.088861
# day 3658: buy 1 unit at price 2119.209961, total balance 5334.878900
# day 3661, sell 1 unit at price 2079.649902, investment -2.284950 %, total balance 7414.528802,
# day 3662, sell 1 unit at price 2067.639893, investment -2.433457 %, total balance 9482.168695,
# day 3669: buy 1 unit at price 2099.840088, total balance 7382.328607
# day 3670, sell 1 unit at price 2083.560059, investment -0.775299 %, total balance 9465.888666,
# day 3677: buy 1 unit at price 2102.439941, total balance 7363.448725
# day 3678, sell 1 unit at price 2096.919922, investment -0.262553 %, total balance 9460.368647,
# day 3684: buy 1 unit at price 1940.510010, total balance 7519.858637
# day 3685, sell 1 unit at price 1987.660034, investment 2.429775 %, total balance 9507.518671,
# day 3686: buy 1 unit at price 1988.869995, total balance 7518.648676
# day 3687, sell 1 unit at price 1972.180054, investment -0.839167 %, total balance 9490.828730,
# day 3695: buy 1 unit at price 1961.050049, total balance 7529.778681
# day 3698: buy 1 unit at price 1995.310059, total balance 5534.468622
# day 3701, sell 1 unit at price 1966.969971, investment 0.301875 %, total balance 7501.438593,
# day 3702, sell 1 unit at price 1942.739990, investment -2.634682 %, total balance 9444.178583,
# day 3707: buy 1 unit at price 1884.089966, total balance 7560.088617
# day 3708, sell 1 unit at price 1920.030029, investment 1.907556 %, total balance 9480.118646,
# day 3719: buy 1 unit at price 2023.859985, total balance 7456.258661
# day 3720, sell 1 unit at price 2033.109985, investment 0.457047 %, total balance 9489.368646,
# day 3726: buy 1 unit at price 2071.179932, total balance 7418.188714
# day 3730, sell 1 unit at price 2079.360107, investment 0.394952 %, total balance 9497.548821,
# day 3731: buy 1 unit at price 2104.050049, total balance 7393.498772
# day 3732, sell 1 unit at price 2109.790039, investment 0.272807 %, total balance 9503.288811,
# day 3756: buy 1 unit at price 2063.590088, total balance 7439.698723
# day 3757, sell 1 unit at price 2047.619995, investment -0.773899 %, total balance 9487.318718,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
