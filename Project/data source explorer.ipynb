# %% [markdown]
# https://www.alphavantage.co/documentation/#
#
# #### Alpha Advantage API Key: VVLO0LVEKD59PF4Y

# %%
import alpha_vantage as alpha
import numpy as np
import pandas as pd

# %%
from alpha_vantage.timeseries import TimeSeries
ts = TimeSeries(key='VVLO0LVEKD59PF4Y', output_format='pandas')
# Get json object with the intraday data and another with  the call's metadata
data, meta_data = ts.get_intraday('GOOGL')

# %%
data
# Out:
#                        1. open    2. high     3. low   4. close  5. volume
# date
# 2019-11-18 16:00:00  1319.6400  1319.7600  1316.2400  1319.5700   197496.0
# 2019-11-18 15:45:00  1321.7700  1322.2000  1319.8800  1320.0300    42623.0
# 2019-11-18 15:30:00  1322.7800  1322.7800  1320.9250  1321.7500    37189.0
# 2019-11-18 15:15:00  1323.8936  1323.8936  1322.1899  1323.1600    24520.0
# 2019-11-18 15:00:00  1324.5300  1324.7000  1323.1600  1323.4300    22417.0
# ...                        ...        ...        ...        ...        ...
# 2019-11-13 11:45:00  1296.1500  1299.8000  1296.1500  1299.3544    29611.0
# 2019-11-13 11:30:00  1297.4200  1298.9000  1296.8600  1296.9500    21278.0
# 2019-11-13 11:15:00  1300.0200  1300.0200  1297.0150  1297.2209    26335.0
# 2019-11-13 11:00:00  1300.6000  1301.3900  1299.3700  1299.6300    18828.0
# 2019-11-13 10:45:00  1301.3253  1302.5200  1299.2800  1300.4700    29512.0
#
# [100 rows x 5 columns]

# %%
from alpha_vantage.timeseries import TimeSeries
from pprint import pprint
ts = TimeSeries(key='YOUR_API_KEY', output_format='pandas')
data, meta_data = ts.get_intraday(symbol='MSFT',interval='1min', outputsize='full')
pprint(data)
# Out:
#                      1. open  2. high   3. low  4. close  5. volume
# date
# 2019-11-18 16:00:00  150.340  150.340  150.340  150.3400   490723.0
# 2019-11-18 15:59:00  150.150  150.190  150.144  150.1750   117147.0
# 2019-11-18 15:58:00  150.120  150.170  150.100  150.1500   386884.0
# 2019-11-18 15:57:00  150.205  150.225  150.110  150.1200   107184.0
# 2019-11-18 15:56:00  150.250  150.280  150.170  150.2050    83459.0
# ...                      ...      ...      ...       ...        ...
# 2019-11-12 09:37:00  146.540  146.670  146.540  146.6002   223454.0
# 2019-11-12 09:34:00  146.490  146.580  146.475  146.5600    46685.0
# 2019-11-12 09:33:00  146.340  146.520  146.290  146.4900   102807.0
# 2019-11-12 09:32:00  146.250  146.414  146.245  146.3100    64718.0
# 2019-11-12 09:31:00  146.280  146.420  146.190  146.2700   499860.0
#
# [1927 rows x 5 columns]

# %%
from alpha_vantage.timeseries import TimeSeries
import matplotlib.pyplot as plt

ts = TimeSeries(key='YOUR_API_KEY', output_format='pandas')
data, meta_data = ts.get_intraday(symbol='MSFT',interval='1min', outputsize='full')
data['4. close'].plot()
plt.title('Intraday Times Series for the MSFT stock (1 min)')
plt.show()

# %%
data, meta_data = ts.get_batch_stock_quotes(['GOOGL', 'TSLA'])
data
# Out:
#                               1. symbol   2. price 3. volume  \
# date
# 1970-01-01 00:00:00.000000000     GOOGL  1317.9800        --
# 1970-01-01 00:00:00.000000001      TSLA   350.0000        --
#
#                                       4. timestamp
# date
# 1970-01-01 00:00:00.000000000  2019-11-18 15:59:52
# 1970-01-01 00:00:00.000000001  2019-11-18 15:59:57

# %%
data, meta_data = ts.get_daily_adjusted('IBM', outputsize='full')
data
# Out:
#             1. open   2. high   3. low  4. close  5. adjusted close  \
# date
# 2019-11-18  134.300  134.4800  133.230   134.310           134.3100
# 2019-11-15  134.390  135.1200  134.030   134.400           134.4000
# 2019-11-14  134.130  134.3300  133.330   134.000           134.0000
# 2019-11-13  135.390  135.5800  133.850   134.480           134.4800
# 2019-11-12  135.870  136.6600  135.020   135.590           135.5900
# ...             ...       ...      ...       ...                ...
# 1999-11-26  105.938  106.0000  104.125   105.000            69.1653
# 1999-11-24  105.000  104.9953  101.813   104.500            68.8360
# 1999-11-23  108.813  109.8750  106.000   106.063            69.8652
# 1999-11-22  105.500  108.4321  104.438   107.875            71.0591
# 1999-11-19   99.000  105.1250   98.375   103.938            68.4655
#
#              6. volume  7. dividend amount  8. split coefficient
# date
# 2019-11-18   3035480.0                 0.0                   1.0
# ...

# %%
from alpha_vantage.sectorperformance import SectorPerformances
import matplotlib.pyplot as plt

sp = SectorPerformances(key='YOUR_API_KEY', output_format='pandas')
data, meta_data = sp.get_sector()
data['Rank A: Real-Time Performance'].plot(kind='bar')
plt.title('Real Time Performance (%) per Sector')
plt.tight_layout()
plt.grid()
plt.show()
