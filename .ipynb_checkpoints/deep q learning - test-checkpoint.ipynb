# %% [markdown]
# #### objective
# 1. understand algo
# 2. re-read paper and understand "online-training" and other technical nuances
# 3. think about data
# 4. (optional) set up AWS
# 5. (optional) backtester

# %%
import numpy as np
import pandas as pd
# import tensorflow as tf
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
import matplotlib.pyplot as plt
import seaborn as sns
# from tensorflow.python.framework import ops
tf.disable_v2_behavior()
sns.set()
# Out:
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow_core/python/compat/v2_compat.py:65: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
df_hsi = pd.read_csv('^HSI.csv')[['Date', 'Adj Close']]
df_spx = pd.read_csv('^GSPC.csv')[['Date', 'Adj Close']]
df_hsi.rename(columns={'Adj Close':'hsi'}, inplace=True)
df_spx.rename(columns={'Adj Close':'spx'}, inplace=True)
df = df_hsi.merge(df_spx, on='Date').dropna()

# %%
df = pd.read_csv('^GSPC.csv')[['Date', 'Close']]

# %%
from collections import deque
import random


class Agent:
    def __init__(self, state_size, window_size, trend, skip, batch_size):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.action_size = 3
        self.batch_size = batch_size
        self.memory = deque(maxlen = 1000)
        self.inventory = []

        self.gamma = 0.95
        self.epsilon = 0.5
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.999

        tf.reset_default_graph()
        self.sess = tf.InteractiveSession()
        self.X = tf.placeholder(tf.float32, [None, self.state_size])
        self.Y = tf.placeholder(tf.float32, [None, self.action_size])
        feed = tf.layers.dense(self.X, 256, activation = tf.nn.relu)
        self.logits = tf.layers.dense(feed, self.action_size)
        self.cost = tf.reduce_mean(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.GradientDescentOptimizer(1e-5).minimize(
            self.cost
        )
        self.sess.run(tf.global_variables_initializer())

    def act(self, state):
        if random.random() <= self.epsilon:
            return random.randrange(self.action_size)
        return np.argmax(
            self.sess.run(self.logits, feed_dict = {self.X: state})[0] # pick action that maximizes logits (through forward pass)
        )
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])

    def replay(self, batch_size):
        mini_batch = []
        l = len(self.memory)
        for i in range(l - batch_size, l):
            mini_batch.append(self.memory[i])
        replay_size = len(mini_batch)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.action_size))
        states = np.array([a[0][0] for a in mini_batch])
        new_states = np.array([a[3][0] for a in mini_batch])
        Q = self.sess.run(self.logits, feed_dict = {self.X: states})
        Q_new = self.sess.run(self.logits, feed_dict = {self.X: new_states})
        for i in range(len(mini_batch)):
            state, action, reward, next_state, done = mini_batch[i]
            target = Q[i]
            target[action] = reward
            if not done:
                target[action] += self.gamma * np.amax(Q_new[i])
            X[i] = state
            Y[i] = target
        cost, _ = self.sess.run(
            [self.cost, self.optimizer], feed_dict = {self.X: X, self.Y: Y}
        )
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
        return cost
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
                
                
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
        
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.act(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                self.memory.append((state, action, invest, 
                                    next_state, starting_money < initial_money))
                state = next_state
                batch_size = min(self.batch_size, len(self.memory))
                cost = self.replay(batch_size)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip, 
              batch_size = batch_size)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# WARNING:tensorflow:From <ipython-input-33-9934fc4f9176>:26: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow_core/python/client/session.py:1750: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# epoch: 10, total rewards: 1457.188427.3, cost: 0.901230, total money: 11457.188427
# epoch: 20, total rewards: 715.967289.3, cost: 0.379903, total money: 10715.967289
# epoch: 30, total rewards: -222.922963.3, cost: 0.250127, total money: 9777.077037
# epoch: 40, total rewards: -135.422915.3, cost: 0.171314, total money: 9864.577085
# epoch: 50, total rewards: -581.773313.3, cost: 0.116008, total money: 9418.226687
# epoch: 60, total rewards: -737.003230.3, cost: 0.096853, total money: 9262.996770
# epoch: 70, total rewards: -233.333063.3, cost: 0.066392, total money: 9766.666937
# epoch: 80, total rewards: 0.577214.3, cost: 0.068149, total money: 10000.577214
# epoch: 90, total rewards: -15.033203.3, cost: 0.065281, total money: 9984.966797
# epoch: 100, total rewards: 176.366213.3, cost: 0.059152, total money: 10176.366213
# epoch: 110, total rewards: -368.252310.3, cost: 0.042479, total money: 9631.747690
# epoch: 120, total rewards: 172.756779.3, cost: 0.043364, total money: 10172.756779
# epoch: 130, total rewards: -666.543643.3, cost: 0.027971, total money: 9333.456357
# epoch: 140, total rewards: -417.672485.3, cost: 0.028345, total money: 9582.327515
# epoch: 150, total rewards: 248.836796.3, cost: 0.035331, total money: 10248.836796
# epoch: 160, total rewards: -177.443851.3, cost: 0.022993, total money: 9822.556149
# epoch: 170, total rewards: -540.952451.3, cost: 0.019613, total money: 9459.047549
# epoch: 180, total rewards: -198.143738.3, cost: 0.017383, total money: 9801.856262
# epoch: 190, total rewards: 730.976197.3, cost: 0.021998, total money: 10730.976197
# epoch: 200, total rewards: 637.646613.3, cost: 0.021310, total money: 10637.646613

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 2: buy 1 unit at price 1333.339966, total balance 8666.660034
# day 3, sell 1 unit at price 1298.349976, investment -2.624236 %, total balance 9965.010010,
# day 4: buy 1 unit at price 1295.859985, total balance 8669.150025
# day 6, sell 1 unit at price 1313.270020, investment 1.343512 %, total balance 9982.420045,
# day 9: buy 1 unit at price 1326.650024, total balance 8655.770021
# day 10: buy 1 unit at price 1329.469971, total balance 7326.300050
# day 11: buy 1 unit at price 1347.969971, total balance 5978.330079
# day 12, sell 1 unit at price 1342.540039, investment 1.197755 %, total balance 7320.870118,
# day 13: buy 1 unit at price 1342.900024, total balance 5977.970094
# day 14: buy 1 unit at price 1360.400024, total balance 4617.570070
# day 15, sell 1 unit at price 1364.300049, investment 2.619847 %, total balance 5981.870119,
# day 16, sell 1 unit at price 1357.510010, investment 0.707734 %, total balance 7339.380129,
# day 17: buy 1 unit at price 1354.949951, total balance 5984.430178
# day 19, sell 1 unit at price 1373.729980, investment 2.295774 %, total balance 7358.160158,
# day 21: buy 1 unit at price 1373.469971, total balance 5984.690187
# day 22, sell 1 unit at price 1349.469971, investment -0.803444 %, total balance 7334.160158,
# day 23: buy 1 unit at price 1354.310059, total balance 5979.850099
# day 24: buy 1 unit at price 1352.260010, total balance 4627.590089
# day 25, sell 1 unit at price 1340.890015, investment -1.037672 %, total balance 5968.480104,
# day 27, sell 1 unit at price 1314.760010, investment -4.274572 %, total balance 7283.240114,
# day 28, sell 1 unit at price 1330.310059, investment -1.772120 %, total balance 8613.550173,
# day 29: buy 1 unit at price 1318.800049, total balance 7294.750124
# day 30: buy 1 unit at price 1315.920044, total balance 5978.830080
# day 31: buy 1 unit at price 1326.609985, total balance 4652.220095
# day 32: buy 1 unit at price 1301.530029, total balance 3350.690066
# day 33: buy 1 unit at price 1278.939941, total balance 2071.750125
# day 34, sell 1 unit at price 1255.270020, investment -7.172436 %, total balance 3327.020145,
# day 36: buy 1 unit at price 1245.859985, total balance 2081.160160
# day 38: buy 1 unit at price 1257.939941, total balance 823.220219
# day 44, sell 1 unit at price 1261.890015, investment -4.315289 %, total balance 2085.110234,
# day 45, sell 1 unit at price 1264.739990, investment -3.889298 %, total balance 3349.850224,
# day 46: buy 1 unit at price 1233.420044, total balance 2116.430180
# day 47, sell 1 unit at price 1180.160034, investment -11.039413 %, total balance 3296.590214,
# day 48, sell 1 unit at price 1197.660034, investment -7.980607 %, total balance 4494.250248,
# day 50: buy 1 unit at price 1173.560059, total balance 3320.690189
# day 51, sell 1 unit at price 1150.530029, investment -10.040339 %, total balance 4471.220218,
# day 53, sell 1 unit at price 1142.619995, investment -8.286645 %, total balance 5613.840213,
# day 54, sell 1 unit at price 1122.140015, investment -10.795422 %, total balance 6735.980228,
# day 57: buy 1 unit at price 1152.689941, total balance 5583.290287
# day 58, sell 1 unit at price 1182.170044, investment -4.155113 %, total balance 6765.460331,
# day 59: buy 1 unit at price 1153.290039, total balance 5612.170292
# day 61, sell 1 unit at price 1160.329956, investment -1.127348 %, total balance 6772.500248,
# day 62, sell 1 unit at price 1145.869995, investment -0.591655 %, total balance 7918.370243,
# day 63, sell 1 unit at price 1106.459961, investment -4.060564 %, total balance 9024.830204,
# day 64: buy 1 unit at price 1103.250000, total balance 7921.580204
# day 65: buy 1 unit at price 1151.439941, total balance 6770.140263
# day 67: buy 1 unit at price 1137.589966, total balance 5632.550297
# day 68, sell 1 unit at price 1168.380005, investment 5.903467 %, total balance 6800.930302,
# day 70, sell 1 unit at price 1183.500000, investment 2.784345 %, total balance 7984.430302,
# day 71, sell 1 unit at price 1179.680054, investment 3.699935 %, total balance 9164.110356,
# day 76: buy 1 unit at price 1224.359985, total balance 7939.750371
# day 78, sell 1 unit at price 1228.750000, investment 0.358556 %, total balance 9168.500371,
# day 83: buy 1 unit at price 1267.430054, total balance 7901.070317
# day 84, sell 1 unit at price 1248.579956, investment -1.487269 %, total balance 9149.650273,
# day 90: buy 1 unit at price 1245.670044, total balance 7903.980229
# day 93, sell 1 unit at price 1284.989990, investment 3.156530 %, total balance 9188.970219,
# day 95: buy 1 unit at price 1291.959961, total balance 7897.010258
# day 96, sell 1 unit at price 1312.829956, investment 1.615375 %, total balance 9209.840214,
# day 97: buy 1 unit at price 1309.380005, total balance 7900.460209
# day 98, sell 1 unit at price 1289.050049, investment -1.552640 %, total balance 9189.510258,
# day 99: buy 1 unit at price 1293.170044, total balance 7896.340214
# day 101, sell 1 unit at price 1267.930054, investment -1.951792 %, total balance 9164.270268,
# day 102: buy 1 unit at price 1248.079956, total balance 7916.190312
# day 103, sell 1 unit at price 1255.819946, investment 0.620152 %, total balance 9172.010258,
# day 108: buy 1 unit at price 1276.959961, total balance 7895.050297
# day 109, sell 1 unit at price 1264.959961, investment -0.939732 %, total balance 9160.010258,
# day 114: buy 1 unit at price 1214.359985, total balance 7945.650273
# day 116, sell 1 unit at price 1212.579956, investment -0.146582 %, total balance 9158.230229,
# day 117: buy 1 unit at price 1223.140015, total balance 7935.090214
# day 119: buy 1 unit at price 1225.349976, total balance 6709.740238
# day 121, sell 1 unit at price 1216.760010, investment -0.521609 %, total balance 7926.500248,
# day 122, sell 1 unit at price 1211.069946, investment -1.165384 %, total balance 9137.570194,
# day 124: buy 1 unit at price 1224.380005, total balance 7913.190189
# day 125, sell 1 unit at price 1236.719971, investment 1.007854 %, total balance 9149.910160,
# day 129: buy 1 unit at price 1198.780029, total balance 7951.130131
# day 130: buy 1 unit at price 1181.520020, total balance 6769.610111
# day 131: buy 1 unit at price 1180.180054, total balance 5589.430057
# day 133, sell 1 unit at price 1215.680054, investment 1.409769 %, total balance 6805.110111,
# day 134: buy 1 unit at price 1202.449951, total balance 5602.660160
# day 135, sell 1 unit at price 1214.439941, investment 2.786235 %, total balance 6817.100101,
# day 137, sell 1 unit at price 1215.020020, investment 2.952089 %, total balance 8032.120121,
# day 138: buy 1 unit at price 1210.849976, total balance 6821.270145
# day 139, sell 1 unit at price 1191.030029, investment -0.949721 %, total balance 8012.300174,
# day 140, sell 1 unit at price 1171.650024, investment -3.237391 %, total balance 9183.950198,
# day 142: buy 1 unit at price 1202.930054, total balance 7981.020144
# day 143: buy 1 unit at price 1205.819946, total balance 6775.200198
# day 144: buy 1 unit at price 1204.520020, total balance 5570.680178
# day 145, sell 1 unit at price 1211.229980, investment 0.689976 %, total balance 6781.910158,
# day 146: buy 1 unit at price 1215.930054, total balance 5565.980104
# day 147: buy 1 unit at price 1220.750000, total balance 4345.230104
# day 148, sell 1 unit at price 1214.349976, investment 0.707405 %, total balance 5559.580080,
# day 149: buy 1 unit at price 1200.479980, total balance 4359.100100
# day 151: buy 1 unit at price 1183.530029, total balance 3175.570071
# day 152, sell 1 unit at price 1183.430054, investment -1.750902 %, total balance 4359.000125,
# day 153: buy 1 unit at price 1190.160034, total balance 3168.840091
# day 154, sell 1 unit at price 1191.290039, investment -2.026434 %, total balance 4360.130130,
# day 155, sell 1 unit at price 1186.729980, investment -2.786813 %, total balance 5546.860110,
# day 158: buy 1 unit at price 1161.969971, total balance 4384.890139
# day 162: buy 1 unit at price 1162.089966, total balance 3222.800173
# day 163, sell 1 unit at price 1184.930054, investment -1.295309 %, total balance 4407.730227,
# day 164: buy 1 unit at price 1179.209961, total balance 3228.520266
# day 165: buy 1 unit at price 1161.510010, total balance 2067.010256
# day 166, sell 1 unit at price 1148.560059, investment -2.954718 %, total balance 3215.570315,
# day 167: buy 1 unit at price 1129.030029, total balance 2086.540286
# day 168, sell 1 unit at price 1133.579956, investment -4.753989 %, total balance 3220.120242,
# day 170: buy 1 unit at price 1131.739990, total balance 2088.380252
# day 171: buy 1 unit at price 1106.400024, total balance 981.980228
# day 173, sell 1 unit at price 1092.540039, investment -5.975192 %, total balance 2074.520267,
# day 174: buy 1 unit at price 1038.770020, total balance 1035.750247
# day 175: buy 1 unit at price 1032.739990, total balance 3.010257
# day 177, sell 1 unit at price 984.539978, investment -15.278506 %, total balance 987.550235,
# day 178: buy 1 unit at price 965.799988, total balance 21.750247
# day 179, sell 1 unit at price 1003.450012, investment -14.904890 %, total balance 1025.200259,
# day 180: buy 1 unit at price 1012.270020, total balance 12.930239
# day 181, sell 1 unit at price 1007.039978, investment -13.299070 %, total balance 1019.970217,
# day 182, sell 1 unit at price 1018.609985, investment -9.780080 %, total balance 2038.580202,
# day 183: buy 1 unit at price 1040.939941, total balance 997.640261
# day 184, sell 1 unit at price 1038.550049, investment -8.234218 %, total balance 2036.190310,
# day 186: buy 1 unit at price 1072.280029, total balance 963.910281
# day 187, sell 1 unit at price 1069.630005, investment -3.323393 %, total balance 2033.540286,
# day 188, sell 1 unit at price 1071.380005, investment 3.139288 %, total balance 3104.920291,
# day 189, sell 1 unit at price 1062.439941, investment 2.875840 %, total balance 4167.360232,
# day 191, sell 1 unit at price 1080.989990, investment 11.926900 %, total balance 5248.350222,
# day 192, sell 1 unit at price 1097.430054, investment 8.412778 %, total balance 6345.780276,
# day 193, sell 1 unit at price 1091.650024, investment 4.871567 %, total balance 7437.430300,
# day 194: buy 1 unit at price 1089.979980, total balance 6347.450320
# day 196: buy 1 unit at price 1077.089966, total balance 5270.360354
# day 197: buy 1 unit at price 1068.609985, total balance 4201.750369
# day 198, sell 1 unit at price 1073.479980, investment 0.111906 %, total balance 5275.230349,
# day 199, sell 1 unit at price 1089.900024, investment -0.007336 %, total balance 6365.130373,
# day 200, sell 1 unit at price 1084.780029, investment 0.713967 %, total balance 7449.910402,
# day 201, sell 1 unit at price 1085.199951, investment 1.552481 %, total balance 8535.110353,
# day 205: buy 1 unit at price 1059.790039, total balance 7475.320314
# day 206, sell 1 unit at price 1059.780029, investment -0.000945 %, total balance 8535.100343,
# day 208: buy 1 unit at price 1087.199951, total balance 7447.900392
# day 209, sell 1 unit at price 1102.839966, investment 1.438559 %, total balance 8550.740358,
# day 211: buy 1 unit at price 1115.800049, total balance 7434.940309
# day 212, sell 1 unit at price 1118.540039, investment 0.245563 %, total balance 8553.480348,
# day 213: buy 1 unit at price 1120.310059, total balance 7433.170289
# day 214, sell 1 unit at price 1118.329956, investment -0.176746 %, total balance 8551.500245,
# day 217: buy 1 unit at price 1142.239990, total balance 7409.260255
# day 218, sell 1 unit at price 1138.650024, investment -0.314292 %, total balance 8547.910279,
# day 221: buy 1 unit at price 1137.030029, total balance 7410.880250
# day 222: buy 1 unit at price 1150.339966, total balance 6260.540284
# day 224, sell 1 unit at price 1149.500000, investment 1.096714 %, total balance 7410.040284,
# day 225: buy 1 unit at price 1128.520020, total balance 6281.520264
# day 226, sell 1 unit at price 1140.199951, investment -0.881480 %, total balance 7421.720215,
# day 227: buy 1 unit at price 1139.449951, total balance 6282.270264
# day 228: buy 1 unit at price 1129.900024, total balance 5152.370240
# day 229, sell 1 unit at price 1144.800049, investment 1.442600 %, total balance 6297.170289,
# day 230, sell 1 unit at price 1170.349976, investment 2.711837 %, total balance 7467.520265,
# day 231: buy 1 unit at price 1167.099976, total balance 6300.420289
# day 233, sell 1 unit at price 1139.930054, investment 0.887692 %, total balance 7440.350343,
# day 234, sell 1 unit at price 1136.760010, investment -2.599603 %, total balance 8577.110353,
# day 236: buy 1 unit at price 1119.380005, total balance 7457.730348
# day 237, sell 1 unit at price 1123.089966, investment 0.331430 %, total balance 8580.820314,
# day 242: buy 1 unit at price 1144.890015, total balance 7435.930299
# day 243: buy 1 unit at price 1144.650024, total balance 6291.280275
# day 244, sell 1 unit at price 1149.369995, investment 0.391302 %, total balance 7440.650270,
# day 245, sell 1 unit at price 1157.130005, investment 1.090288 %, total balance 8597.780275,
# day 247: buy 1 unit at price 1148.079956, total balance 7449.700319
# day 248, sell 1 unit at price 1154.670044, investment 0.574009 %, total balance 8604.370363,
# day 253: buy 1 unit at price 1155.140015, total balance 7449.230348
# day 254, sell 1 unit at price 1156.550049, investment 0.122066 %, total balance 8605.780397,
# day 255: buy 1 unit at price 1145.599976, total balance 7460.180421
# day 256: buy 1 unit at price 1138.410034, total balance 6321.770387
# day 257, sell 1 unit at price 1146.189941, investment 0.051498 %, total balance 7467.960328,
# day 259: buy 1 unit at price 1138.880005, total balance 6329.080323
# day 260, sell 1 unit at price 1127.579956, investment -0.951334 %, total balance 7456.660279,
# day 261, sell 1 unit at price 1119.310059, investment -1.718350 %, total balance 8575.970338,
# day 264: buy 1 unit at price 1133.280029, total balance 7442.690309
# day 267, sell 1 unit at price 1113.569946, investment -1.739207 %, total balance 8556.260255,
# day 269: buy 1 unit at price 1122.199951, total balance 7434.060304
# day 270, sell 1 unit at price 1094.439941, investment -2.473713 %, total balance 8528.500245,
# day 272: buy 1 unit at price 1083.510010, total balance 7444.990235
# day 273, sell 1 unit at price 1080.170044, investment -0.308254 %, total balance 8525.160279,
# day 274: buy 1 unit at price 1096.219971, total balance 7428.940308
# day 275: buy 1 unit at price 1111.939941, total balance 6317.000367
# day 276: buy 1 unit at price 1107.500000, total balance 5209.500367
# day 277: buy 1 unit at price 1118.510010, total balance 4090.990357
# day 278, sell 1 unit at price 1116.479980, investment 1.848170 %, total balance 5207.470337,
# day 279, sell 1 unit at price 1104.180054, investment -0.697869 %, total balance 6311.650391,
# day 280, sell 1 unit at price 1083.339966, investment -2.181493 %, total balance 7394.990357,
# day 281, sell 1 unit at price 1097.979980, investment -1.835480 %, total balance 8492.970337,
# day 282: buy 1 unit at price 1080.949951, total balance 7412.020386
# day 285: buy 1 unit at price 1109.380005, total balance 6302.640381
# day 286: buy 1 unit at price 1109.890015, total balance 5192.750366
# day 287, sell 1 unit at price 1106.729980, investment 2.384942 %, total balance 6299.480346,
# day 290, sell 1 unit at price 1146.140015, investment 3.313563 %, total balance 7445.620361,
# day 291, sell 1 unit at price 1162.770020, investment 4.764437 %, total balance 8608.390381,
# day 292: buy 1 unit at price 1157.540039, total balance 7450.850342
# day 293, sell 1 unit at price 1164.310059, investment 0.584863 %, total balance 8615.160401,
# day 300: buy 1 unit at price 1170.290039, total balance 7444.870362
# day 302, sell 1 unit at price 1153.589966, investment -1.427003 %, total balance 8598.460328,
# day 303: buy 1 unit at price 1148.699951, total balance 7449.760377
# day 306, sell 1 unit at price 1144.579956, investment -0.358666 %, total balance 8594.340333,
# day 307: buy 1 unit at price 1147.390015, total balance 7446.950318
# day 308, sell 1 unit at price 1146.540039, investment -0.074079 %, total balance 8593.490357,
# day 309: buy 1 unit at price 1136.760010, total balance 7456.730347
# day 310, sell 1 unit at price 1125.400024, investment -0.999330 %, total balance 8582.130371,
# day 311: buy 1 unit at price 1126.339966, total balance 7455.790405
# day 312, sell 1 unit at price 1122.729980, investment -0.320506 %, total balance 8578.520385,
# day 318: buy 1 unit at price 1102.550049, total balance 7475.970336
# day 320: buy 1 unit at price 1126.069946, total balance 6349.900390
# day 323: buy 1 unit at price 1107.829956, total balance 5242.070434
# day 324, sell 1 unit at price 1100.959961, investment -0.144219 %, total balance 6343.030395,
# day 325, sell 1 unit at price 1093.140015, investment -2.924324 %, total balance 7436.170410,
# day 326, sell 1 unit at price 1091.479980, investment -1.475856 %, total balance 8527.650390,
# day 327: buy 1 unit at price 1076.319946, total balance 7451.330444
# day 328, sell 1 unit at price 1065.449951, investment -1.009922 %, total balance 8516.780395,
# day 330: buy 1 unit at price 1086.459961, total balance 7430.320434
# day 331: buy 1 unit at price 1084.560059, total balance 6345.760375
# day 332, sell 1 unit at price 1073.430054, investment -1.199299 %, total balance 7419.190429,
# day 333: buy 1 unit at price 1052.670044, total balance 6366.520385
# day 334: buy 1 unit at price 1049.489990, total balance 5317.030395
# day 335: buy 1 unit at price 1088.849976, total balance 4228.180419
# day 337, sell 1 unit at price 1054.989990, investment -2.726457 %, total balance 5283.170409,
# day 338: buy 1 unit at price 1074.560059, total balance 4208.610350
# day 339, sell 1 unit at price 1097.280029, investment 4.237794 %, total balance 5305.890379,
# day 341: buy 1 unit at price 1098.229980, total balance 4207.660399
# day 342, sell 1 unit at price 1106.589966, investment 5.440736 %, total balance 5314.250365,
# day 343, sell 1 unit at price 1091.880005, investment 0.278278 %, total balance 6406.130370,
# day 345: buy 1 unit at price 1086.020020, total balance 5320.110350
# day 346, sell 1 unit at price 1097.079956, investment 2.095732 %, total balance 6417.190306,
# day 347, sell 1 unit at price 1083.819946, investment -1.312114 %, total balance 7501.010252,
# day 352, sell 1 unit at price 1040.680054, investment -4.174874 %, total balance 8541.690306,
# day 356: buy 1 unit at price 1027.530029, total balance 7514.160277
# day 357, sell 1 unit at price 1030.739990, investment 0.312396 %, total balance 8544.900267,
# day 363: buy 1 unit at price 1037.140015, total balance 7507.760252
# day 364, sell 1 unit at price 1019.989990, investment -1.653588 %, total balance 8527.750242,
# day 365: buy 1 unit at price 1006.289978, total balance 7521.460264
# day 366, sell 1 unit at price 989.140015, investment -1.704276 %, total balance 8510.600279,
# day 368: buy 1 unit at price 976.140015, total balance 7534.460264
# day 369: buy 1 unit at price 973.530029, total balance 6560.930235
# day 370, sell 1 unit at price 990.640015, investment 1.485443 %, total balance 7551.570250,
# day 372: buy 1 unit at price 968.650024, total balance 6582.920226
# day 373: buy 1 unit at price 948.090027, total balance 5634.830199
# day 375: buy 1 unit at price 989.030029, total balance 4645.800170
# day 376: buy 1 unit at price 976.979980, total balance 3668.820190
# day 377, sell 1 unit at price 952.830017, investment -2.126284 %, total balance 4621.650207,
# day 378, sell 1 unit at price 920.469971, investment -4.973938 %, total balance 5542.120178,
# day 380: buy 1 unit at price 921.390015, total balance 4620.730163
# day 382: buy 1 unit at price 900.940002, total balance 3719.790161
# day 383, sell 1 unit at price 906.039978, investment -4.435238 %, total balance 4625.830139,
# day 384: buy 1 unit at price 881.559998, total balance 3744.270141
# day 385: buy 1 unit at price 847.750000, total balance 2896.520141
# day 386, sell 1 unit at price 819.849976, investment -17.105654 %, total balance 3716.370117,
# day 388: buy 1 unit at price 843.429993, total balance 2872.940124
# day 390, sell 1 unit at price 852.840027, investment -12.706499 %, total balance 3725.780151,
# day 391: buy 1 unit at price 898.960022, total balance 2826.820129
# day 392: buy 1 unit at price 902.780029, total balance 1924.040100
# day 393, sell 1 unit at price 911.619995, investment -1.060357 %, total balance 2835.660095,
# day 394: buy 1 unit at price 884.659973, total balance 1951.000122
# day 395, sell 1 unit at price 864.239990, investment -4.073525 %, total balance 2815.240112,
# day 396: buy 1 unit at price 834.599976, total balance 1980.640136
# day 398, sell 1 unit at price 876.770020, investment -0.543352 %, total balance 2857.410156,
# day 399: buy 1 unit at price 905.460022, total balance 1951.950134
# day 401, sell 1 unit at price 903.799988, investment 6.611618 %, total balance 2855.750122,
# day 403: buy 1 unit at price 919.619995, total balance 1936.130127
# day 404: buy 1 unit at price 930.250000, total balance 1005.880127
# day 405, sell 1 unit at price 928.770020, investment 10.118211 %, total balance 1934.650147,
# day 406: buy 1 unit at price 950.700012, total balance 983.950135
# day 407: buy 1 unit at price 937.429993, total balance 46.520142
# day 409, sell 1 unit at price 962.700012, investment 7.090414 %, total balance 1009.220154,
# day 410: buy 1 unit at price 940.859985, total balance 68.360169
# day 411, sell 1 unit at price 947.950012, investment 5.003432 %, total balance 1016.310181,
# day 412, sell 1 unit at price 934.820007, investment 5.669979 %, total balance 1951.130188,
# day 413, sell 1 unit at price 917.869995, investment 9.977237 %, total balance 2869.000183,
# day 414: buy 1 unit at price 917.799988, total balance 1951.200195
# day 415, sell 1 unit at price 916.070007, investment 1.171778 %, total balance 2867.270202,
# day 416: buy 1 unit at price 878.020020, total balance 1989.250182
# day 419, sell 1 unit at price 893.919983, investment -2.794634 %, total balance 2883.170165,
# day 420: buy 1 unit at price 902.960022, total balance 1980.210143
# day 421, sell 1 unit at price 909.580017, investment -2.221982 %, total balance 2889.790160,
# day 422, sell 1 unit at price 909.450012, investment -4.338908 %, total balance 3799.240172,
# day 425, sell 1 unit at price 891.099976, investment -4.942238 %, total balance 4690.340148,
# day 427: buy 1 unit at price 869.460022, total balance 3820.880126
# day 429, sell 1 unit at price 845.390015, investment -10.147096 %, total balance 4666.270141,
# day 430, sell 1 unit at price 833.700012, investment -9.163214 %, total balance 5499.970153,
# day 431, sell 1 unit at price 819.289978, investment -6.688918 %, total balance 6319.260131,
# day 432, sell 1 unit at price 839.659973, investment -7.010283 %, total balance 7158.920104,
# day 434: buy 1 unit at price 827.369995, total balance 6331.550109
# day 435, sell 1 unit at price 815.280029, investment -6.231453 %, total balance 7146.830138,
# day 436, sell 1 unit at price 847.909973, investment 2.482563 %, total balance 7994.740111,
# day 437: buy 1 unit at price 827.909973, total balance 7166.830138
# day 438, sell 1 unit at price 818.950012, investment -1.082239 %, total balance 7985.780150,
# day 442: buy 1 unit at price 776.760010, total balance 7209.020140
# day 443: buy 1 unit at price 803.919983, total balance 6405.100157
# day 444: buy 1 unit at price 835.320007, total balance 5569.780150
# day 445, sell 1 unit at price 841.440002, investment 8.326895 %, total balance 6411.220152,
# day 447: buy 1 unit at price 860.020020, total balance 5551.200132
# day 448: buy 1 unit at price 879.200012, total balance 4672.000120
# day 449, sell 1 unit at price 884.390015, investment 10.009707 %, total balance 5556.390135,
# day 450, sell 1 unit at price 899.719971, investment 7.709616 %, total balance 6456.110106,
# day 451: buy 1 unit at price 890.159973, total balance 5565.950133
# day 452: buy 1 unit at price 896.140015, total balance 4669.810118
# day 453, sell 1 unit at price 882.500000, investment 2.613890 %, total balance 5552.310118,
# day 455, sell 1 unit at price 890.229980, investment 1.254546 %, total balance 6442.540098,
# day 456, sell 1 unit at price 882.150024, investment -0.899833 %, total balance 7324.690122,
# day 457: buy 1 unit at price 890.710022, total balance 6433.980100
# day 458: buy 1 unit at price 885.760010, total balance 5548.220090
# day 459: buy 1 unit at price 900.960022, total balance 4647.260068
# day 460, sell 1 unit at price 908.349976, investment 1.362506 %, total balance 5555.610044,
# day 461: buy 1 unit at price 915.390015, total balance 4640.220029
# day 462: buy 1 unit at price 923.760010, total balance 3716.460019
# day 463: buy 1 unit at price 902.650024, total balance 2813.809995
# day 464: buy 1 unit at price 894.739990, total balance 1919.070005
# day 465, sell 1 unit at price 876.190002, investment -1.630162 %, total balance 2795.260007,
# day 466, sell 1 unit at price 882.950012, investment -0.317241 %, total balance 3678.210019,
# day 468: buy 1 unit at price 904.270020, total balance 2773.939999
# day 469: buy 1 unit at price 909.830017, total balance 1864.109982
# day 471: buy 1 unit at price 896.739990, total balance 967.369992
# day 473, sell 1 unit at price 933.760010, investment 3.640560 %, total balance 1901.130002,
# day 474: buy 1 unit at price 930.549988, total balance 970.580014
# day 476: buy 1 unit at price 913.309998, total balance 57.270016
# day 487, sell 1 unit at price 901.580017, investment -1.508646 %, total balance 958.850033,
# day 488, sell 1 unit at price 889.479980, investment -3.710924 %, total balance 1848.330013,
# day 489: buy 1 unit at price 910.400024, total balance 937.929989
# day 490: buy 1 unit at price 902.989990, total balance 34.939999
# day 491, sell 1 unit at price 891.119995, investment -1.277353 %, total balance 926.059994,
# day 492: buy 1 unit at price 884.250000, total balance 41.809994
# day 493, sell 1 unit at price 895.760010, investment 0.114002 %, total balance 937.570004,
# day 494: buy 1 unit at price 897.380005, total balance 40.189999
# day 496, sell 1 unit at price 889.659973, investment -1.615673 %, total balance 929.849972,
# day 497: buy 1 unit at price 875.400024, total balance 54.449948
# day 498, sell 1 unit at price 879.390015, investment -3.345680 %, total balance 933.839963,
# day 501, sell 1 unit at price 908.590027, investment 1.321457 %, total balance 1842.429990,
# day 502, sell 1 unit at price 929.010010, investment -0.165491 %, total balance 2771.440000,
# day 503: buy 1 unit at price 922.929993, total balance 1848.510007
# day 505, sell 1 unit at price 927.570007, investment 1.561355 %, total balance 2776.080014,
# day 506, sell 1 unit at price 927.570007, investment 1.885982 %, total balance 3703.650021,
# day 508: buy 1 unit at price 931.659973, total balance 2771.990048
# day 509, sell 1 unit at price 918.219971, investment 1.686617 %, total balance 3690.210019,
# day 511, sell 1 unit at price 901.780029, investment 1.982474 %, total balance 4591.990048,
# day 512, sell 1 unit at price 887.619995, investment -1.087612 %, total balance 5479.610043,
# day 513, sell 1 unit at price 878.359985, investment 0.338127 %, total balance 6357.970028,
# day 514: buy 1 unit at price 887.340027, total balance 5470.630001
# day 515, sell 1 unit at price 861.400024, investment -6.666808 %, total balance 6332.030025,
# day 516, sell 1 unit at price 847.479980, investment -9.035485 %, total balance 7179.510005,
# day 517, sell 1 unit at price 858.539978, investment -3.245661 %, total balance 8038.049983,
# day 518: buy 1 unit at price 864.359985, total balance 7173.689998
# day 519, sell 1 unit at price 844.609985, investment -2.284928 %, total balance 8018.299983,
# day 521: buy 1 unit at price 860.320007, total balance 7157.979976
# day 522: buy 1 unit at price 848.200012, total balance 6309.779964
# day 523, sell 1 unit at price 843.590027, investment -1.944623 %, total balance 7153.369991,
# day 524, sell 1 unit at price 838.150024, investment -1.184861 %, total balance 7991.520015,
# day 528: buy 1 unit at price 818.679993, total balance 7172.840022
# day 529: buy 1 unit at price 817.369995, total balance 6355.470027
# day 530, sell 1 unit at price 834.890015, investment 1.980019 %, total balance 7190.360042,
# day 531: buy 1 unit at price 851.169983, total balance 6339.190059
# day 533: buy 1 unit at price 837.099976, total balance 5502.090083
# day 534: buy 1 unit at price 848.169983, total balance 4653.920100
# day 536, sell 1 unit at price 838.570007, investment 2.593686 %, total balance 5492.490107,
# day 537: buy 1 unit at price 827.549988, total balance 4664.940119
# day 538, sell 1 unit at price 837.280029, investment -1.631866 %, total balance 5502.220148,
# day 539, sell 1 unit at price 841.150024, investment 0.483819 %, total balance 6343.370172,
# day 540, sell 1 unit at price 834.809998, investment -1.575154 %, total balance 7178.180170,
# day 541, sell 1 unit at price 821.989990, investment -0.671862 %, total balance 8000.170160,
# day 547: buy 1 unit at price 804.190002, total balance 7195.980158
# day 548, sell 1 unit at price 831.900024, investment 3.445706 %, total balance 8027.880182,
# day 549: buy 1 unit at price 833.270020, total balance 7194.610162
# day 551: buy 1 unit at price 866.450012, total balance 6328.160150
# day 553: buy 1 unit at price 875.669983, total balance 5452.490167
# day 554, sell 1 unit at price 895.789978, investment 7.502965 %, total balance 6348.280145,
# day 555, sell 1 unit at price 864.229980, investment -0.256222 %, total balance 7212.510125,
# day 556: buy 1 unit at price 874.739990, total balance 6337.770135
# day 558, sell 1 unit at price 868.520020, investment -0.816513 %, total balance 7206.290155,
# day 559: buy 1 unit at price 863.500000, total balance 6342.790155
# day 560, sell 1 unit at price 848.179993, investment -3.036330 %, total balance 7190.970148,
# day 561: buy 1 unit at price 858.479980, total balance 6332.490168
# day 564, sell 1 unit at price 878.849976, investment 1.777646 %, total balance 7211.340144,
# day 565: buy 1 unit at price 879.929993, total balance 6331.410151
# day 566: buy 1 unit at price 878.289978, total balance 5453.120173
# day 567, sell 1 unit at price 865.989990, investment 0.874803 %, total balance 6319.110163,
# day 568: buy 1 unit at price 871.580017, total balance 5447.530146
# day 571, sell 1 unit at price 890.809998, investment 1.236463 %, total balance 6338.340144,
# day 576: buy 1 unit at price 919.020020, total balance 5419.320124
# day 577, sell 1 unit at price 911.429993, investment 3.773243 %, total balance 6330.750117,
# day 578, sell 1 unit at price 898.809998, investment 3.124209 %, total balance 7229.560115,
# day 579, sell 1 unit at price 914.840027, investment -0.454832 %, total balance 8144.400142,
# day 584: buy 1 unit at price 926.549988, total balance 7217.850154
# day 586: buy 1 unit at price 929.619995, total balance 6288.230159
# day 587, sell 1 unit at price 920.270020, investment -0.677780 %, total balance 7208.500179,
# day 589, sell 1 unit at price 945.109985, investment 1.666271 %, total balance 8153.610164,
# day 591: buy 1 unit at price 939.280029, total balance 7214.330135
# day 592: buy 1 unit at price 946.669983, total balance 6267.660152
# day 593: buy 1 unit at price 944.299988, total balance 5323.360164
# day 594, sell 1 unit at price 920.770020, investment -1.970659 %, total balance 6244.130184,
# day 597, sell 1 unit at price 931.869995, investment -1.563374 %, total balance 7176.000179,
# day 598, sell 1 unit at price 933.219971, investment -1.173358 %, total balance 8109.220150,
# day 600: buy 1 unit at price 953.219971, total balance 7156.000179
# day 601, sell 1 unit at price 949.640015, investment -0.375565 %, total balance 8105.640194,
# day 607: buy 1 unit at price 987.760010, total balance 7117.880184
# day 609, sell 1 unit at price 984.840027, investment -0.295617 %, total balance 8102.720211,
# day 613: buy 1 unit at price 1010.739990, total balance 7091.980221
# day 614, sell 1 unit at price 1011.659973, investment 0.091021 %, total balance 8103.640194,
# day 625: buy 1 unit at price 993.750000, total balance 7109.890194
# day 626, sell 1 unit at price 985.700012, investment -0.810062 %, total balance 8095.590206,
# day 634: buy 1 unit at price 994.090027, total balance 7101.500179
# day 636: buy 1 unit at price 993.320007, total balance 6108.180172
# day 639: buy 1 unit at price 988.609985, total balance 5119.570187
# day 640: buy 1 unit at price 981.599976, total balance 4137.970211
# day 641, sell 1 unit at price 998.679993, investment 0.461725 %, total balance 5136.650204,
# day 642: buy 1 unit at price 996.520020, total balance 4140.130184
# day 643: buy 1 unit at price 989.280029, total balance 3150.850155
# day 646, sell 1 unit at price 980.150024, investment -1.325855 %, total balance 4131.000179,
# day 647, sell 1 unit at price 982.820007, investment -0.585669 %, total balance 5113.820186,
# day 650, sell 1 unit at price 974.119995, investment -0.762019 %, total balance 6087.940181,
# day 652, sell 1 unit at price 980.590027, investment -1.598562 %, total balance 7068.530208,
# day 653, sell 1 unit at price 990.349976, investment 0.108154 %, total balance 8058.880184,
# day 656: buy 1 unit at price 990.669983, total balance 7068.210201
# day 657: buy 1 unit at price 999.739990, total balance 6068.470211
# day 659, sell 1 unit at price 1000.299988, investment 0.972070 %, total balance 7068.770199,
# day 660: buy 1 unit at price 1003.270020, total balance 6065.500179
# day 661: buy 1 unit at price 993.059998, total balance 5072.440181
# day 662, sell 1 unit at price 993.710022, investment -0.603154 %, total balance 6066.150203,
# day 663, sell 1 unit at price 996.729980, investment -0.651872 %, total balance 7062.880183,
# day 664: buy 1 unit at price 996.789978, total balance 6066.090205
# day 665: buy 1 unit at price 1002.840027, total balance 5063.250178
# day 667: buy 1 unit at price 1021.989990, total balance 4041.260188
# day 668: buy 1 unit at price 1026.270020, total balance 3014.990168
# day 669: buy 1 unit at price 1027.969971, total balance 1987.020197
# day 670: buy 1 unit at price 1021.390015, total balance 965.630182
# day 671, sell 1 unit at price 1031.640015, investment 3.884963 %, total balance 1997.270197,
# day 672: buy 1 unit at price 1023.169983, total balance 974.100214
# day 673, sell 1 unit at price 1010.919983, investment 1.417551 %, total balance 1985.020197,
# day 674, sell 1 unit at price 1016.419983, investment 1.354150 %, total balance 3001.440180,
# day 675, sell 1 unit at price 1018.630005, investment -0.328769 %, total balance 4020.070185,
# day 676, sell 1 unit at price 1014.809998, investment -1.116667 %, total balance 5034.880183,
# day 677, sell 1 unit at price 1029.319946, investment 0.131324 %, total balance 6064.200129,
# day 678, sell 1 unit at price 1025.969971, investment 0.448404 %, total balance 7090.170100,
# day 679: buy 1 unit at price 1039.579956, total balance 6050.590144
# day 680: buy 1 unit at price 1036.300049, total balance 5014.290095
# day 681, sell 1 unit at price 1022.820007, investment -0.034205 %, total balance 6037.110102,
# day 682, sell 1 unit at price 1029.030029, investment -1.014826 %, total balance 7066.140131,
# day 683: buy 1 unit at price 1009.380005, total balance 6056.760126
# day 685, sell 1 unit at price 996.849976, investment -3.806820 %, total balance 7053.610102,
# day 686, sell 1 unit at price 1006.580017, investment -0.277397 %, total balance 8060.190119,
# day 687: buy 1 unit at price 995.969971, total balance 7064.220148
# day 688, sell 1 unit at price 1018.219971, investment 2.234003 %, total balance 8082.440119,
# day 691: buy 1 unit at price 1034.349976, total balance 7048.090143
# day 693: buy 1 unit at price 1033.780029, total balance 6014.310114
# day 694, sell 1 unit at price 1038.729980, investment 0.423455 %, total balance 7053.040094,
# day 696: buy 1 unit at price 1045.349976, total balance 6007.690118
# day 697: buy 1 unit at price 1049.479980, total balance 4958.210138
# day 699: buy 1 unit at price 1050.069946, total balance 3908.140192
# day 700, sell 1 unit at price 1039.319946, investment 0.535889 %, total balance 4947.460138,
# day 702: buy 1 unit at price 1046.030029, total balance 3901.430109
# day 703, sell 1 unit at price 1030.359985, investment -1.433969 %, total balance 4931.790094,
# day 704, sell 1 unit at price 1033.770020, investment -1.496928 %, total balance 5965.560114,
# day 705: buy 1 unit at price 1028.910034, total balance 4936.650080
# day 706: buy 1 unit at price 1031.130005, total balance 3905.520075
# day 707, sell 1 unit at price 1046.790039, investment -0.312351 %, total balance 4952.310114,
# day 708: buy 1 unit at price 1048.109985, total balance 3904.200129
# day 709: buy 1 unit at price 1046.939941, total balance 2857.260188
# day 710: buy 1 unit at price 1050.709961, total balance 1806.550227
# day 711: buy 1 unit at price 1059.020020, total balance 747.530207
# day 712, sell 1 unit at price 1053.250000, investment 0.690226 %, total balance 1800.780207,
# day 713: buy 1 unit at price 1051.810059, total balance 748.970148
# day 715, sell 1 unit at price 1053.209961, investment 2.361715 %, total balance 1802.180109,
# day 716, sell 1 unit at price 1047.109985, investment 1.549754 %, total balance 2849.290094,
# day 717: buy 1 unit at price 1046.569946, total balance 1802.720148
# day 718, sell 1 unit at price 1058.530029, investment 0.994175 %, total balance 2861.250177,
# day 719: buy 1 unit at price 1058.410034, total balance 1802.840143
# day 720, sell 1 unit at price 1050.349976, investment 0.325714 %, total balance 2853.190119,
# day 723: buy 1 unit at price 1042.439941, total balance 1810.750178
# day 724: buy 1 unit at price 1033.650024, total balance 777.100154
# day 725, sell 1 unit at price 1035.280029, investment -1.468524 %, total balance 1812.380183,
# day 726, sell 1 unit at price 1052.079956, investment -0.655329 %, total balance 2864.460139,
# day 727: buy 1 unit at price 1053.890015, total balance 1810.570124
# day 728, sell 1 unit at price 1058.449951, investment 0.631282 %, total balance 2869.020075,
# day 729: buy 1 unit at price 1058.199951, total balance 1810.820124
# day 730: buy 1 unit at price 1070.119995, total balance 740.700129
# day 733, sell 1 unit at price 1069.719971, investment 2.211990 %, total balance 1810.420100,
# day 734, sell 1 unit at price 1061.500000, investment 0.291944 %, total balance 2871.920100,
# day 735, sell 1 unit at price 1069.300049, investment 2.576658 %, total balance 3941.220149,
# day 738, sell 1 unit at price 1071.209961, investment 3.633719 %, total balance 5012.430110,
# day 739, sell 1 unit at price 1074.140015, investment 1.921453 %, total balance 6086.570125,
# day 740: buy 1 unit at price 1068.040039, total balance 5018.530086
# day 743: buy 1 unit at price 1089.180054, total balance 3929.350032
# day 744: buy 1 unit at price 1088.660034, total balance 2840.689998
# day 745, sell 1 unit at price 1092.939941, investment 3.282932 %, total balance 3933.629939,
# day 747, sell 1 unit at price 1094.040039, investment 2.235267 %, total balance 5027.669978,
# day 748: buy 1 unit at price 1095.890015, total balance 3931.779963
# day 749, sell 1 unit at price 1109.479980, investment 3.879999 %, total balance 5041.259943,
# day 750, sell 1 unit at price 1109.640015, investment 1.878474 %, total balance 6150.899958,
# day 751, sell 1 unit at price 1111.920044, investment 2.136572 %, total balance 7262.820002,
# day 753, sell 1 unit at price 1122.219971, investment 2.402609 %, total balance 8385.039973,
# day 755: buy 1 unit at price 1126.329956, total balance 7258.710017
# day 756, sell 1 unit at price 1131.920044, investment 0.496310 %, total balance 8390.630061,
# day 757: buy 1 unit at price 1121.859985, total balance 7268.770076
# day 759: buy 1 unit at price 1121.219971, total balance 6147.550105
# day 760, sell 1 unit at price 1130.520020, investment 0.771935 %, total balance 7278.070125,
# day 761, sell 1 unit at price 1132.050049, investment 0.965919 %, total balance 8410.120174,
# day 768: buy 1 unit at price 1144.050049, total balance 7266.070125
# day 769, sell 1 unit at price 1128.479980, investment -1.360960 %, total balance 8394.550105,
# day 775: buy 1 unit at price 1128.589966, total balance 7265.960139
# day 776: buy 1 unit at price 1142.760010, total balance 6123.200129
# day 778, sell 1 unit at price 1145.540039, investment 1.501881 %, total balance 7268.740168,
# day 780: buy 1 unit at price 1152.109985, total balance 6116.630183
# day 781, sell 1 unit at price 1145.810059, investment 0.266902 %, total balance 7262.440242,
# day 782, sell 1 unit at price 1156.989990, investment 0.423571 %, total balance 8419.430232,
# day 784: buy 1 unit at price 1147.060059, total balance 7272.370173
# day 785: buy 1 unit at price 1144.109985, total balance 6128.260188
# day 787, sell 1 unit at price 1139.089966, investment -0.694828 %, total balance 7267.350154,
# day 788, sell 1 unit at price 1143.670044, investment -0.038453 %, total balance 8411.020198,
# day 789: buy 1 unit at price 1144.910034, total balance 7266.110164
# day 790, sell 1 unit at price 1144.939941, investment 0.002612 %, total balance 8411.050105,
# day 794: buy 1 unit at price 1154.869995, total balance 7256.180110
# day 795, sell 1 unit at price 1156.859985, investment 0.172313 %, total balance 8413.040095,
# day 796: buy 1 unit at price 1147.199951, total balance 7265.840144
# day 797: buy 1 unit at price 1140.579956, total balance 6125.260188
# day 798, sell 1 unit at price 1123.890015, investment -2.031898 %, total balance 7249.150203,
# day 799, sell 1 unit at price 1106.780029, investment -2.963398 %, total balance 8355.930232,
# day 810: buy 1 unit at price 1108.060059, total balance 7247.870173
# day 811: buy 1 unit at price 1122.469971, total balance 6125.400202
# day 813, sell 1 unit at price 1126.209961, investment 1.637989 %, total balance 7251.610163,
# day 814: buy 1 unit at price 1132.170044, total balance 6119.440119
# day 817: buy 1 unit at price 1148.160034, total balance 4971.280085
# day 819: buy 1 unit at price 1139.319946, total balance 3831.960139
# day 820: buy 1 unit at price 1145.199951, total balance 2686.760188
# day 821, sell 1 unit at price 1129.439941, investment 0.620949 %, total balance 3816.200129,
# day 824, sell 1 unit at price 1134.609985, investment 0.215510 %, total balance 4950.810114,
# day 825: buy 1 unit at price 1135.819946, total balance 3814.990168
# day 826, sell 1 unit at price 1118.150024, investment -2.613748 %, total balance 4933.140192,
# day 827, sell 1 unit at price 1124.089966, investment -1.336761 %, total balance 6057.230158,
# day 828: buy 1 unit at price 1139.930054, total balance 4917.300104
# day 829: buy 1 unit at price 1140.599976, total balance 3776.700128
# day 831, sell 1 unit at price 1138.109985, investment -0.619103 %, total balance 4914.810113,
# day 832, sell 1 unit at price 1122.410034, investment -1.180637 %, total balance 6037.220147,
# day 834, sell 1 unit at price 1107.300049, investment -2.862457 %, total balance 7144.520196,
# day 835, sell 1 unit at price 1117.489990, investment -2.026125 %, total balance 8262.010186,
# day 842: buy 1 unit at price 1097.280029, total balance 7164.730157
# day 843, sell 1 unit at price 1096.439941, investment -0.076561 %, total balance 8261.170098,
# day 846: buy 1 unit at price 1091.489990, total balance 7169.680108
# day 847, sell 1 unit at price 1088.680054, investment -0.257440 %, total balance 8258.360162,
# day 849: buy 1 unit at price 1093.560059, total balance 7164.800103
# day 850: buy 1 unit at price 1095.410034, total balance 6069.390069
# day 851, sell 1 unit at price 1113.050049, investment 1.782251 %, total balance 7182.440118,
# day 852: buy 1 unit at price 1114.939941, total balance 6067.500177
# day 853: buy 1 unit at price 1121.280029, total balance 4946.220148
# day 854: buy 1 unit at price 1120.680054, total balance 3825.540094
# day 855, sell 1 unit at price 1121.199951, investment 2.354362 %, total balance 4946.740045,
# day 856: buy 1 unit at price 1124.989990, total balance 3821.750055
# day 857, sell 1 unit at price 1116.640015, investment 0.152481 %, total balance 4938.390070,
# day 858: buy 1 unit at price 1122.500000, total balance 3815.890070
# day 859, sell 1 unit at price 1140.420044, investment 1.706979 %, total balance 4956.310114,
# day 861, sell 1 unit at price 1131.329956, investment 0.950307 %, total balance 6087.640070,
# day 864, sell 1 unit at price 1132.010010, investment 0.624007 %, total balance 7219.650080,
# day 865: buy 1 unit at price 1133.560059, total balance 6086.090021
# day 866, sell 1 unit at price 1132.050049, investment 0.850784 %, total balance 7218.140070,
# day 869, sell 1 unit at price 1134.410034, investment 0.074983 %, total balance 8352.550104,
# day 871: buy 1 unit at price 1140.650024, total balance 7211.900080
# day 872: buy 1 unit at price 1134.430054, total balance 6077.470026
# day 873, sell 1 unit at price 1133.349976, investment -0.639990 %, total balance 7210.820002,
# day 874, sell 1 unit at price 1136.199951, investment 0.156016 %, total balance 8347.019953,
# day 876: buy 1 unit at price 1128.939941, total balance 7218.080012
# day 877: buy 1 unit at price 1125.380005, total balance 6092.700007
# day 878, sell 1 unit at price 1116.209961, investment -1.127605 %, total balance 7208.909968,
# day 880: buy 1 unit at price 1109.109985, total balance 6099.799983
# day 881: buy 1 unit at price 1112.810059, total balance 4986.989924
# day 882, sell 1 unit at price 1114.349976, investment -0.980116 %, total balance 6101.339900,
# day 883: buy 1 unit at price 1115.140015, total balance 4986.199885
# day 884, sell 1 unit at price 1111.469971, investment 0.212782 %, total balance 6097.669856,
# day 885, sell 1 unit at price 1106.689941, investment -0.549970 %, total balance 7204.359797,
# day 886, sell 1 unit at price 1101.390015, investment -1.233029 %, total balance 8305.749812,
# day 888: buy 1 unit at price 1108.670044, total balance 7197.079768
# day 889: buy 1 unit at price 1093.880005, total balance 6103.199763
# day 890, sell 1 unit at price 1096.839966, investment -1.067051 %, total balance 7200.039729,
# day 892, sell 1 unit at price 1084.069946, investment -0.896813 %, total balance 8284.109675,
# day 893: buy 1 unit at price 1094.829956, total balance 7189.279719
# day 894: buy 1 unit at price 1095.420044, total balance 6093.859675
# day 895: buy 1 unit at price 1100.430054, total balance 4993.429621
# day 896, sell 1 unit at price 1101.719971, investment 0.629323 %, total balance 6095.149592,
# day 898: buy 1 unit at price 1099.689941, total balance 4995.459651
# day 899: buy 1 unit at price 1098.630005, total balance 3896.829646
# day 901, sell 1 unit at price 1063.969971, investment -2.871051 %, total balance 4960.799617,
# day 902, sell 1 unit at price 1065.219971, investment -3.199666 %, total balance 6026.019588,
# day 903, sell 1 unit at price 1079.040039, investment -1.877793 %, total balance 7105.059627,
# day 904: buy 1 unit at price 1075.790039, total balance 6029.269588
# day 906, sell 1 unit at price 1064.800049, investment -3.079286 %, total balance 7094.069637,
# day 907: buy 1 unit at price 1079.339966, total balance 6014.729671
# day 908: buy 1 unit at price 1081.709961, total balance 4933.019710
# day 911: buy 1 unit at price 1098.349976, total balance 3834.669734
# day 912, sell 1 unit at price 1095.680054, investment 1.848875 %, total balance 4930.349788,
# day 913, sell 1 unit at price 1096.189941, investment 1.561137 %, total balance 6026.539729,
# day 914, sell 1 unit at price 1104.959961, investment 2.149375 %, total balance 7131.499690,
# day 915, sell 1 unit at price 1105.089966, investment 0.613647 %, total balance 8236.589656,
# day 919: buy 1 unit at price 1105.910034, total balance 7130.679622
# day 920: buy 1 unit at price 1118.310059, total balance 6012.369563
# day 921, sell 1 unit at price 1113.630005, investment 0.698065 %, total balance 7125.999568,
# day 924: buy 1 unit at price 1118.380005, total balance 6007.619563
# day 925, sell 1 unit at price 1123.920044, investment 0.501648 %, total balance 7131.539607,
# day 926, sell 1 unit at price 1125.819946, investment 0.665243 %, total balance 8257.359553,
# day 927: buy 1 unit at price 1128.329956, total balance 7129.029597
# day 928, sell 1 unit at price 1120.369995, investment -0.705464 %, total balance 8249.399592,
# day 931: buy 1 unit at price 1122.199951, total balance 7127.199641
# ...
# day 3461, sell 1 unit at price 1935.099976, investment -0.568302 %, total balance 5627.207640,
# day 3462, sell 1 unit at price 1968.890015, investment 0.050307 %, total balance 7596.097655,
# day 3464, sell 1 unit at price 1906.130005, investment -2.987039 %, total balance 9502.227660,
# day 3467: buy 1 unit at price 1862.489990, total balance 7639.737670
# day 3469, sell 1 unit at price 1886.760010, investment 1.303095 %, total balance 9526.497680,
# day 3474: buy 1 unit at price 1964.579956, total balance 7561.917724
# day 3475, sell 1 unit at price 1961.630005, investment -0.150157 %, total balance 9523.547729,
# day 3481: buy 1 unit at price 2012.099976, total balance 7511.447753
# day 3482, sell 1 unit at price 2023.569946, investment 0.570050 %, total balance 9535.017699,
# day 3484: buy 1 unit at price 2031.920044, total balance 7503.097655
# day 3485: buy 1 unit at price 2038.260010, total balance 5464.837645
# day 3486, sell 1 unit at price 2039.680054, investment 0.381905 %, total balance 7504.517699,
# day 3488, sell 1 unit at price 2039.329956, investment 0.052493 %, total balance 9543.847655,
# day 3491: buy 1 unit at price 2051.800049, total balance 7492.047606
# day 3494, sell 1 unit at price 2063.500000, investment 0.570229 %, total balance 9555.547606,
# day 3495: buy 1 unit at price 2069.409912, total balance 7486.137694
# day 3496: buy 1 unit at price 2067.030029, total balance 5419.107665
# day 3497, sell 1 unit at price 2072.830078, investment 0.165273 %, total balance 7491.937743,
# day 3498: buy 1 unit at price 2067.560059, total balance 5424.377684
# day 3501, sell 1 unit at price 2074.330078, investment 0.353166 %, total balance 7498.707762,
# day 3502, sell 1 unit at price 2071.919922, investment 0.210870 %, total balance 9570.627684,
# day 3503: buy 1 unit at price 2075.370117, total balance 7495.257567
# day 3504, sell 1 unit at price 2060.310059, investment -0.725656 %, total balance 9555.567626,
# day 3506: buy 1 unit at price 2026.140015, total balance 7529.427611
# day 3507, sell 1 unit at price 2035.329956, investment 0.453569 %, total balance 9564.757567,
# day 3508: buy 1 unit at price 2002.329956, total balance 7562.427611
# day 3509: buy 1 unit at price 1989.630005, total balance 5572.797606
# day 3510, sell 1 unit at price 1972.739990, investment -1.477777 %, total balance 7545.537596,
# day 3511, sell 1 unit at price 2012.890015, investment 1.169062 %, total balance 9558.427611,
# day 3512: buy 1 unit at price 2061.229980, total balance 7497.197631
# day 3513: buy 1 unit at price 2070.649902, total balance 5426.547729
# day 3514: buy 1 unit at price 2078.540039, total balance 3348.007690
# day 3516: buy 1 unit at price 2081.879883, total balance 1266.127807
# day 3519, sell 1 unit at price 2080.350098, investment 0.927607 %, total balance 3346.477905,
# day 3520: buy 1 unit at price 2058.899902, total balance 1287.578003
# day 3523, sell 1 unit at price 2002.609985, investment -3.285921 %, total balance 3290.187988,
# day 3524: buy 1 unit at price 2025.900024, total balance 1264.287964
# day 3527, sell 1 unit at price 2028.260010, investment -2.419007 %, total balance 3292.547974,
# day 3529, sell 1 unit at price 2011.270020, investment -3.391640 %, total balance 5303.817994,
# day 3530, sell 1 unit at price 1992.670044, investment -3.216759 %, total balance 7296.488038,
# day 3531, sell 1 unit at price 2019.420044, investment -0.319857 %, total balance 9315.908082,
# day 3532: buy 1 unit at price 2022.550049, total balance 7293.358033
# day 3533: buy 1 unit at price 2032.119995, total balance 5261.238038
# day 3534: buy 1 unit at price 2063.149902, total balance 3198.088136
# day 3536, sell 1 unit at price 2057.090088, investment 1.707747 %, total balance 5255.178224,
# day 3537: buy 1 unit at price 2029.550049, total balance 3225.628175
# day 3538: buy 1 unit at price 2002.160034, total balance 1223.468141
# day 3541, sell 1 unit at price 2020.849976, investment -0.554594 %, total balance 3244.318117,
# day 3542, sell 1 unit at price 2050.030029, investment -0.635915 %, total balance 5294.348146,
# day 3543: buy 1 unit at price 2041.510010, total balance 3252.838136
# day 3544: buy 1 unit at price 2062.520020, total balance 1190.318116
# day 3547, sell 1 unit at price 2068.590088, investment 1.923581 %, total balance 3258.908204,
# day 3549: buy 1 unit at price 2088.479980, total balance 1170.428224
# day 3550, sell 1 unit at price 2096.989990, investment 4.736382 %, total balance 3267.418214,
# day 3552, sell 1 unit at price 2099.679932, investment 2.849358 %, total balance 5367.098146,
# day 3553: buy 1 unit at price 2097.449951, total balance 3269.648195
# day 3554, sell 1 unit at price 2110.300049, investment 2.316585 %, total balance 5379.948244,
# day 3555, sell 1 unit at price 2109.659912, investment 1.014131 %, total balance 7489.608156,
# day 3556: buy 1 unit at price 2115.479980, total balance 5374.128176
# day 3557: buy 1 unit at price 2113.860107, total balance 3260.268069
# day 3558, sell 1 unit at price 2110.739990, investment 0.633628 %, total balance 5371.008059,
# day 3559, sell 1 unit at price 2104.500000, investment -0.519030 %, total balance 7475.508059,
# day 3560, sell 1 unit at price 2117.389893, investment 0.166983 %, total balance 9592.897952,
# day 3561: buy 1 unit at price 2107.780029, total balance 7485.117923
# day 3562, sell 1 unit at price 2098.530029, investment -0.438850 %, total balance 9583.647952,
# day 3563: buy 1 unit at price 2101.040039, total balance 7482.607913
# day 3564, sell 1 unit at price 2071.260010, investment -1.417395 %, total balance 9553.867923,
# day 3568: buy 1 unit at price 2065.949951, total balance 7487.917972
# day 3569, sell 1 unit at price 2053.399902, investment -0.607471 %, total balance 9541.317874,
# day 3571: buy 1 unit at price 2074.280029, total balance 7467.037845
# day 3572: buy 1 unit at price 2099.500000, total balance 5367.537845
# day 3573: buy 1 unit at price 2089.270020, total balance 3278.267825
# day 3575: buy 1 unit at price 2104.419922, total balance 1173.847903
# day 3579, sell 1 unit at price 2061.020020, investment -0.639258 %, total balance 3234.867923,
# day 3581, sell 1 unit at price 2067.889893, investment -1.505602 %, total balance 5302.757816,
# day 3582: buy 1 unit at price 2059.689941, total balance 3243.067875
# day 3583: buy 1 unit at price 2066.959961, total balance 1176.107914
# day 3587, sell 1 unit at price 2091.179932, investment 0.091415 %, total balance 3267.287846,
# day 3588: buy 1 unit at price 2102.060059, total balance 1165.227787
# day 3589, sell 1 unit at price 2092.429932, investment -0.569753 %, total balance 3257.657719,
# day 3590: buy 1 unit at price 2095.840088, total balance 1161.817631
# day 3591, sell 1 unit at price 2106.629883, investment 2.278981 %, total balance 3268.447514,
# day 3592: buy 1 unit at price 2104.989990, total balance 1163.457524
# day 3595, sell 1 unit at price 2097.290039, investment 1.467376 %, total balance 3260.747563,
# day 3596, sell 1 unit at price 2107.959961, investment 0.280672 %, total balance 5368.707524,
# day 3597, sell 1 unit at price 2112.929932, investment 0.815417 %, total balance 7481.637456,
# day 3598, sell 1 unit at price 2117.689941, investment 0.603326 %, total balance 9599.327397,
# day 3600: buy 1 unit at price 2114.760010, total balance 7484.567387
# day 3601, sell 1 unit at price 2106.850098, investment -0.374034 %, total balance 9591.417485,
# day 3602: buy 1 unit at price 2085.510010, total balance 7505.907475
# day 3604, sell 1 unit at price 2114.489990, investment 1.389587 %, total balance 9620.397465,
# day 3605: buy 1 unit at price 2089.459961, total balance 7530.937504
# day 3606: buy 1 unit at price 2080.149902, total balance 5450.787602
# day 3607, sell 1 unit at price 2088.000000, investment -0.069873 %, total balance 7538.787602,
# day 3609, sell 1 unit at price 2105.330078, investment 1.210498 %, total balance 9644.117680,
# day 3610: buy 1 unit at price 2099.120117, total balance 7544.997563
# day 3612: buy 1 unit at price 2121.100098, total balance 5423.897465
# day 3613: buy 1 unit at price 2122.729980, total balance 3301.167485
# day 3614, sell 1 unit at price 2129.199951, investment 1.432973 %, total balance 5430.367436,
# day 3615, sell 1 unit at price 2127.830078, investment 0.317287 %, total balance 7558.197514,
# day 3616, sell 1 unit at price 2125.850098, investment 0.146986 %, total balance 9684.047612,
# day 3620: buy 1 unit at price 2123.479980, total balance 7560.567632
# day 3621, sell 1 unit at price 2120.790039, investment -0.126676 %, total balance 9681.357671,
# day 3625: buy 1 unit at price 2114.070068, total balance 7567.287603
# day 3626, sell 1 unit at price 2095.840088, investment -0.862317 %, total balance 9663.127691,
# day 3630: buy 1 unit at price 2105.199951, total balance 7557.927740
# day 3631, sell 1 unit at price 2108.860107, investment 0.173863 %, total balance 9666.787847,
# day 3632: buy 1 unit at price 2094.110107, total balance 7572.677740
# day 3633: buy 1 unit at price 2084.429932, total balance 5488.247808
# day 3636: buy 1 unit at price 2121.239990, total balance 3367.007818
# day 3637: buy 1 unit at price 2109.989990, total balance 1257.017828
# day 3639, sell 1 unit at price 2124.199951, investment 1.436880 %, total balance 3381.217779,
# day 3640, sell 1 unit at price 2108.580078, investment 1.158597 %, total balance 5489.797857,
# day 3641: buy 1 unit at price 2102.310059, total balance 3387.487798
# day 3642, sell 1 unit at price 2101.489990, investment -0.931059 %, total balance 5488.977788,
# day 3643: buy 1 unit at price 2057.639893, total balance 3431.337895
# day 3644: buy 1 unit at price 2063.110107, total balance 1368.227788
# day 3646, sell 1 unit at price 2076.780029, investment -1.573939 %, total balance 3445.007817,
# day 3647: buy 1 unit at price 2068.760010, total balance 1376.247807
# day 3648, sell 1 unit at price 2081.340088, investment -0.997473 %, total balance 3457.587895,
# day 3649: buy 1 unit at price 2046.680054, total balance 1410.907841
# day 3651, sell 1 unit at price 2076.620117, investment 0.922427 %, total balance 3487.527958,
# day 3653, sell 1 unit at price 2108.949951, investment 2.221881 %, total balance 5596.477909,
# day 3655: buy 1 unit at price 2124.290039, total balance 3472.187870
# day 3656: buy 1 unit at price 2126.639893, total balance 1345.547977
# day 3657, sell 1 unit at price 2128.280029, investment 2.877087 %, total balance 3473.828006,
# day 3658: buy 1 unit at price 2119.209961, total balance 1354.618045
# day 3659, sell 1 unit at price 2114.149902, investment 3.296551 %, total balance 3468.767947,
# day 3662, sell 1 unit at price 2067.639893, investment -2.666780 %, total balance 5536.407840,
# day 3663: buy 1 unit at price 2093.250000, total balance 3443.157840
# day 3664: buy 1 unit at price 2108.570068, total balance 1334.587772
# day 3665, sell 1 unit at price 2108.629883, investment -0.846876 %, total balance 3443.217655,
# day 3666, sell 1 unit at price 2103.840088, investment -0.725264 %, total balance 5547.057743,
# day 3667: buy 1 unit at price 2098.040039, total balance 3449.017704
# day 3669, sell 1 unit at price 2099.840088, investment 0.314826 %, total balance 5548.857792,
# day 3670, sell 1 unit at price 2083.560059, investment -1.186112 %, total balance 7632.417851,
# day 3671: buy 1 unit at price 2077.570068, total balance 5554.847783
# day 3672, sell 1 unit at price 2104.179932, investment 0.292649 %, total balance 7659.027715,
# day 3673: buy 1 unit at price 2084.070068, total balance 5574.957647
# day 3675: buy 1 unit at price 2083.389893, total balance 3491.567754
# day 3676: buy 1 unit at price 2091.540039, total balance 1400.027715
# day 3678, sell 1 unit at price 2096.919922, investment 0.931370 %, total balance 3496.947637,
# day 3679: buy 1 unit at price 2079.610107, total balance 1417.337530
# day 3681, sell 1 unit at price 1970.890015, investment -5.430722 %, total balance 3388.227545,
# day 3682: buy 1 unit at price 1893.209961, total balance 1495.017584
# day 3683, sell 1 unit at price 1867.609985, investment -10.357154 %, total balance 3362.627569,
# day 3684, sell 1 unit at price 1940.510010, investment -7.220996 %, total balance 5303.137579,
# day 3685, sell 1 unit at price 1987.660034, investment -4.421505 %, total balance 7290.797613,
# day 3686, sell 1 unit at price 1988.869995, investment 5.052796 %, total balance 9279.667608,
# day 3688: buy 1 unit at price 1913.849976, total balance 7365.817632
# day 3689: buy 1 unit at price 1948.859985, total balance 5416.957647
# day 3690: buy 1 unit at price 1951.130005, total balance 3465.827642
# day 3691: buy 1 unit at price 1921.219971, total balance 1544.607671
# day 3692, sell 1 unit at price 1969.410034, investment 2.903052 %, total balance 3514.017705,
# day 3694: buy 1 unit at price 1952.290039, total balance 1561.727666
# day 3695, sell 1 unit at price 1961.050049, investment 0.625497 %, total balance 3522.777715,
# day 3697: buy 1 unit at price 1978.089966, total balance 1544.687749
# day 3699, sell 1 unit at price 1990.199951, investment 2.002427 %, total balance 3534.887700,
# day 3700: buy 1 unit at price 1958.030029, total balance 1576.857671
# day 3703, sell 1 unit at price 1938.760010, investment 0.912964 %, total balance 3515.617681,
# day 3705, sell 1 unit at price 1931.339966, investment -1.073102 %, total balance 5446.957647,
# day 3706, sell 1 unit at price 1881.770020, investment -4.869341 %, total balance 7328.727667,
# day 3707, sell 1 unit at price 1884.089966, investment -3.776248 %, total balance 9212.817633,
# day 3710: buy 1 unit at price 1951.359985, total balance 7261.457648
# day 3712: buy 1 unit at price 1979.920044, total balance 5281.537604
# day 3713, sell 1 unit at price 1995.829956, investment 2.278922 %, total balance 7277.367560,
# day 3714, sell 1 unit at price 2013.430054, investment 1.692493 %, total balance 9290.797614,
# day 3717: buy 1 unit at price 2003.689941, total balance 7287.107673
# day 3718: buy 1 unit at price 1994.239990, total balance 5292.867683
# day 3720, sell 1 unit at price 2033.109985, investment 1.468293 %, total balance 7325.977668,
# day 3721: buy 1 unit at price 2033.660034, total balance 5292.317634
# day 3722, sell 1 unit at price 2030.770020, investment 1.831777 %, total balance 7323.087654,
# day 3724: buy 1 unit at price 2052.510010, total balance 5270.577644
# day 3725: buy 1 unit at price 2075.149902, total balance 3195.427742
# day 3726, sell 1 unit at price 2071.179932, investment 1.844944 %, total balance 5266.607674,
# day 3727, sell 1 unit at price 2065.889893, investment 0.651879 %, total balance 7332.497567,
# day 3729: buy 1 unit at price 2089.409912, total balance 5243.087655
# day 3730, sell 1 unit at price 2079.360107, investment 0.202887 %, total balance 7322.447762,
# day 3731, sell 1 unit at price 2104.050049, investment 0.700683 %, total balance 9426.497811,
# day 3736: buy 1 unit at price 2078.580078, total balance 7347.917733
# day 3737, sell 1 unit at price 2081.719971, investment 0.151060 %, total balance 9429.637704,
# day 3740: buy 1 unit at price 2023.040039, total balance 7406.597665
# day 3741, sell 1 unit at price 2053.189941, investment 1.490327 %, total balance 9459.787606,
# day 3744: buy 1 unit at price 2081.239990, total balance 7378.547616
# day 3746: buy 1 unit at price 2086.590088, total balance 5291.957528
# day 3747, sell 1 unit at price 2089.139893, investment 0.379577 %, total balance 7381.097421,
# day 3749: buy 1 unit at price 2090.110107, total balance 5290.987314
# day 3751, sell 1 unit at price 2102.629883, investment 0.768708 %, total balance 7393.617197,
# day 3752, sell 1 unit at price 2079.510010, investment -0.507155 %, total balance 9473.127207,
# day 3753: buy 1 unit at price 2049.620117, total balance 7423.507090
# day 3756: buy 1 unit at price 2063.590088, total balance 5359.917002
# day 3757: buy 1 unit at price 2047.619995, total balance 3312.297007
# day 3758, sell 1 unit at price 2052.229980, investment 0.127334 %, total balance 5364.526987,
# day 3759, sell 1 unit at price 2012.369995, investment -2.482087 %, total balance 7376.896982,
# day 3760, sell 1 unit at price 2021.939941, investment -1.254142 %, total balance 9398.836923,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
